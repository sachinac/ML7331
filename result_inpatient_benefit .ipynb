# %%
sys.path

# %%
import pandas as pd
import numpy as np
import sys

#Read in the benefitiary and inpatient data, using pandas to save it as a dataframe.
benefit = pd.read_csv("H:/1SMU/healthcare-provider-fraud-detection-analysis/Train_Beneficiarydata-1542865627584.csv")
inpatient = pd.read_csv("H:/1SMU/healthcare-provider-fraud-detection-analysis/Train_Inpatientdata-1542865627584.csv")
result = pd.read_csv("H:/1SMU/healthcare-provider-fraud-detection-analysis/Train-1542865627584.csv")

print(len(benefit))
print(len(inpatient))
print(len(result))
benefit.head()

result_inpatient = pd.merge(inpatient, result, how='inner', on=['Provider'])
result_inpatient.head()

result_inpatient_benefit = pd.merge(benefit,result_inpatient, how='inner', on=['BeneID'])
print(len(result_inpatient_benefit))
result_inpatient_benefit.head()
# Out:
# 138556
# 40474
# 5410
# 40474
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11001  1943-01-01  NaN       1     1                     0     39
# 2  BENE11001  1943-01-01  NaN       1     1                     0     39
# 3  BENE11011  1914-03-01  NaN       2     2                     0      1
# 4  BENE11014  1938-04-01  NaN       2     1                     Y     45
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  ClmDiagnosisCode_8  \
# 0     230                   12                   12  ...               19889
# 1     230                   12                   12  ...                 NaN
# 2     230                   12                   12  ...                 NaN
# 3     360                   12                   12  ...               40390
# 4     780                   12                   12  ...               29620
#
# ...

# %%
result_inpatient_benefit.describe()
# Out:
#              Gender          Race         State        County  \
# count  40474.000000  40474.000000  40474.000000  40474.000000
# mean       1.574863      1.248752     25.392573    377.385136
# std        0.494370      0.698123     15.235985    266.417759
# min        1.000000      1.000000      1.000000      0.000000
# 25%        1.000000      1.000000     11.000000    150.000000
# 50%        2.000000      1.000000     25.000000    342.000000
# 75%        2.000000      1.000000     38.000000    570.000000
# max        2.000000      5.000000     54.000000    999.000000
#
#        NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# count         40474.000000         40474.000000           40474.000000
# mean             11.915402            11.922642               1.495948
# std               0.987961             0.879923               0.499990
# min               0.000000             0.000000               1.000000
# ...
