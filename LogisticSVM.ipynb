# %%
import pandas as pd
import numpy as np

svm_df = pd.read_csv('data/final_fraud_dataset.csv')

# %%
svm_df["PerProviderAvg_Age"]=svm_df.groupby('Provider')['Age'].transform('mean')
svm_df["PerProviderAvg_OPAnnualReimbursementAmt"]=svm_df.groupby('Provider')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerProviderAvg_IPAnnualReimbursementAmt"]=svm_df.groupby('Provider')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerProviderAvg_InscClaimAmtReimbursed"]=svm_df.groupby('Provider')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerProviderAvg_IPAnnualDeductibleAmt"]=svm_df.groupby('Provider')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerProviderAvg_OPAnnualDeductibleAmt"]=svm_df.groupby('Provider')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerProviderAvg_DaysAdmitted"]=svm_df.groupby('Provider')['DaysAdmitted'].transform('mean')


svm_df["PerBeneIDAvg_InscClaimAmtReimbursed"]=svm_df.groupby('BeneID')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerBeneIDAvg_IPAnnualReimbursementAmt"]=svm_df.groupby('BeneID')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerBeneIDAvg_OPAnnualReimbursementAmt"]=svm_df.groupby('BeneID')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerBeneIDAvg_IPAnnualDeductibleAmt"]=svm_df.groupby('BeneID')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerBeneIDAvg_OPAnnualDeductibleAmt"]=svm_df.groupby('BeneID')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerBeneIDAvg_DaysAdmitted"]=svm_df.groupby('BeneID')['DaysAdmitted'].transform('mean')


svm_df["PerOtherPhysicianAvg_InscClaimAmtReimbursed"]=svm_df.groupby('OtherPhysician')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerOtherPhysicianAvg_IPAnnualReimbursementAmt"]=svm_df.groupby('OtherPhysician')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerOtherPhysicianAvg_IPAnnualDeductibleAmt"]=svm_df.groupby('OtherPhysician')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerOtherPhysicianAvg_OPAnnualReimbursementAmt"]=svm_df.groupby('OtherPhysician')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerOtherPhysicianAvg_OPAnnualDeductibleAmt"]=svm_df.groupby('OtherPhysician')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerOtherPhysicianAvg_DaysAdmitted"]=svm_df.groupby('OtherPhysician')['DaysAdmitted'].transform('mean')

##Average features grouped by OperatingPhysician

svm_df["PerOperatingPhysicianAvg_InscClaimAmtReimbursed"]=svm_df.groupby('OperatingPhysician')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerOperatingPhysicianAvg_IPAnnualReimbursementAmt"]=svm_df.groupby('OperatingPhysician')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerOperatingPhysicianAvg_IPAnnualDeductibleAmt"]=svm_df.groupby('OperatingPhysician')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerOperatingPhysicianAvg_OPAnnualReimbursementAmt"]=svm_df.groupby('OperatingPhysician')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerOperatingPhysicianAvg_OPAnnualDeductibleAmt"]=svm_df.groupby('OperatingPhysician')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerOperatingPhysicianAvg_DaysAdmitted"]=svm_df.groupby('OperatingPhysician')['DaysAdmitted'].transform('mean')

### Average features grouped by AttendingPhysician   

svm_df["PerAttendingPhysicianAvg_InscClaimAmtReimbursed"]=svm_df.groupby('AttendingPhysician')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerAttendingPhysicianAvg_IPAnnualReimbursementAmt"]=svm_df.groupby('AttendingPhysician')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerAttendingPhysicianAvg_IPAnnualDeductibleAmt"]=svm_df.groupby('AttendingPhysician')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerAttendingPhysicianAvg_OPAnnualReimbursementAmt"]=svm_df.groupby('AttendingPhysician')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerAttendingPhysicianAvg_OPAnnualDeductibleAmt"]=svm_df.groupby('AttendingPhysician')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerAttendingPhysicianAvg_DaysAdmitted"]=svm_df.groupby('AttendingPhysician')['DaysAdmitted'].transform('mean')

###  Average features grouped by DiagnosisGroupCode  

svm_df["PerDiagnosisGroupCodeAvg_InscClaimAmtReimbursed"]=svm_df.groupby('DiagnosisGroupCode')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerDiagnosisGroupCodeAvg_IPAnnualReimbursementAmt"]=svm_df.groupby('DiagnosisGroupCode')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerDiagnosisGroupCodeAvg_IPAnnualDeductibleAmt"]=svm_df.groupby('DiagnosisGroupCode')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerDiagnosisGroupCodeAvg_OPAnnualReimbursementAmt"]=svm_df.groupby('DiagnosisGroupCode')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerDiagnosisGroupCodeAvg_OPAnnualDeductibleAmt"]=svm_df.groupby('DiagnosisGroupCode')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerDiagnosisGroupCodeAvg_DaysAdmitted"]=svm_df.groupby('DiagnosisGroupCode')['DaysAdmitted'].transform('mean')



### Average features grouped by ClmAdmitDiagnosisCode 

svm_df["PerClmAdmitDiagnosisCodeAvg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmAdmitDiagnosisCode')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmAdmitDiagnosisCodeAvg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmAdmitDiagnosisCode')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmAdmitDiagnosisCodeAvg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmAdmitDiagnosisCode')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmAdmitDiagnosisCodeAvg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmAdmitDiagnosisCode')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmAdmitDiagnosisCodeAvg_OPAnnualDeductisifibleAmt"]=svm_df.groupby('ClmAdmitDiagnosisCode')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmAdmitDiagnosisCodeAvg_DaysAdmitted"]=svm_df.groupby('ClmAdmitDiagnosisCode')['DaysAdmitted'].transform('mean')



### Average features grouped by ClmProcedureCode_1 

svm_df["PerClmProcedureCode_1Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmProcedureCode_1')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmProcedureCode_1Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_1')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_1Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_1')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_1Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_1')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_1Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_1')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_1Avg_DaysAdmitted"]=svm_df.groupby('ClmProcedureCode_1')['DaysAdmitted'].transform('mean')



### Average features grouped by ClmProcedureCode_2

svm_df["PerClmProcedureCode_2Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmProcedureCode_2')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmProcedureCode_2Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_2')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_2Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_2')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_2Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_2')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_2Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_2')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_2Avg_DaysAdmitted"]=svm_df.groupby('ClmProcedureCode_2')['DaysAdmitted'].transform('mean')



###  Average features grouped by ClmProcedureCode_3

svm_df["PerClmProcedureCode_3Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmProcedureCode_3')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmProcedureCode_3Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_3')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_3Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_3')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_3Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_3')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_3Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_3')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_3Avg_DaysAdmitted"]=svm_df.groupby('ClmProcedureCode_3')['DaysAdmitted'].transform('mean')


###  Average features grouped by ClmProcedureCode_4

svm_df["PerClmProcedureCode_4Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmProcedureCode_4')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmProcedureCode_4Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_4')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_4Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_4')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_4Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_4')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_4Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_4')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_4Avg_DaysAdmitted"]=svm_df.groupby('ClmProcedureCode_4')['DaysAdmitted'].transform('mean')

###  Average features grouped by ClmProcedureCode_5

svm_df["PerClmProcedureCode_5Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmProcedureCode_5')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmProcedureCode_5Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_5')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_5Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_5')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_5Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmProcedureCode_5')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmProcedureCode_5Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmProcedureCode_5')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmProcedureCode_5Avg_DaysAdmitted"]=svm_df.groupby('ClmProcedureCode_5')['DaysAdmitted'].transform('mean')


### Average features grouped by ClmDiagnosisCode_1 

svm_df["PerClmDiagnosisCode_1Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_1')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_1Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_1')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_1Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_1')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_1Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_1')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_1Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_1')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_1Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_1')['DaysAdmitted'].transform('mean')




###  Average features grouped by ClmDiagnosisCode_2

svm_df["PerClmDiagnosisCode_2Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_2')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_2Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_2')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_2Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_2')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_2Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_2')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_2Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_2')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_2Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_2')['DaysAdmitted'].transform('mean')

###  Average features grouped by ClmDiagnosisCode_3

svm_df["PerClmDiagnosisCode_3Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_3')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_3Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_3')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_3Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_3')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_3Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_3')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_3Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_3')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_3Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_3')['DaysAdmitted'].transform('mean')



###  Average features grouped by ClmDiagnosisCode_4

svm_df["PerClmDiagnosisCode_4Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_4')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_4Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_4')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_4Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_4')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_4Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_4')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_4Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_4')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_4Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_4')['DaysAdmitted'].transform('mean')

###  Average features grouped by ClmDiagnosisCode_5

svm_df["PerClmDiagnosisCode_5Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_5')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_5Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_5')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_5Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_5')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_5Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_5')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_5Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_5')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_5Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_5')['DaysAdmitted'].transform('mean')

###  Average features grouped by ClmDiagnosisCode_6

svm_df["PerClmDiagnosisCode_6Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_6')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_6Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_6')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_6Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_6')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_6Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_6')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_6Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_6')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_6Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_6')['DaysAdmitted'].transform('mean')

###  Average features grouped by ClmDiagnosisCode_7
svm_df["PerClmDiagnosisCode_7Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_7')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_7Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_7')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_7Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_7')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_7Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_7')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_7Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_7')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_7Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_7')['DaysAdmitted'].transform('mean')

###  Average features grouped by ClmDiagnosisCode_8

svm_df["PerClmDiagnosisCode_8Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_8')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_8Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_8')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_8Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_8')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_8Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_8')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_8Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_8')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_8Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_8')['DaysAdmitted'].transform('mean')

###  Average features grouped by ClmDiagnosisCode_9

svm_df["PerClmDiagnosisCode_9Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_9')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_9Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_9')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_9Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_9')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_9Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_9')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_9Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_9')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_9Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_9')['DaysAdmitted'].transform('mean')

###  Average features grouped by ClmDiagnosisCode_10

svm_df["PerClmDiagnosisCode_10Avg_InscClaimAmtReimbursed"]=svm_df.groupby('ClmDiagnosisCode_10')['InscClaimAmtReimbursed'].transform('mean')
svm_df["PerClmDiagnosisCode_10Avg_IPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_10')['IPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_10Avg_IPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_10')['IPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_10Avg_OPAnnualReimbursementAmt"]=svm_df.groupby('ClmDiagnosisCode_10')['OPAnnualReimbursementAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_10Avg_OPAnnualDeductibleAmt"]=svm_df.groupby('ClmDiagnosisCode_10')['OPAnnualDeductibleAmt'].transform('mean')
svm_df["PerClmDiagnosisCode_10Avg_DaysAdmitted"]=svm_df.groupby('ClmDiagnosisCode_10')['DaysAdmitted'].transform('mean')


### Average Feature based on grouping based on combinations of different variables

svm_df["ClmCount_Provider"]=svm_df.groupby(['Provider'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_BeneID"]=svm_df.groupby(['Provider','BeneID'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_AttendingPhysician"]=svm_df.groupby(['Provider','AttendingPhysician'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_OtherPhysician"]=svm_df.groupby(['Provider','OtherPhysician'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_OperatingPhysician"]=svm_df.groupby(['Provider','OperatingPhysician'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmAdmitDiagnosisCode"]=svm_df.groupby(['Provider','ClmAdmitDiagnosisCode'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmProcedureCode_1"]=svm_df.groupby(['Provider','ClmProcedureCode_1'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmProcedureCode_2"]=svm_df.groupby(['Provider','ClmProcedureCode_2'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmProcedureCode_3"]=svm_df.groupby(['Provider','ClmProcedureCode_3'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmProcedureCode_4"]=svm_df.groupby(['Provider','ClmProcedureCode_4'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmProcedureCode_5"]=svm_df.groupby(['Provider','ClmProcedureCode_5'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmDiagnosisCode_1"]=svm_df.groupby(['Provider','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmDiagnosisCode_2"]=svm_df.groupby(['Provider','ClmDiagnosisCode_2'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmDiagnosisCode_3"]=svm_df.groupby(['Provider','ClmDiagnosisCode_3'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmDiagnosisCode_4"]=svm_df.groupby(['Provider','ClmDiagnosisCode_4'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmDiagnosisCode_5"]=svm_df.groupby(['Provider','ClmDiagnosisCode_5'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmDiagnosisCode_6"]=svm_df.groupby(['Provider','ClmDiagnosisCode_6'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmDiagnosisCode_7"]=svm_df.groupby(['Provider','ClmDiagnosisCode_7'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmDiagnosisCode_8"]=svm_df.groupby(['Provider','ClmDiagnosisCode_8'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_ClmDiagnosisCode_9"]=svm_df.groupby(['Provider','ClmDiagnosisCode_9'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_DiagnosisGroupCode"]=svm_df.groupby(['Provider','DiagnosisGroupCode'])['ClaimID'].transform('count')

svm_df["ClmCount_Provider_BeneID_AttendingPhysician"]=svm_df.groupby(['Provider','BeneID','AttendingPhysician'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_BeneID_OtherPhysician"]=svm_df.groupby(['Provider','BeneID','OtherPhysician'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmProcedureCode_1"]=svm_df.groupby(['Provider','BeneID','AttendingPhysician','ClmProcedureCode_1'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_BeneID_AttendingPhysician_ClmDiagnosisCode_1"]=svm_df.groupby(['Provider','BeneID','AttendingPhysician','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_BeneID_OperatingPhysician"]=svm_df.groupby(['Provider','BeneID','OperatingPhysician'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_BeneID_ClmProcedureCode_1"]=svm_df.groupby(['Provider','BeneID','ClmProcedureCode_1'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1"]=svm_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1'])['ClaimID'].transform('count')
svm_df["ClmCount_Provider_BeneID_ClmDiagnosisCode_1_ClmProcedureCode_1"]=svm_df.groupby(['Provider','BeneID','ClmDiagnosisCode_1','ClmProcedureCode_1'])['ClaimID'].transform('count')

# %%
cols = svm_df.columns.tolist()
preds_fields_1 = cols[4:9]+cols[11:26]+cols[27:28]+cols[29:33]+cols[35:37]+cols[37:39]+cols[40:42]+cols[50:55]+cols[71:3000]
svm_preds_df1 = svm_df[preds_fields_1]

#len(svm_preds_df.columns)
#svm_preds_df1.info()

# %%
import datetime
statDt = []
endDt = []
adminDt = []
dischDt = []

for index, row in svm_preds_df1.iterrows():
    x = datetime.datetime.strptime(row['ClaimStartDt'],'%Y-%m-%d').weekday()
    statDt.append(x)

    y = datetime.datetime.strptime(row['ClaimEndDt'],'%Y-%m-%d').weekday()
    endDt.append(y)
    
    z = datetime.datetime.strptime(row['AdmissionDt'],'%Y-%m-%d').weekday()
    adminDt.append(z)
    
    a = datetime.datetime.strptime(row['DischargeDt'],'%Y-%m-%d').weekday()
    dischDt.append(a)

# %%
statDt = np.asarray(statDt)
endDt = np.asarray(endDt)
adminDt = np.asarray(adminDt)
dischDt = np.asarray(dischDt)
svm_preds_df1['ClaimStartWkDt'] = statDt
svm_preds_df1['ClaimEndWkDt'] = endDt
svm_preds_df1['AdminWkDt'] = adminDt
svm_preds_df1['DischWkDt'] = dischDt
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# ...

# %%
#svm_preds_df1[['Alive']].describe().transpose()

# %%
svm_preds_df1['Alive'] = svm_preds_df1.Alive=='Y'
svm_preds_df1.Alive = svm_preds_df1.Alive.astype(np.int)
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
svm_preds_df1.Race = svm_preds_df1.Race.astype(np.object)
svm_preds_df1.Gender = svm_preds_df1.Gender.astype(np.object)
svm_preds_df1[['Race','Gender']].describe().transpose()
# Out:
#         count  unique  top   freq
# Race    40474       4    1  34126
# Gender  40474       2    2  23267

# %%
svm_preds_df1['IsMale'] = svm_preds_df1.Gender==2
svm_preds_df1.IsMale = svm_preds_df1.IsMale.astype(np.int)
svm_preds_df1['IsRace1'] = svm_preds_df1.Race==1
svm_preds_df1.IsRace1 = svm_preds_df1.IsRace1.astype(np.int)
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# ...

# %%
#svm_preds_df1.AttendingPhysician.mode()
#svm_preds_df1.AttendingPhysician.value_counts()[:50].sort_values(ascending=False)

# %%
svm_preds_df1['IsOtherPhysician'] = svm_preds_df1.OtherPhysician=='None'
svm_preds_df1.IsOtherPhysician = svm_preds_df1.IsOtherPhysician.astype(np.int)
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
svm_preds_df1[['ClmProcedureCode_1','ClmDiagnosisCode_1','ClmAdmitDiagnosisCode','AdmissionDt','ClmDiagnosisCode_2','ClmProcedureCode_2']].describe().transpose()
# Out:
#                        count unique         top   freq
# ClmProcedureCode_1     40474   1118        None  17326
# ClmDiagnosisCode_1     40474   2254         486   1499
# ClmAdmitDiagnosisCode  40474   1928       78650   1731
# AdmissionDt            40474    398  2009-02-10    144
# ClmDiagnosisCode_2     40474   2440        4019   2484
# ClmProcedureCode_2     40474    298        None  35020

# %%
#svm_preds_df1['ClmProcedureCode_2'] = svm_preds_df1.ClmProcedureCode_2=='None'
#svm_preds_df1.ClmProcedureCode_2 = svm_preds_df1.ClmProcedureCode_2.astype(np.int)

# %%
#svm_preds_df1.ClmProcedureCode_1.value_counts()[:50].sort_values(ascending=False)

# %%
#svm_preds_df1.ClmDiagnosisCode_1.value_counts()[:50].sort_values(ascending=False)

# %%
#svm_preds_df1.ClmAdmitDiagnosisCode.value_counts()[:50].sort_values(ascending=False)

# %%
#svm_preds_df1.PotentialFraud

# %%
svm_preds_df1['PotentialFraud'] = svm_preds_df1.PotentialFraud=='Yes'
svm_preds_df1.PotentialFraud = svm_preds_df1.PotentialFraud.astype(np.int)
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
list = ['ChronicCond_Alzheimer','ChronicCond_Heartfailure','ChronicCond_KidneyDisease','ChronicCond_Cancer',
'ChronicCond_ObstrPulmonary','ChronicCond_Depression','ChronicCond_Diabetes','ChronicCond_IschemicHeart',
'ChronicCond_Osteoporasis','ChronicCond_rheumatoidarthritis','ChronicCond_stroke']

for i in list:
    svm_preds_df1[i] = svm_preds_df1[i] == 1
    svm_preds_df1[i] = svm_preds_df1[i].astype(np.int)
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
svm_preds_df1['RenalDiseaseIndicator'] = svm_preds_df1['RenalDiseaseIndicator'] == 'Y'
svm_preds_df1['RenalDiseaseIndicator'] = svm_preds_df1['RenalDiseaseIndicator'].astype(np.int)
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#svm_preds_df1.ClaimStartWkDt.describe().transpose()

# %%
svm_preds_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40474 entries, 0 to 40473
# Columns: 215 entries, Gender to IsOtherPhysician
# dtypes: float64(129), int64(70), object(16)
# memory usage: 66.4+ MB

# %%
svm_preds_df = svm_preds_df1
y = svm_preds_df.PotentialFraud
del svm_preds_df1['Gender']
del svm_preds_df1['Race']
del svm_preds_df1['ClmAdmitDiagnosisCode']
del svm_preds_df1['ClmDiagnosisCode_1']
del svm_preds_df1['ClmDiagnosisCode_2']
del svm_preds_df1['OtherPhysician']
del svm_preds_df1['ClmProcedureCode_2']
del svm_preds_df1['ClmProcedureCode_3']
del svm_preds_df1['ClmProcedureCode_4']
del svm_preds_df1['ClmProcedureCode_5']
del svm_preds_df1['Provider']
#del svm_preds_df1['PotentialFraud']
del svm_preds_df1['ClaimStartDt']
del svm_preds_df1['ClaimEndDt']
del svm_preds_df1['AdmissionDt']
del svm_preds_df1['DischargeDt']

from boruta import BorutaPy

#X_train.y = y_train
train = svm_preds_df1
#test = X_test

train = pd.get_dummies(train , sparse=True) 

#test = pd.get_dummies(train, drop_first=True, dummy_na=True)

# %% [raw]
# from sklearn.model_selection import train_test_split
# train, X_test= train_test_split(train, test_size=0.3, random_state=42)

# %%
Y = train['PotentialFraud'].values.ravel()
del train['PotentialFraud']
#features = [f for f in train.columns if f not in ['TARGET','SK_ID_CURR']]
features = train.columns
len(features)
# Out:
# 1316

# %%
X_init = train[features].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_init)
X_init = scaler.transform(X_init)

# %%
from sklearn.ensemble.forest import RandomForestClassifier
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)



boruta_feature_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42, max_iter = 50, perc = 90)
boruta_feature_selector.fit(X_init, Y)
# Out:
# Iteration: 	1 / 50
# Confirmed: 	0
# Tentative: 	1316
# Rejected: 	0
# Iteration: 	2 / 50
# Confirmed: 	0
# Tentative: 	1316
# Rejected: 	0
# Iteration: 	3 / 50
# Confirmed: 	0
# Tentative: 	1316
# Rejected: 	0
# Iteration: 	4 / 50
# Confirmed: 	0
# Tentative: 	1316
# Rejected: 	0
# Iteration: 	5 / 50
# Confirmed: 	0
# Tentative: 	1316
# Rejected: 	0
# Iteration: 	6 / 50
# Confirmed: 	0
# Tentative: 	1316
# Rejected: 	0
# Iteration: 	7 / 50
# Confirmed: 	0
# Tentative: 	1316
# Rejected: 	0
# Iteration: 	8 / 50
# Confirmed: 	157
# Tentative: 	14
# Rejected: 	1145
# Iteration: 	9 / 50
# Confirmed: 	157
# Tentative: 	14
# Rejected: 	1145
# Iteration: 	10 / 50
# Confirmed: 	157
# Tentative: 	14
# Rejected: 	1145
# Iteration: 	11 / 50
# Confirmed: 	157
# Tentative: 	14
# Rejected: 	1145
# Iteration: 	12 / 50
# Confirmed: 	158
# Tentative: 	13
# Rejected: 	1145
# Iteration: 	13 / 50
# Confirmed: 	158
# Tentative: 	13
# Rejected: 	1145
# Iteration: 	14 / 50
# Confirmed: 	158
# ...

# %% [raw]
# import matplotlib.pyplot as plt
# import lightgbm as lgb
#
# d_train = lgb.Dataset(train, label=Y)
#
# param = {'max_depth': 5, 'learning_rate' : 0.1, 'num_leaves': 900, 'n_estimators': 100}
#
# model = lgb.train(params=param,train_set=d_train)
#
# print('Plot feature importances…')
#
# ax = lgb.plot_importance(model2, max_num_features=50)
#
# plt.show()
# feature_importances = model.feature_importance
# feature_importances

# %%
X_filtered = boruta_feature_selector.transform(X_init)
X_filtered.shape
# Out:
# (40474, 160)

# %%
final_features = []
indexes = np.where(boruta_feature_selector.support_ == True)
for x in np.nditer(indexes):
    final_features.append(features[x])
len (final_features)
# Out:
# 160

# %%
# Final dataset with features from features selected by Boruta package
df = train[final_features]

# %%
from sklearn.model_selection import ShuffleSplit

y = Y
X = df.values

num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as mt


lr_clf = LogisticRegression(penalty='l2', C=1.0, class_weight=None, solver='liblinear' ) # get object

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object.split(X,y): 
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
    # train the reusable logisitc regression model on the training data
    lr_clf.fit(X_train,y_train)  # train object
    y_hat = lr_clf.predict(X_test) # get test set precitions

    # now let's get the accuracy and confusion matrix for this iterations of training/testing
    acc = mt.accuracy_score(y_test,y_hat)
    rec = mt.recall_score(y_test,y_hat)
    pres = mt.precision_score(y_test,y_hat)
    conf = mt.confusion_matrix(y_test,y_hat)
    print("====Iteration",iter_num," ====")
    print("accuracy", acc )
    print("Recall", rec )
    print("Precision", pres )
    print("confusion matrix\n",conf)
    iter_num+=1
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ====Iteration 0  ====
# accuracy 0.7946880790611489
# Recall 0.7784405624201107
# Precision 0.8545369504209541
# confusion matrix
#  [[2779  622]
#  [1040 3654]]
# ====Iteration 1  ====
# accuracy 0.7888820259419395
# Recall 0.7740558992959249
# Precision 0.8480598410472183
# confusion matrix
#  [[2758  650]
#  [1059 3628]]
# ====Iteration 2  ====
# accuracy 0.8040765904879555
# Recall 0.7848960543063216
# Precision 0.8661048689138576
# confusion matrix
#  [[2809  572]
#  [1014 3700]]
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
# ...

# %%
for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
    lr_clf.fit(X[train_indices],y[train_indices])  # train object
    y_hat = lr_clf.predict(X[test_indices]) # get test set precitions

    # print the accuracy and confusion matrix 
    acc = mt.accuracy_score(y_test,y_hat)
    rec = mt.recall_score(y_test,y_hat)
    pres = mt.precision_score(y_test,y_hat)
    conf = mt.confusion_matrix(y_test,y_hat)
    print("====Iteration",iter_num," ====")
    print("accuracy", acc )
    print("Recall", rec )
    print("Precision", pres )
    print("confusion matrix\n",conf)    print("====Iteration",iter_num," ====")
    print("accuracy", mt.accuracy_score(y[test_indices],y_hat)) 
    print("confusion matrix\n",mt.confusion_matrix(y[test_indices],y_hat))
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ====Iteration 0  ====
# accuracy 0.5001852995676344
# Recall 0.5267665952890792
# Precision 0.5726256983240223
# confusion matrix
#  [[1589 1836]
#  [2210 2460]]
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ====Iteration 1  ====
# accuracy 0.5006794317479926
# Recall 0.5167023554603855
# Precision 0.5747975226298238
# confusion matrix
#  [[1640 1785]
#  [2257 2413]]
# ...

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(lr_clf, X, y=y, cv=cv_object) # this also can help with parallelism
print(accuracies)
# Out:
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# [0.79407041 0.80481779 0.79617048]
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/sklearn/svm/_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
# This is Dustin's code
# Scale training data
from sklearn.preprocessing import MinMaxScaler
import timeit
start_time = timeit.default_timer()

scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)


# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=86)


total_time = timeit.default_timer() - start_time
print("Total time: ", total_time)
# Out:
# Total time:  0.33410141900822055

# %%
# This is Dustin's code
# Fitting the model takes awhile, let's time it:
import timeit
start_time = timeit.default_timer()

# Logistic Regression
from sklearn.linear_model import LogisticRegression
# This line works, takes about 15 minutes to train
#logreg = LogisticRegression(penalty='l2', random_state=86, solver='sag', n_jobs=-1)

# This is what I'm working on, still trying to get this to train w/o crashing.
logreg = LogisticRegression(penalty='l2', random_state=86, solver='lbfgs', n_jobs=-1)

# fit the model
logreg.fit(X_train,y_train)

fit_time = timeit.default_timer() - start_time
print("Fit time: ", fit_time)
# Out:
# Fit time:  5.975241688996903

# %%
# This is Dustin's code
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
#After fitting, you can play around with predictions to really see the effect of the probability threshold

# Build predictions:
y_pred=logreg.predict_proba(X_test)[:,1] > .51

# import the metrics class
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)

class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Potential Fraud Confusion matrix', y=1.1)
plt.ylabel('Actual Fraud')
plt.xlabel('Predicted Fraud')
print('accuracy:', acc )print('accuracy:', acc )
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.7915997529339098
# Precision: 0.8479132280122612
# Recall: 0.7753341957740405

# %%
from ipywidgets import widgets as wd

def lr_explor(cost):
    lr_clf = LogisticRegression(penalty='l2', C=cost, class_weight=None,solver='liblinear') # get object
    accuracies = cross_val_score(lr_clf,X,y=y,cv=cv_object) # this also can help with parallelism
    print(accuracies)

wd.interact(lr_explor,cost=(0.001,5.0,0.05),__manual=True)
# Out:
# [0.79456455 0.79419395 0.80024707]
# <function __main__.lr_explor(cost)>

# %%
weights = lr_clf.coef_.T # take transpose to make a column vector
variable_names = df.columns
for coef, name in zip(weights,variable_names):
    print(name, 'has weight of', coef[0])
# Out:
# State has weight of 0.004835200120316471
# County has weight of -8.886353672216085e-05
# IPAnnualReimbursementAmt has weight of 3.762974599495838e-07
# IPAnnualDeductibleAmt has weight of 4.1632453257914144e-06
# OPAnnualReimbursementAmt has weight of -2.9632474087095945e-06
# OPAnnualDeductibleAmt has weight of 2.0278184683627262e-05
# InscClaimAmtReimbursed has weight of 8.023312708551243e-07
# DaysAdmitted has weight of 0.0004120237463709475
# Age has weight of -0.0008310234387290638
# NoPhysician has weight of 3.445679561934774e-05
# OtherPhysicianPresent has weight of 2.334732577908977e-05
# OperatingPhysicianPresent has weight of 1.3248866479214799e-05
# NoOfDiag has weight of 2.8512187311418e-05
# NoOfProc has weight of 3.359371469687451e-05
# NoOfChronicCondition has weight of -2.6060229555544198e-05
# PerProviderAvg_Age has weight of -0.0007207793780306984
# PerProviderAvg_OPAnnualReimbursementAmt has weight of 0.00021023475814617543
# ...

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=0.05, solver='liblinear') # get object, the 'C' value is less (can you guess why??)
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf )

# sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,df'PotentialFraud'No.columns) # combine attributes
zip_vars = sorted(zip_vars)
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# accuracy: 0.7902408894379247
# [[2780  677]
#  [1021 3617]]
# ClmCount_Provider_ClmProcedureCode_1 has weight of -0.31533550450174996
# PerProviderAvg_OPAnnualDeductibleAmt has weight of -0.1470475403485024
# PerDiagnosisGroupCodeAvg_IPAnnualReimbursementAmt has weight of -0.091796620890405
# PerProviderAvg_IPAnnualReimbursementAmt has weight of -0.0899157366931412
# IPAnnualReimbursementAmt has weight of -0.08683195063495297
# PerBeneIDAvg_IPAnnualReimbursementAmt has weight of -0.08683195063495297
# OperatingPhysicianPresent has weight of -0.08020327927929038
# PerClmProcedureCode_3Avg_IPAnnualDeductibleAmt has weight of -0.057627693969903825
# ClmCount_Provider_ClmDiagnosisCode_8 has weight of -0.057486176469330436
# ClmCount_Provider_DiagnosisGroupCode has weight of -0.05728972132970006
# ClmCount_Provider_ClmDiagnosisCode_3 has weight of -0.04726357344614608
# PerOtherPhysicianAvg_DaysAdmitted has weight of -0.04621968242209031
# ...

# %%
from the features of the selection of the # now let's make a pandas Series with the names and values, and plot them
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


weights = pd.Series(lr_clf.coef_[0],index=df.columns)
weights.plot(kind='bar')
plt.show()

# %%
# SVM
# okay, so run through the cross validation loop and set the training and testing variable for one single iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]tate
    
X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test)

# %%
'PotentialFraud'# lets investigate SVMs on the data and play with the parameters and kernels
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=0.5, kernel='rbf', degree=3, gamma='auto') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
rec = mt.recall_score(y_test,y_hat)
pres = mt.precision_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print("====Iteration",iter_num," ====")
print("accuracy", acc )
print("Recall", rec )
print("Precision", pres )
print("confusion matrix\n",conf)
print("accuracy", mt.accuracy_score(y[test_indices],y_hat)) 
print("confusion matrix\n",mt.confusion_matrix(y[test_indices],y_hat))
# Out:
# ====Iteration 3  ====
# accuracy 0.7912291537986411
# Recall 0.7945087945087945
# Precision 0.8349864743011722
# confusion matrix
#  [[2701  732]
#  [ 958 3704]]
# accuracy 0.7912291537986411
# confusion matrix
#  [[2701  732]
#  [ 958 3704]]

# %%
# look at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )
# Out:
# (16930, 160)
# (16930,)
# [8439 8491]

# %%
print(svm_clf.coef_)
weights = pd.Series(svm_clf.coef_[0],index=df.columns)
weights.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-55591ee49843> in <module>
# ----> 1 print(svm_clf.coef_)
#       2 weights = pd.Series(svm_clf.coef_[0],index=df.columns)
#       3 weights.plot(kind='bar')
#
# ~/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/sklearn/svm/_base.py in coef_(self)
#     490     def coef_(self):
#     491         if self.kernel != 'linear':
# --> 492             raise AttributeError('coef_ is only available when using a '
#     493                                  'linear kernel')
#     494
#
# AttributeError: coef_ is only available when using a linear kernel

# %%
# Now let's do some different analysis with the SVM and look at the instances that were chosen as support vectors

# now lets look at the support for the vectors and see if we they are indicative of anything
# grabe the rows that were selected as support vectors (these are usually instances that are hard to classify)

# make a dataframe of the training data
df_tested_on = df.iloc[train_indices].copy() # saved from above, the indices chosen for training
# now get the support vectors from the trained model
df_support = df_tested_on.iloc[svm_clf.support_,:].copy()

df_support['PotentialFraud'] = y[svm_clf.support_] # add back in the 'Survived' Column to the pandas dataframe
df# now lets see the statistics of these attributes
from pandas.plotting import boxplot

# group the original data and the support vectors
df_grouped_support = df_support.groupby(['Survived'])
df_grouped = df_imputed.groupby(['Survived'])

# plot KDE of Different variables
vars_to_plot = ['Age','Pclass','IsMale','FamilySize']

for v in vars_to_plot:
    plt.figure(figsize=(10,4))
    # plot support vector stats
    plt.subplot(1,2,1)
    ax = df_grouped_support[v].plot.kde() 
    plt.legend(['Perished','Survived'])
    plt.title(v+' (Instances chosen as Support Vectors)')
    
    # plot original distributions
    plt.subplot(1,2,2)
    ax = df_grouped[v].plot.kde() 
    plt.legend(['Perished','Survived'])
    plt.title(v+' (Original)')tate['PotentialFraud'] = y # also add it back in for the original data
df_support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16930 entries, 19046 to 25362
# Columns: 161 entries, State to PotentialFraud
# dtypes: Sparse[int64, 0](1), float64(110), int64(50)
# memory usage: 20.9 MB
# /home/ikenna/Documents/datascience/Anaconda/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
# now lets see the statistics of these attributes
from pandas.plotting import boxplot

# group the original data and the support vectors
df_grouped_support = df_support.groupby(['PotentialFraud'])
df_grouped = df.groupby(['PotentialFraud'])

# plot KDE of Different variables
vars_to_plot = ['State','County','IPAnnualReimbursementAmt','IPAnnualDeductibleAmt',
               'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt','InscClaimAmtReimbursed','Age', 
            'NoPhysician','OtherPhysicianPresent','OperatingPhysicianPresent','NoOfDiag',
            'NoOfProc','NoOfChronicCondition']

for v in vars_to_plot:
    plt.figure(figsize=(10,4))
    # plot support vector stats
    plt.subplot(1,2,1)
    ax = df_grouped_support[v].plot.kde() 
    plt.legend(['Not Fraud','Potntial Fraud'])
    plt.title(v+' (Instances chosen as Support Vectors)')
    
    # plot original distributions
    plt.subplot(1,2,2)
    ax = df_grouped[v].plot.kde() 
    plt.legend(['Not Fraud','Potntial Fraud'])
    plt.title(v+' (Original)')
