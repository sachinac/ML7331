# %% [markdown]
# <font size=6> <b> SMU Lab Three - MSDS7331 - Machine Learning-1 </b> </font>
#
# <font size=5> <b> Summer 2020 Group - Sachin, Ikenna, Edgar, Dustin </b></font>
#
#
#
#
# <img src="https://github.com/sachinac/ML7331/blob/master/data/maxresdefault.png?raw=true" alt="Recommender" border="4">
# <div align="center"> Image Source : Google Images </div>
# <p align="center"><font size=5> <b> Movie Recommender System  </b></font> </p>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-1">Import Libraries</a></span></li><li><span><a href="#Introduction" data-toc-modified-id="Introduction-2">Introduction</a></span></li><li><span><a href="#Business-Understanding" data-toc-modified-id="Business-Understanding-3">Business Understanding</a></span></li><li><span><a href="#Data-Understanding-1" data-toc-modified-id="Data-Understanding-1-4">Data Understanding 1</a></span><ul class="toc-item"><li><span><a href="#Data-source" data-toc-modified-id="Data-source-4.1">Data source</a></span></li><li><span><a href="#Data-Description-Summary" data-toc-modified-id="Data-Description-Summary-4.2">Data Description Summary</a></span></li><li><span><a href="#Download-from-AWS-S3" data-toc-modified-id="Download-from-AWS-S3-4.3">Download from AWS S3</a></span></li><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-4.4">Load Data</a></span></li><li><span><a href="#Get-the-glimpse-of-the-data" data-toc-modified-id="Get-the-glimpse-of-the-data-4.5">Get the glimpse of the data</a></span><ul class="toc-item"><li><span><a href="#Credits" data-toc-modified-id="Credits-4.5.1">Credits</a></span></li><li><span><a href="#Keywords" data-toc-modified-id="Keywords-4.5.2">Keywords</a></span></li><li><span><a href="#Movies-Metadata" data-toc-modified-id="Movies-Metadata-4.5.3">Movies Metadata</a></span></li><li><span><a href="#Movie-ratings" data-toc-modified-id="Movie-ratings-4.5.4">Movie ratings</a></span></li><li><span><a href="#Links" data-toc-modified-id="Links-4.5.5">Links</a></span></li></ul></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-4.6">Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Movie-Credits" data-toc-modified-id="Movie-Credits-4.6.1">Movie Credits</a></span></li><li><span><a href="#Movie-Keywords" data-toc-modified-id="Movie-Keywords-4.6.2">Movie Keywords</a></span></li><li><span><a href="#Movie-Metadata" data-toc-modified-id="Movie-Metadata-4.6.3">Movie Metadata</a></span></li><li><span><a href="#Movie-Ratings" data-toc-modified-id="Movie-Ratings-4.6.4">Movie Ratings</a></span></li></ul></li><li><span><a href="#Descriptive-Statistics-Summary" data-toc-modified-id="Descriptive-Statistics-Summary-4.7">Descriptive Statistics Summary</a></span><ul class="toc-item"><li><span><a href="#Credits/Keyword-Stats-Summary" data-toc-modified-id="Credits/Keyword-Stats-Summary-4.7.1">Credits/Keyword Stats Summary</a></span></li><li><span><a href="#Ratings-Stats-Summary" data-toc-modified-id="Ratings-Stats-Summary-4.7.2">Ratings Stats Summary</a></span></li><li><span><a href="#Movies-MetaData-Stats-Summary" data-toc-modified-id="Movies-MetaData-Stats-Summary-4.7.3">Movies MetaData Stats Summary</a></span></li></ul></li></ul></li><li><span><a href="#Data-Understanding-2---Visualization" data-toc-modified-id="Data-Understanding-2---Visualization-5">Data Understanding 2 - Visualization</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Distribution-of-Movie-Popularity" data-toc-modified-id="Distribution-of-Movie-Popularity-5.0.1">Distribution of Movie Popularity</a></span></li><li><span><a href="#Distribution-of-Movie-Ratings" data-toc-modified-id="Distribution-of-Movie-Ratings-5.0.2">Distribution of Movie Ratings</a></span></li><li><span><a href="#Distribution-of-Movie-Genres" data-toc-modified-id="Distribution-of-Movie-Genres-5.0.3">Distribution of Movie Genres</a></span></li><li><span><a href="#Distribution-of-vote-average" data-toc-modified-id="Distribution-of-vote-average-5.0.4">Distribution of vote average</a></span></li><li><span><a href="#Word-cloud---Common-Keywords" data-toc-modified-id="Word-cloud---Common-Keywords-5.0.5">Word cloud - Common Keywords</a></span></li><li><span><a href="#Top-10-Stats:" data-toc-modified-id="Top-10-Stats:-5.0.6">Top 10 Stats:</a></span></li><li><span><a href="#Top-10-Popular-Movies" data-toc-modified-id="Top-10-Popular-Movies-5.0.7">Top 10 Popular Movies</a></span></li><li><span><a href="#Top-10-High-Budget-Movies" data-toc-modified-id="Top-10-High-Budget-Movies-5.0.8">Top 10 High Budget Movies</a></span></li><li><span><a href="#Top-10-actors" data-toc-modified-id="Top-10-actors-5.0.9">Top 10 actors</a></span></li><li><span><a href="#Top-10-Genres" data-toc-modified-id="Top-10-Genres-5.0.10">Top 10 Genres</a></span></li><li><span><a href="#Top-10-Directors" data-toc-modified-id="Top-10-Directors-5.0.11">Top 10 Directors</a></span></li><li><span><a href="#Top-10-Producers" data-toc-modified-id="Top-10-Producers-5.0.12">Top 10 Producers</a></span></li><li><span><a href="#Top-10-Collections" data-toc-modified-id="Top-10-Collections-5.0.13">Top 10 Collections</a></span></li><li><span><a href="#Top-10-Original-languages" data-toc-modified-id="Top-10-Original-languages-5.0.14">Top 10 Original languages</a></span></li><li><span><a href="#Top-10-Spoken-Languages" data-toc-modified-id="Top-10-Spoken-Languages-5.0.15">Top 10 Spoken Languages</a></span></li><li><span><a href="#Top-10-Movies-by-vote_count" data-toc-modified-id="Top-10-Movies-by-vote_count-5.0.16">Top 10 Movies by vote_count</a></span></li></ul></li></ul></li><li><span><a href="#Modeling-and-Evaluation-1" data-toc-modified-id="Modeling-and-Evaluation-1-6">Modeling and Evaluation 1</a></span><ul class="toc-item"><li><span><a href="#Set-GPU-for-Recommendation-System" data-toc-modified-id="Set-GPU-for-Recommendation-System-6.1">Set GPU for Recommendation System</a></span></li><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-6.2">Train Test Split</a></span></li><li><span><a href="#Supporting-functions" data-toc-modified-id="Supporting-functions-6.3">Supporting functions</a></span></li><li><span><a href="#Item-Item-collaborative-model" data-toc-modified-id="Item-Item-collaborative-model-6.4">Item-Item collaborative model</a></span><ul class="toc-item"><li><span><a href="#Item-Item-Model-Summary" data-toc-modified-id="Item-Item-Model-Summary-6.4.1">Item-Item Model Summary</a></span></li><li><span><a href="#Recommendations-from-Item-Item-Model" data-toc-modified-id="Recommendations-from-Item-Item-Model-6.4.2">Recommendations from Item-Item Model</a></span></li></ul></li><li><span><a href="#Basic-Explicit-Model-(user-item)" data-toc-modified-id="Basic-Explicit-Model-(user-item)-6.5">Basic Explicit Model (user-item)</a></span></li></ul></li><li><span><a href="#Modeling-and-Evaluation-2" data-toc-modified-id="Modeling-and-Evaluation-2-7">Modeling and Evaluation 2</a></span><ul class="toc-item"><li><span><a href="#Item-Item-Model-Evaluation" data-toc-modified-id="Item-Item-Model-Evaluation-7.1">Item-Item Model Evaluation</a></span></li><li><span><a href="#Item-Item-Model-Evaluation-Result" data-toc-modified-id="Item-Item-Model-Evaluation-Result-7.2">Item-Item Model Evaluation Result</a></span></li><li><span><a href="#User-Item-Model-Evaluation" data-toc-modified-id="User-Item-Model-Evaluation-7.3">User-Item Model Evaluation</a></span></li></ul></li><li><span><a href="#Modeling-and-Evaluation-3" data-toc-modified-id="Modeling-and-Evaluation-3-8">Modeling and Evaluation 3</a></span><ul class="toc-item"><li><span><a href="#Precision-Recall-Curves-(Comparison)" data-toc-modified-id="Precision-Recall-Curves-(Comparison)-8.1">Precision Recall Curves (Comparison)</a></span></li><li><span><a href="#RMSE" data-toc-modified-id="RMSE-8.2">RMSE</a></span><ul class="toc-item"><li><span><a href="#Item-Item-model" data-toc-modified-id="Item-Item-model-8.2.1">Item-Item model</a></span></li><li><span><a href="#User-Item-Base-Model" data-toc-modified-id="User-Item-Base-Model-8.2.2">User-Item Base Model</a></span></li><li><span><a href="#User-Item-Model-(Minimum-Side-Information)" data-toc-modified-id="User-Item-Model-(Minimum-Side-Information)-8.2.3">User-Item Model (Minimum Side Information)</a></span></li><li><span><a href="#User-Item-Model-(Extra-Side-information)" data-toc-modified-id="User-Item-Model-(Extra-Side-information)-8.2.4">User-Item Model (Extra Side information)</a></span></li></ul></li><li><span><a href="#Precision-Recall-Curves" data-toc-modified-id="Precision-Recall-Curves-8.3">Precision Recall Curves</a></span><ul class="toc-item"><li><span><a href="#Item-Item-Model" data-toc-modified-id="Item-Item-Model-8.3.1">Item-Item Model</a></span></li><li><span><a href="#User-Item-Model" data-toc-modified-id="User-Item-Model-8.3.2">User-Item Model</a></span></li></ul></li></ul></li><li><span><a href="#Modeling-and-Evaluation-4" data-toc-modified-id="Modeling-and-Evaluation-4-9">Modeling and Evaluation 4</a></span></li><li><span><a href="#Deployment" data-toc-modified-id="Deployment-10">Deployment</a></span></li><li><span><a href="#Exceptional-Work" data-toc-modified-id="Exceptional-Work-11">Exceptional Work</a></span></li><li><span><a href="#References" data-toc-modified-id="References-12">References</a></span></li></ul></div>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import turicreate as tc
import turicreate.aggregate as agg
import ast
import wget
import zipfile
import os
import seaborn as sns
import matplotlib.pyplot as plt

from datetime import datetime
from sklearn.preprocessing import MultiLabelBinarizer
from wordcloud import WordCloud, STOPWORDS

timebreak = '\n\n----------------------------------------------------\nCell Processing Time'

# %% [markdown]
# # Introduction

# %% [markdown]
# <i> "A recommender system calculates and provides relevant content to the user based on knowledge of the user, content, and interactions between the user and the item." </i> - Practical Recommeder Systems by Kim Falk
#
# <b> What are recommender Systems ? </b>
#
# Systems that are designed to predict user's interests and recommend product items that are likely interesting for them. These are most powerful system particularly for online retailers to boost sales. E-commerce and retail companies are leveraging power of data and boosting sales by implementing recommender systems on their websites. The use cases of these systems have been steadily increasing within the last few years.
#
# Companies like Amazon, Netflix, Linkedin, and Pandora leverage recommender systems to help users discover new and relevant items (products, videos, jobs, music), creating a delightful user experience while driving incremental revenue. The purpose of recommender systems is to tempt/persuade customer to buy a product/service by providing relevant information that interest to them right at their fingretips.
#
# Recommendations typically speed up searches and make it easier for users to access content they’re interested in, and surprise them with offers they would have never searched for.
#
# What is more, companies are able to gain and retain customers by sending out emails with links to new offers that meet the recipients’ interests, or suggestions of films and TV shows that suit their profiles.The user starts to feel known and understood and is more likely to buy additional products or consume more content. By knowing what a user wants, the company gains competitive advantage and the threat of losing a customer to a competitor decreases.
#
# Providing that added value to users by including recommendations in systems and products is appealing. Furthermore, it allows companies to position ahead of their competitors and eventually increase their earnings.
#
# Various types of recommendations systems are depcited in below diagram.<br><br>
#
#   <div class="image1" align="center">
#   <img src="https://d1m75rqqgidzqn.cloudfront.net/wp-data/2019/11/19121357/types-of-recommendation-systember.jpg" width="400" height="300" alt="Screen 1"/>
#     <a href="https://d1m75rqqgidzqn.cloudfront.net/wp-data/2019/11/19121357/types-of-recommendation-systember.jpg">
#         Image Source </a>
#   </div>
#
#
# For this assignment we will focus on user based and item based system which are based on nearest neighbour.

# %% [markdown]
# # Business Understanding
#
# Recommender systems are a powerful technology for extracting additional value for a business from its user databases. These systems help users find items they want to buy from a business. Recommender systems benefit users by enabling them to find items they like. Conversely, they help the business by generating more sales. Recommender systems are rapidly becoming a crucial tool in E-commerce on the Web. Recommender systems are being stressed by the huge volume of user data in existing corporate databases, and will be stressed even more by the increasing volume of user data available on the Web. New technologies are needed that can dramatically improve the scalability of recommender systems.
#
# ## Our Approach:
#
# In this notebook we aim to build movie recommendations system using Apple's <a href="https://apple.github.io/turicreate/docs/userguide/recommender/"> Turicreate </a> package.The system that we are going to build will go a but deeper than traditional grouplens movie ratings dataset.In this notebook, we will be utilizing the popular movies dataset comprised of 26 million movie ratings from the GroupLens website, but with additional augmented data from TMDB which provides details including more detailed movie metadata such as: cast, crew, budget, country, revenue, languages and plot keywords on approximately 45,000 movies released prior to August 2017.
#
# We will explore various methods for recommending movies to users based on content based and collaborative filtering methods. <b> Because movie taste is highly subjective, it may prove difficult to measure the effectiveness of our algorithms, but we will capture Root Mean Square Errored (RMSE) to compare predicted vs actual ratings for items.</b> We will also look at precision and recall for per-user and per-item metrics, as well as calculating metrics in different ways such as by genre or country or origin.
#
# Here is general overview movie recommender system.
#
# In general recommendation systems consist of following components
#
# <b>1) Candidate generation </b><br><br>
#     Starts from potentially huge corpus to smaller subset of candidates. e.g Candidate generator in youtube reduces
#     billions of videos to hundred or thousands<br><br>
#
# Following table shows two common candidate generation approaches.
#
# <table>
#   <tr>
#     <th  style="text-align:center">Type </th>
#     <th  style="text-align:center" width="100px">Definition</th>
#     <th  style="text-align:center" width="100px">Example</th>
#   </tr>
#   <tr>
#     <td style="text-align:left" width="100px">content-based filtering</td>
#     <td style="text-align:left">Uses similarity between items to recommend items similar to what the user likes.</td>
#     <td style="text-align:left">If user A watches two cute cat videos, then the system can recommend cute animal videos to that user.</td>
#   </tr>
#   <tr>
#     <td style="text-align:left">collaborative filtering</td>
#     <td style="text-align:left">Uses similarities between queries and items simultaneously to provide recommendations</td>
#     <td style="text-align:left">If user A is similar to user B, and user B likes video 1, then the system can recommend video 1 to user A (even if user A hasn’t seen any videos similar to video 1).</td>
#   </tr>
# </table>
#
#
# <b> 2)  Scoring </b> <br> <br>
# Next, another model scores and ranks the candidates in order to select the set of items (on the order of 10) to display to the user. <br><br>
#
# <b>3) Re-Ranking</b><br><br>
# Finally, the system must take into account additional constraints for the final ranking. For example, the system removes items that the user explicitly disliked or boosts the score of fresher content. Re-ranking can also help ensure diversity, freshness, and fairness<br><br>
#
#
#
#
#
# <font size=4> <b> Content based filtering </b> </font>
#
# Content-based filtering uses item features (movie-metadata) to recommend other items similar to what the user likes, based on their previous actions or explicit feedback. Movie dataset that we have obtained contains only ratings as explicit feedback. There are no other user's action data available in this dataset.
#
# So this filter does not involve other users. It only recommends based on what particular user likes and recommends item with similar content. e.g If user A likes comedy and action movies and user B also likes comedy but never watched action movies,collborative filter will recommend action movies to user B based on common comedy movies and later it may turn out that User B also likes action movies and he gets more recommendations on this list.
#
# <table>
#     <tr>
#   <td style="background-color: transparent;">
#     <img src="https://github.com/sachinac/ML7331/blob/master/data/content_based_filter.png?raw=true" alt="Snow" style="height:30%;width:100%;text-align:left">
#       <div style="text-align:center"> Content-Based Filter </div>
#       <div style="text-align:center"> Image Source : Google Images </div>
#     </td>
#   <td style="background-color: none;">
#     <img src="https://github.com/sachinac/ML7331/blob/master/data/collaborative_filter.png?raw=true" alt="Forest" style="height:25%;width:60%;text-align:left">
#       <div style="text-align:center"> Collaborative Filter </div>
#       <div style="text-align:center"> Image Source : Google Images </div>
#   </td>
# </tr>
# </table>
#
#
# <font size=4> <b> Collaborative Filtering </b> </font>
#
# There are two types of collaborative filtering exist: <br>
#
# <b>User Based collaborative filtering </b><br>
#
# This type of filter is based on users’ ratings, and it will recommend movies that user hasn't watched yet, but users similar to us have, and like. To determine whether two users are similar or not, this filter considers the movies both of them watched and how they rated them. By looking at the items in common, this type of algorithm  predicts the rating of a movie for a user who hasn’t watched it yet, based on the similar users’ rating.
#
# One of the challenge for this type of filter to work accurately is that it requires user's ratings and in real sense not all users rate the movie they watched.Some of them never rate movie. That poses challege to build effective recommender.
#
# <b> Item based collaborative filtering </b><br>
#
# This is another type of recommendation method which looks for similar items based on items users have already liked or consumed.Item-based collaborative filtering is a model-based algorithm for making recommendations. In the algorithm, the similarities between different items in the dataset are calculated by using one of a number of similarity measures, and then these similarity values are used to predict ratings for user-item pairs not present in the dataset.
#
# <b>Similarity Measures</b>
#
# There are a number of different mathematical formulations that can be used to calculate the similarity between two items. As can be seen in the formulae below, each formula includes terms summed over the set of common users U.
#
# Item-base collaborative filtering normally divided into two sub tasks:
#
# 1.Calculate similarity among the items:
#
# * Cosine-Based Similarity
# * Correlation-Based Similarity
# * Adjusted Cosine Similarity
# * 1-Jaccard distance
#
# 2.Calculation of Prediction:
# * Weighted Sum
# * Regression
#
# The difference between User-Based Collaborative Filtering and this method is that, in this case, we directly pre-calculate the similarity between the co-rated items, skipping K-neighborhood search
#
# <b> What is long tail ? </b>
#
# Typically, there are very popular items that users interact with a lot and others that they don’t, which comprise what is known as the <font size=4 color="blue">Long Tail</font>. Recommender systems usually work pretty well on popular items, although that’s probably not very interesting to users as they most likely already know about them. The items in the Long Tail are the most interesting ones, because they may not be considered by the user at all if they aren’t recommended.
#
# <img src="https://github.com/sachinac/ML7331/blob/master/data/long-tail.png?raw=true" alt="Snow" style="width:50%">
# <div style="text-align:center"> Image Source : <a href="https://tryolabs.com/blog/introduction-to-recommender-systems/"> Tryolab Article </a> </div>

# %% [markdown]
# # Data Understanding 1 - Description and Exploration
#
# ## Data source
#
# We have obtained dataset from <a href=https://www.kaggle.com/rounakbanik/the-movies-dataset>kaggle </a> These files contain metadata for all 45,000 movies listed in the Full MovieLens Dataset. The dataset consists of movies released on or before July 2017. Data points include cast, crew, plot keywords, budget, revenue, posters, release dates, languages, production companies, countries, TMDB vote counts and vote averages.
#
# This dataset also has files containing 26 million ratings from 270,000 users for all 45,000 movies. Ratings are on a scale of 1-5 and have been obtained from the official GroupLens website.

# %% [markdown]
# ## Data Description Summary

# %% [markdown]
# Here is brief Summary of movielens data:
#
# <table>
#   <tr>
#     <th  style="text-align:left">Filename </th>
#     <th  style="text-align:left" width="100px">Number of records</th>
#     <th  style="text-align:center" width="100px">Description</th>
#   </tr>
#   <tr>
#     <td style="text-align:left" width="100px">movies_metadata.csv</td>
#     <td style="text-align:left"> 45,467 </td>
#     <td style="text-align:left">The main Movies Metadata file. Contains information on 45,000 movies featured in the Full MovieLens dataset. Features include posters, backdrops, budget, revenue, release dates, languages, production countries and companies.
#       </td>
#   </tr>
#   <tr>
#     <td style="text-align:left" width="100px">keywords.csv</td>
#         <td style="text-align:left"> 46,420 </td>
#     <td style="text-align:left">Contains the movie plot keywords for our MovieLens movies. Available in the form of a stringified JSON Object.
#       </td>
#   </tr>
#   <tr>
#     <td style="text-align:left" width="100px">credits.csv</td>
#     <td style="text-align:left"> 45,504 </td>
#     <td style="text-align:left">Consists of Cast and Crew Information for all our movies. Available in the form of a stringified JSON Object.
#       </td>
#   </tr>
#   <tr>
#     <td style="text-align:left" width="100px">links.csv</td>
#     <td style="text-align:left"> 45,844 </td>
#     <td style="text-align:left">The file that contains the TMDB and IMDB IDs of all the movies featured in the Full MovieLens dataset.
#       </td>
#   </tr>
#   <tr>
#     <td style="text-align:left" width="100px">ratings.csv</td>
#     <td style="text-align:left"> 26,024,290 </td>
#     <td style="text-align:left">The file that contains the TMDB and IMDB IDs of all the movies featured in the Full MovieLens dataset.
#       </td>
#   </tr>
#   <tr>
#     <td style="text-align:left" width="100px">links_small.csv</td>
#     <td style="text-align:left"> 9000 </td>
#     <td style="text-align:left">Contains the TMDB and IMDB IDs of a small subset of 9,000 movies of the Full Dataset
#       </td>
#   </tr>
#   <tr>
#     <td style="text-align:left" width="100px">ratings_small.csv</td>
#     <td style="text-align:left"> 100,000 </td>
#     <td style="text-align:left"> The subset of 100,000 ratings from 700 users on 9,000 movies.</td>
#   </tr>
#
# </table>
#
# Due to its huge size we have uploaded this data to AWS S3 bucket as github requires paid subscription to store more than 100MB of data. This notebook downloads data from AWS S3 for processing as described in the next sections.

# %% [markdown]
# ## Download from AWS S3

# %% [markdown]
# ### Movie Data:
# Because the unzipped data is ~ 900mb, we've saved it in an AWS S3 bucket as a zip file.  We've added the movies data directory to our *.gitignore* file so it doesn't get picked up in github.  This chunk of code does the following:
# * Check if the movie directory exists, create it if not, skip the step if so.
# * Checks files in the directory against expected files, if not found, download the zip file from AWS, extracts and deletes the downloaded zip file, then cleans up created variables.

# %%
# %%time
movie_dir = './data/movies'
movie_zipfile = movie_dir + '/movies.zip'
expected_files = ['keywords.csv', 'credits.csv', 'ratings.csv', 'ratings_small.csv', 'links_small.csv', 'movies_metadata.csv', 'links.csv']
movie_data = 'https://ml7331.s3.us-east-2.amazonaws.com/3405_6663_bundle_archive.zip'

# If movie directory doesn't exist, create it
if not os.path.isdir(movie_dir):
    print('creating directory:', movie_dir)
    os.mkdir(movie_dir)

# If all expected files are not present, download a fresh copy of movie data:    
if not all(files in os.listdir(movie_dir) for files in expected_files):
    print('downloading files...')
    wget.download(movie_data, movie_zipfile)
    print('unzipping files...')
    with zipfile.ZipFile(movie_zipfile, 'r') as zip_ref:
        zip_ref.extractall(movie_dir)
    os.remove(movie_zipfile)
    
del movie_data, movie_zipfile, movie_dir, expected_files
print('Movie files are present!', timebreak)
# Out:
# Movie files are present!
#
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 806 µs, sys: 75 µs, total: 881 µs
# Wall time: 498 µs

# %% [markdown]
# ### Model Data:
# To save time, we've saved all trained models in an AWS S3 bucket as a zip file.  We've added the models data directory to our *.gitignore* file so it doesn't get picked up in github.  This chunk of code does the same as the above chunk, except for models:
# * Check if the directory exists, create it if not, skip the step if so.
# * Checks files in the directory against expected files, if not found, download the zip file from AWS, extracts and deletes the downloaded zip file, then cleans up created variables.

# %%
# %%time
model_dir = './models'
expected_models = ['user_prefs_min_plus',
     'base_model',
     'base_model_rr01',
     'base_model_rr05',
     'user_prefs_large',
     'base_model_rr05_nsne16',
     'user_prefs_min',
     'base_model_rr0',
     'item_item_m',
     'base_model_rr05_nsne8']
model_data = 'https://ml7331.s3.us-east-2.amazonaws.com/models.zip'
model_zipfile = model_dir + '/models.zip'

# If directory doesn't exist, create it
if not os.path.isdir(model_dir):
    print('creating directory:', model_dir)
    os.mkdir(model_dir)

# If all expected files are not present, download a fresh copy of data:    
if not all(files in os.listdir(model_dir) for files in expected_models):
    print('downloading files...')
    wget.download(model_data, model_zipfile)
    print('unzipping files...')
    with zipfile.ZipFile(model_zipfile, 'r') as zip_ref:
        zip_ref.extractall(model_dir)
    os.remove(model_zipfile)
    
del model_data, model_zipfile, model_dir, expected_models
print('Models are present!', timebreak)
# Out:
# Models are present!
#
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 531 µs, sys: 20 µs, total: 551 µs
# Wall time: 348 µs

# %%
os.listdir('./models')
# Out:
# ['user_prefs_min_plus',
#  'base_model',
#  'base_model_rr01',
#  'base_model_rr05',
#  'user_prefs_large',
#  'base_model_rr05_nsne16',
#  'base_model_rr0_nsne8',
#  'user_prefs_min',
#  'base_model_rr0',
#  '.ipynb_checkpoints',
#  'item_item_m',
#  'base_model_rr05_nsne8']

# %% [markdown]
# ## Load Data
#
# Let's first load movide data into memory

# %%
# %%time

credits  = pd.read_csv('./data/movies/credits.csv')
keywords = pd.read_csv('./data/movies/keywords.csv')
movies   = pd.read_csv('./data/movies/movies_metadata.csv', low_memory=False)


links_small   = pd.read_csv('./data/movies/links_small.csv')
links         = pd.read_csv('./data/movies/links.csv')
ratings_small = pd.read_csv('./data/movies/ratings_small.csv')
ratings_full  = pd.read_csv('./data/movies/ratings.csv')
# Out:
# CPU times: user 4.75 s, sys: 589 ms, total: 5.33 s
# Wall time: 5.34 s

# %% [markdown]
# <font size="3"> <b>Set up ratings dataset for model building, plots and analysis</b></font>

# %%
ratings = ratings_full.copy()

# %% [markdown]
# ## Get the glimpse of the data
#
# Here we will see structure of the data and first 5 records from each data file to get glimpse of the data.
# Few fields are of type json and these fields needs to be processed in order to use these fields in model building process. In pandas these fields are stored as normal object so viewing first 5 record we can see contents of each data field to take appropriate actions that may be required for preprocessing.

# %% [markdown]
# ### Credits

# %% [markdown]
# As we can see below cast and crew fields are looking like dictonary. These are json type.

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %% [markdown]
# ### Keywords
#
# Keywords field is of type dict/json

# %%
keywords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46419 entries, 0 to 46418
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        46419 non-null  int64
#  1   keywords  46419 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 725.4+ KB

# %%
keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %% [markdown]
# ### Movies Metadata
#
# Movies metadata following fields are dictionary/json :<br>
# * belongs_to_collection
# * genres
# * production_companies
# * production_countries
# * spoken_languages

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Movie ratings
#
# These are user interactions. It contains ratings given by user for the movie they watched.

# %%
ratings_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
ratings_full.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %% [markdown]
# ### Links
#
# Contains the TMDB and IMDB IDs of a small subset of 9,000 movies of the Full Datas.

# %%
links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45843 entries, 0 to 45842
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  45843 non-null  int64
#  1   imdbId   45843 non-null  int64
#  2   tmdbId   45624 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.0 MB

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# ## Data Preprocessing
#
# Programatically Identify duplicate records and eliminate them, transform json datatypes and creation of new features as described in below sections.

# %% [markdown]
# ### Movie Credits
#
# The credits dataset (found in /data/credits.csv) has a movie id column and provides two JSON objects stored as a string representing the crew and cast.  It uses single quotes for strings, except in cases where a single quote is used, these strings are wrapped in double quotes.  Well formed JSON expects strings to be wrapped in double quotes, so we'll write a little helper function using the *literal_eval* function from the Abstract Syntax Trees package.
#
# After parsing them as literal into a list object, we can pick out **directors, producers and actors**, which we think will be most important in influencing recommendations.  We'll save these as list objects which we can then merge into our movies dataset.
#
# We also discovered 44 duplicate entries in this file, which from a sample of random selections appear to be true duplicates and will be safely removed.

# %%
# %%time

#credits = pd.read_csv('./data/movies/credits.csv')


# Drop rows where both cast and crew are empty
credits = credits[~((credits['cast'].str.contains('\[\]')) & (credits['crew'].str.contains('\[\]')))]

def dedupe(df):
    dupes = len(df[df.duplicated(subset=['id'])])
    print('Removed', dupes, 'duplicate rows.\n')
    return df[~df.duplicated(subset=['id'])]

# Remove duplicates:
credits = dedupe(credits)

def get_credits(crew_json):
    crew = ast.literal_eval(crew_json.crew)
    cast = ast.literal_eval(crew_json.cast)
    directors = []
    producers = []
    actors = []
    for member in crew:
#        if member is np.nan:
#            member = '[]'
        if 'Director' in member['job'] and member['job'] is not np.nan:
            directors.append(member['name'])
        if 'Producer' in member['job'] and member['job'] is not np.nan:
            producers.append(member['name'])
    for actor in cast:
#        if actor is np.nan:
#            actor = '[]'
        if actor['name'] is not np.nan:
            actors.append(actor['name'])

    return  pd.Series([directors, producers, actors])

credits[['directors','producers','actors']] = credits.apply(get_credits, axis=1)

print(credits.info(),timebreak)

credits.head()
# Out:
# Removed 44 duplicate rows.
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45011 entries, 0 to 45475
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cast       45011 non-null  object
#  1   crew       45011 non-null  object
#  2   id         45011 non-null  int64
#  3   directors  45011 non-null  object
#  4   producers  45011 non-null  object
#  5   actors     45011 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 2.4+ MB
# None
#
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 36.9 s, sys: 99.3 ms, total: 37 s
# Wall time: 37.1 s
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                            directors  \
# 0  [John Lasseter, Ash Brannon, William Reeves, R...
# 1                 [Joe Johnston, Thomas E. Ackerman]
# 2                                    [Howard Deutch]
# 3                                  [Forest Whitaker]
# 4                      [Elliot Davis, Charles Shyer]
#
#                                            producers  \
# 0  [Bonnie Arnold, Ed Catmull, Ralph Guggenheim, ...
# 1  [Larry J. Franco, Scott Kroopf, Ted Field, Rob...
# 2                                                 []
# 3  [Ronald Bass, Ezra Swerdlow, Deborah Schindler...
# 4                                     [Nancy Meyers]
#
#                                               actors
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...

# %% [markdown]
# ### Movie Keywords
#
# The keywords dataset (found in /data/keywords.csv) has a movie id column and again provides a JSON object stored as a string representing keywords which apply to each movie.  It uses single quotes for strings, except in cases where a single quote is used, these strings are wrapped in double quotes.  Well formed JSON expects strings to be wrapped in double quotes, so we'll utilize another helper function using the *literal_eval* function from the Abstract Syntax Trees package.
#
# After parsing them as literal into a list object, and removing empty list objects, we'll save these **plot keywords** as list object which we can merge into our movies dataset.
#
# There are 532 duplicate entries in this file which from a sample of random selections, again appear to be true duplicates and will be safely removed.

# %%
# %%time

#keywords = pd.read_csv('./data/movies/keywords.csv')

# Remove empty entries:
keywords = keywords[~keywords['keywords'].str.contains('\[\]')]

# Remove duplicates:
keywords = dedupe(keywords)

keywords['keyword_json'] = keywords['keywords'] 

# Breakout json into a list of names
def get_keywords(keyword_list):
    if keyword_list is np.nan:
        return []
    kw = []
    klist = ast.literal_eval(keyword_list)
    for word in klist:
        kw.append(word['name'])
    return kw

keywords['keywords'] = keywords.keyword_json.apply(get_keywords)

print(keywords.info(),timebreak)

keywords.head()
# Out:
# Removed 532 duplicate rows.
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31092 entries, 0 to 46415
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            31092 non-null  int64
#  1   keywords      31092 non-null  object
#  2   keyword_json  31092 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 971.6+ KB
# None
#
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 1.29 s, sys: 0 ns, total: 1.29 s
# Wall time: 1.29 s
#       id                                           keywords  \
# 0    862  [jealousy, toy, boy, friendship, friends, riva...
# 1   8844  [board game, disappearance, based on children'...
# 2  15602  [fishing, best friend, duringcreditsstinger, o...
# 3  31357  [based on novel, interracial relationship, sin...
# 4  11862  [baby, midlife crisis, confidence, aging, daug...
#
#                                         keyword_json
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %% [markdown]
# ### Movie Metadata
#
#
#
# The movies dataset (found in /data/movies_metadata.csv) has a movie id column and provides a lot of usable and JSON objects storing various metadata about each movie.  This dataset also appears to contain approximately 30 duplicate records, and after examining a sample of random selections, they appear to be true duplicates and will be safely removed.
#
# In this section we'll accomplish the following:
# * There are three movies with improper ID values (1997-08-20,2012-09-29,2014-01-01), these items all appear to have incorrect formatting, so we'll drop these in order to merge the keyword and credits datasets and prevent future problems.
# * Merge directors, producers and actors from credits dataset
# * Merge keywords from keywords dataset
# * Clean up the movie collection by converting it to a string, as it appears to only contain one item per movie.
# * Convert the JSON genres object into a list of genres
# * Add new field num_of_years from release (derived from release date)
# * Change Data type of field "budget" and "popularity" from object to float64
# * Correct empty data fields introduced by left-joins (i.e. the movie data contains files without keywords, credits etc)

# %%
# %%time
def number_of_years(d1, d2):
    d1 = datetime.strptime(d1, "%Y-%m-%d")
    d2 = datetime.strptime(d2, "%Y-%m-%d")
    return round(abs((d2 - d1).days)/365.0,1)

today = datetime.today().strftime("%Y-%m-%d")

movies = pd.read_csv('./data/movies/movies_metadata.csv', low_memory=False)
print('Original Movies Shape: ', movies.shape, '\n')

# Remove the movies with erroneous data & convert ID to int:
movies = movies[~movies['id'].str.contains('-')]
movies['id'] = movies['id'].astype(int)

# Remove duplicates:
movies = dedupe(movies)

print('Movies Shape after dropping bad data: ', movies.shape, '\n')

# Add Keywords & Credits
movies = movies.merge(keywords, how='left', on='id')
print('Movies Shape after merging keywords: ', movies.shape, '\n')

movies = movies.merge(credits, how='left', on='id')
print('Movies Shape after merging credits: ', movies.shape, '\n')

movies = movies.drop(columns=['cast','crew','keyword_json'])

# Function to convert collection to a string
def get_collection(json):
    if pd.isnull(json):
        return 'N/A'
    else:
        return ast.literal_eval(json)['name']

movies['belongs_to_collection'] = movies.belongs_to_collection.apply(get_collection)

#preserve genres and spoken language dicts:
movies['genre_dict'] = movies['genres']
movies['spoken_languages_dict'] = movies['spoken_languages']

#We can re-use our get_keywords function here to get genres & spoken languages
movies['genres'] = movies.genres.apply(get_keywords)
movies['spoken_languages'] = movies.spoken_languages.apply(get_keywords)

#
#  We can check if a string is NaN by using the property of NaN object that a NaN != NaN.
#  y==y checks if given string is not an NaN. if NaN it will put undefined -1 
#
movies['number_of_years']  =  [ number_of_years(today,y) if y==y else -1 for y in movies['release_date']]

print(movies.info(),timebreak)
movies['budget']     = movies['budget'].astype('float64')
movies['popularity'] = movies['popularity'].astype('float64')

movies['keyword_list'] = movies['keywords']
movies['director_list'] = movies['directors']
movies['producer_list'] = movies['producers']
movies['actor_list'] = movies['actors']

movies['keywords'] = [[] if type(x) != list else x for x in movies['keywords']]
movies['directors'] = [[] if type(x) != list else x for x in movies['directors']]
movies['producers'] = [[] if type(x) != list else x for x in movies['producers']]
movies['actors'] = [[] if type(x) != list else x for x in movies['actors']]
movies['tagline'] = [' ' if type(x) != str else x for x in movies['tagline']]
movies['spoken_languages'] = [[] if type(x) != list else x for x in movies['spoken_languages']]
movies['original_language'] = [' ' if type(x) != str else x for x in movies['original_language']]

movies.head()
# Out:
# Original Movies Shape:  (45466, 24)
#
# Removed 30 duplicate rows.
#
# Movies Shape after dropping bad data:  (45433, 24)
#
# Movies Shape after merging keywords:  (45433, 26)
#
# Movies Shape after merging credits:  (45433, 31)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45433 entries, 0 to 45432
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45433 non-null  object
#  1   belongs_to_collection  45433 non-null  object
#  2   budget                 45433 non-null  object
#  3   genres                 45433 non-null  object
#  4   homepage               7774 non-null   object
#  5   id                     45433 non-null  int64
#  6   imdb_id                45416 non-null  object
#  7   original_language      45422 non-null  object
#  8   original_title         45433 non-null  object
#  9   overview               44479 non-null  object
#  10  popularity             45430 non-null  object
#  11  poster_path            45047 non-null  object
#  12  production_companies   45430 non-null  object
#  13  production_countries   45430 non-null  object
#  14  release_date           45346 non-null  object
#  15  revenue                45430 non-null  float64
#  16  runtime                45173 non-null  float64
#  17  spoken_languages       45433 non-null  object
#  18  status                 45349 non-null  object
#  19  tagline                20401 non-null  object
#  20  title                  45430 non-null  object
#  21  video                  45430 non-null  object
#  22  vote_average           45430 non-null  float64
#  23  vote_count             45430 non-null  float64
#  24  keywords               31092 non-null  object
#  25  directors              45011 non-null  object
#  26  producers              45011 non-null  object
#  27  actors                 45011 non-null  object
#  28  genre_dict             45433 non-null  object
#  29  spoken_languages_dict  45430 non-null  object
#  30  number_of_years        45433 non-null  float64
# dtypes: float64(5), int64(1), object(25)
# memory usage: 11.1+ MB
# None
#
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 3.15 s, sys: 49.8 ms, total: 3.2 s
# Wall time: 3.21 s
#    adult           belongs_to_collection      budget  \
# 0  False            Toy Story Collection  30000000.0
# 1  False                             N/A  65000000.0
# 2  False       Grumpy Old Men Collection         0.0
# 3  False                             N/A  16000000.0
# 4  False  Father of the Bride Collection         0.0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Cheated on, mistreated and stepped on, the wom...  ...
# 4  Just when George Banks has recovered from his ...  ...
#
#                                            directors  \
# 0  [John Lasseter, Ash Brannon, William Reeves, R...
# 1                 [Joe Johnston, Thomas E. Ackerman]
# 2                                    [Howard Deutch]
# 3                                  [Forest Whitaker]
# 4                      [Elliot Davis, Charles Shyer]
#
#                                            producers  \
# 0  [Bonnie Arnold, Ed Catmull, Ralph Guggenheim, ...
# 1  [Larry J. Franco, Scott Kroopf, Ted Field, Rob...
# 2                                                 []
# 3  [Ronald Bass, Ezra Swerdlow, Deborah Schindler...
# 4                                     [Nancy Meyers]
#
#                                               actors  \
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
#                                           genre_dict  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                spoken_languages_dict  number_of_years  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]             24.8
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...             24.7
# 2           [{'iso_639_1': 'en', 'name': 'English'}]             24.6
# 3           [{'iso_639_1': 'en', 'name': 'English'}]             24.6
# 4           [{'iso_639_1': 'en', 'name': 'English'}]             25.5
#
#                                         keyword_list  \
# 0  [jealousy, toy, boy, friendship, friends, riva...
# 1  [board game, disappearance, based on children'...
# 2  [fishing, best friend, duringcreditsstinger, o...
# 3  [based on novel, interracial relationship, sin...
# 4  [baby, midlife crisis, confidence, aging, daug...
#
#                                        director_list  \
# 0  [John Lasseter, Ash Brannon, William Reeves, R...
# 1                 [Joe Johnston, Thomas E. Ackerman]
# 2                                    [Howard Deutch]
# 3                                  [Forest Whitaker]
# 4                      [Elliot Davis, Charles Shyer]
#
#                                        producer_list  \
# 0  [Bonnie Arnold, Ed Catmull, Ralph Guggenheim, ...
# 1  [Larry J. Franco, Scott Kroopf, Ted Field, Rob...
# 2                                                 []
# 3  [Ronald Bass, Ezra Swerdlow, Deborah Schindler...
# 4                                     [Nancy Meyers]
#
#                                           actor_list
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Movie Ratings
#
# The ratings dataset consists of approximately **270,000 annonomous userIds, 45,000 movieIds that we can link to our movies dataset, and 2.6 million user ratings** on a scale from **0.5 - 5.0** (worst to best), and a timestamp for when the rating was collected. A cursory glance through the data shows there are no duplicate ratings for user/movie combinations, saving us the work of averaging the scores! Clean data FTW!
#
# *ratings_small* is a subset of the ratings dataset available in the Full MovieLens dataset and contains about **100,000 ratings from 671 users on 9,066 movies**.

# %%
#ratings_small = pd.read_csv('./data/movies/ratings_small.csv')
ratings_small.info()
print('\nCount of duplicate ratings for a user/movie:',len(ratings_small[ratings_small.duplicated(subset=['userId','movieId'])]))
print('\nNumber of unique movies:',len(ratings_small.movieId.unique()))
print('\nNumber of unique users:',len(ratings_small.userId.unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100004 non-null  int64
#  1   movieId    100004 non-null  int64
#  2   rating     100004 non-null  float64
#  3   timestamp  100004 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB
#
# Count of duplicate ratings for a user/movie: 0
#
# Number of unique movies: 9066
#
# Number of unique users: 671

# %%
#ratings = pd.read_csv('./data/movies/ratings.csv')
ratings_full.info()
print('\nCount of duplicate ratings for a user/movie:',len(ratings_full[ratings_full.duplicated(subset=['userId','movieId'])]))
print('\nNumber of unique movies:',len(ratings_full.movieId.unique()))
print('\nNumber of unique users:',len(ratings_full.userId.unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB
#
# Count of duplicate ratings for a user/movie: 0
#
# Number of unique movies: 45115
#
# Number of unique users: 270896

# %% [markdown]
# ## Descriptive Statistics Summary
#
# Below we will use processed data to see how Mean,Median,Mode and other stats looks like post processing using describe or head functions.

# %% [markdown]
# ### Credits/Keyword Stats Summary

# %% [markdown]
# Credits and Keywords set doesn't have categorical or numerical data. All fields are lists which can be used as additional information or side information during model building process. Turicreate internally creates Vector Embeddings to use them to find similarity between users/movies.
#
# Cast Crew and keyword if absent in the data, we don't need to remove these rows, even if lists producers column is absent, other columns does contain important information for that particular record. So we are not deleting any records. Those missing will be handled by Turicreate internally.

# %%
keywords.head()
# Out:
#       id                                           keywords  \
# 0    862  [jealousy, toy, boy, friendship, friends, riva...
# 1   8844  [board game, disappearance, based on children'...
# 2  15602  [fishing, best friend, duringcreditsstinger, o...
# 3  31357  [based on novel, interracial relationship, sin...
# 4  11862  [baby, midlife crisis, confidence, aging, daug...
#
#                                         keyword_json
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                            directors  \
# 0  [John Lasseter, Ash Brannon, William Reeves, R...
# 1                 [Joe Johnston, Thomas E. Ackerman]
# 2                                    [Howard Deutch]
# 3                                  [Forest Whitaker]
# 4                      [Elliot Davis, Charles Shyer]
#
#                                            producers  \
# 0  [Bonnie Arnold, Ed Catmull, Ralph Guggenheim, ...
# 1  [Larry J. Franco, Scott Kroopf, Ted Field, Rob...
# 2                                                 []
# 3  [Ronald Bass, Ezra Swerdlow, Deborah Schindler...
# 4                                     [Nancy Meyers]
#
#                                               actors
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...

# %% [markdown]
# ### Ratings Stats Summary
# Ratings file contains only rating column on which we can take summary. We don't need to take summary on userId and movieId as these are ID columns.
#
# <font size=4> <b> outliers </b> </font><br><br>
# As we can see from the boxplot there are few observation beyond whiskers. We observed that at least 10%-15% of movies have been rated below 2.0 which is quite possible. Therefore these observations doesn't seem invalid and will be kept as it is for modelling purpose.

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ax = sns.boxplot(data=ratings['rating'],showmeans=True)

# %% [markdown]
# ### Movies MetaData Stats Summary

# %% [markdown]
# Movies dataset has following numberic fields:<br>
#
# * budget
# * popularity
# * revenue
# * runtime
# * vote_average
# * vote_count
# * number_of_years (New derived field from release date)
#
# All other fields are either ID fields or list/dictionaries, So for now we don't need to look at those to check outliers.
#
# First of all check if any of the records has NaN. We need to remove these records as model will fail due to NaN. We don't know why these numbers are missing, We don't prefer imputing here as count is small compared to 45K movies, only 260 are seems to NaN. Therefore we will remove these records.

# %% [markdown]
# <font size="3"> <b> Remove NaNs </b> </font> <br>
# Here is count NaN rows that needs to be deleted. We don't see any suspcious outlier in these fields and therefore we will keep records as it is after removing NaNs

# %%
print('Shape Before',movies.shape)

print(movies.loc[:,['budget','title','popularity','revenue',
                    'number_of_years','runtime','vote_average','vote_count'] ].isnull().sum())

#movies[movies.loc[:,['budget','title','popularity',
#                                                                      'revenue','number_of_years','runtime',
#                                                                      'vote_average','vote_count'] ].isna().any(axis=1)]

movies_final= movies.dropna(subset=['budget','title','popularity','revenue',
                      'number_of_years','runtime','vote_average','vote_count']).copy()
print('Shape After',movies_final.shape)
print('\n')
print('Total Deleted',movies.shape[0]-movies_final.shape[0])
# Out:
# Shape Before (45433, 35)
# budget               0
# title                3
# popularity           3
# revenue              3
# number_of_years      0
# runtime            260
# vote_average         3
# vote_count           3
# dtype: int64
# Shape After (45173, 35)
#
#
# Total Deleted 260

# %%
movies_final.sort_values(by=['popularity'],ascending=False).head(10).loc[:,['budget','title','popularity',
                                                                     'revenue','number_of_years','runtime',
                                                                      'vote_average','vote_count' ]]
# Out:
#             budget                           title  popularity       revenue  \
# 30677   74000000.0                         Minions  547.488298  1.156731e+09
# 33333  149000000.0                    Wonder Woman  294.337037  8.205804e+08
# 42192  160000000.0            Beauty and the Beast  287.253654  1.262886e+09
# 43614   34000000.0                     Baby Driver  228.032744  2.245113e+08
# 24438  165000000.0                      Big Hero 6  213.849907  6.521054e+08
# 26546   58000000.0                        Deadpool  187.860492  7.831130e+08
# 26548  200000000.0  Guardians of the Galaxy Vol. 2  185.330992  8.634161e+08
# 14546  237000000.0                          Avatar  185.070892  2.787965e+09
# 24334   20000000.0                       John Wick  183.870374  8.876166e+07
# 23658   61000000.0                       Gone Girl  154.801009  3.693304e+08
#
#        number_of_years  runtime  vote_average  vote_count
# 30677              5.2     91.0           6.4      4729.0
# 33333              3.2    141.0           7.2      5025.0
# 42192              3.4    129.0           6.8      5530.0
# 43614              3.1    113.0           7.2      2083.0
# 24438              5.8    102.0           7.8      6289.0
# 26546              4.5    108.0           7.4     11444.0
# 26548              3.3    137.0           7.6      4858.0
# 14546             10.7    162.0           7.2     12114.0
# 24334              5.8    101.0           7.0      5499.0
# 23658              5.9    145.0           7.9      6023.0

# %%
movies_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45173 entries, 0 to 45432
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45173 non-null  object
#  1   belongs_to_collection  45173 non-null  object
#  2   budget                 45173 non-null  float64
#  3   genres                 45173 non-null  object
#  4   homepage               7773 non-null   object
#  5   id                     45173 non-null  int64
#  6   imdb_id                45158 non-null  object
#  7   original_language      45173 non-null  object
#  8   original_title         45173 non-null  object
#  9   overview               44476 non-null  object
#  10  popularity             45173 non-null  float64
#  11  poster_path            44814 non-null  object
#  12  production_companies   45173 non-null  object
#  13  production_countries   45173 non-null  object
#  14  release_date           45100 non-null  object
#  15  revenue                45173 non-null  float64
#  16  runtime                45173 non-null  float64
#  17  spoken_languages       45173 non-null  object
#  18  status                 45096 non-null  object
#  19  tagline                45173 non-null  object
#  20  title                  45173 non-null  object
#  21  video                  45173 non-null  object
#  22  vote_average           45173 non-null  float64
#  23  vote_count             45173 non-null  float64
#  24  keywords               45173 non-null  object
#  25  directors              45173 non-null  object
#  26  producers              45173 non-null  object
#  27  actors                 45173 non-null  object
#  28  genre_dict             45173 non-null  object
#  29  spoken_languages_dict  45173 non-null  object
#  30  number_of_years        45173 non-null  float64
#  31  keyword_list           31046 non-null  object
#  32  director_list          44772 non-null  object
#  33  producer_list          44772 non-null  object
#  34  actor_list             44772 non-null  object
# dtypes: float64(7), int64(1), object(27)
# memory usage: 12.4+ MB

# %%
fig, ax =plt.subplots(1,4, constrained_layout=True,figsize=(15,5))

ax[0].set(xlabel='budget')
sns.boxplot(data = movies_final['budget']    ,ax=ax[0])
ax[1].set(xlabel='popularity')
sns.boxplot(data = movies_final['popularity'],ax=ax[1])
ax[2].set(xlabel='revenue')
sns.boxplot(data = movies_final['revenue']   ,ax=ax[2])
ax[3].set(xlabel='runtime')
sns.boxplot(data = movies_final['runtime']   ,ax=ax[3])


fig, ax =plt.subplots(1,3, constrained_layout=True,figsize=(15,5))
ax[0].set(xlabel='vote_average')
sns.boxplot(data = movies_final['vote_average']    ,ax=ax[0])
ax[1].set(xlabel='vote_count')
sns.boxplot(data = movies_final['vote_count']      ,ax=ax[1])
ax[2].set(xlabel='number_of_years')
sns.boxplot(data = movies_final['number_of_years'] ,ax=ax[2])

# %% [markdown]
# *We do see outliers. But this is expected as few movies are very popular with very high budget compared to others therefore we won't take any actions on the remaining dataset*

# %% [markdown]
# # Data Understanding 2 - Data Visualization

# %% [markdown]
# ### Distribution of Movie Popularity

# %% [markdown]
# Long tail does exist as expected. Few movies are very popular and mostly watched and rated while many are rarely watched or never watched or rated by users.

# %%
# %matplotlib inline
fig, ax =plt.subplots(1,2, constrained_layout=True,figsize=(15,5))
x_range = range(movies_final['popularity'].shape[0])
ax[0].set(xlabel='Movies')
sns.lineplot(x = x_range, y = movies_final.popularity.sort_values(ascending=False),ax=ax[0])
sns.distplot(movies_final['popularity'],ax=ax[1])
plt.show()

# %% [markdown]
# ### Distribution of Movie Ratings

# %% [markdown]
# Plotting the rating distribution shows some bias towards higher ratings, this could be due to users feeling more passionately about a great movie than a mediocre one, or that users are more likely to seek out, view and subsequently rate high-rated movies.

# %%
# Ratings Histogram:
plt.figure(figsize=(16, 5))
sns.set_style("dark")
ax = sns.countplot(x="rating", data=ratings)
total = float(len(ratings))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2,
            height + 3,
            '{0:.1%}'.format(height/total),
            ha="center") 
ax.set_ylabel("Count of Movies")
ax.set_xlabel("Movie Rating")
ax.set_title("Distribution of Movie Ratings")
plt.show()

# %% [markdown]
# ### Distribution of Movie Genres

# %% [markdown]
# Examining the distribution of movie genre could be useful if we decide to get more sophisticated with our recommendation engine, if we branch out of user preferences (or if we're recommending to a new user), we might try to keep the movie recommendations in line with the overall genre distribution.

# %%
plt.figure(figsize=(14, 7))
mlb = MultiLabelBinarizer()
genre_count = pd.DataFrame(mlb.fit_transform(movies['genres']),columns=mlb.classes_).sum()

ax = sns.barplot(genre_count.index,genre_count.values)
ax.set_xlabel("Movie Count")
ax.set_title("Distribution of Movie Genres")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
plt.show()

# %% [markdown]
# ### Distribution of vote average

# %% [markdown]
# The distribution of votes on each movie indicates that more users are willing to rate movies at a 0 than a 10, and the distribution is slightly left skewed, indicating users may be more likely to rate movies using the higher end of the scale.

# %%
plt.figure(figsize=(14, 7))
ax = sns.distplot(movies['vote_average'])
ax.set_ylabel("")
ax.set_yticks([])
plt.rcParams["axes.labelsize"] = 135
ax.set_title("Distribution of Movie Vote Average")
plt.show()

# %% [markdown]
# ### Word cloud - Common Keywords

# %% [markdown]
# Below is a word cloud for the common keywords found in the movies dataset.

# %%
# Code adapted from: https://github.com/amueller/word_cloud/blob/master/examples/simple.py
l = keywords['keywords'].values.tolist()

text = []
for sublist in l:
    for item in sublist:
        text.append(item)
        
text = ' '.join(text)

wordcloud = WordCloud(max_font_size=30).generate(text)
plt.figure(figsize=(15,5))
plt.imshow(wordcloud, interpolation="bilinear")

plt.axis("off")
plt.show()

# %% [markdown]
# ### Top 10 Stats:
# Below we'll list several top 10 statistics for movies.  For the most part, the stats will be the top 10 "blank" having the most movies.  The only exception to this is the top 10 movies by vote count.  The ordering is as follows:
# * Actors with the most movies
# * Genres with the most movies
# * Directors with the most movies
# * Producers with the most movies
# * Collections with the most movies
# * Original Languages with the most movies
# * Spoken Languages with the most movies
# * Highest rated movies by TMDB user votes (movies must have at least 1,000 votes)

# %%
def get_top10_list(column, plot=True):
    mlb = MultiLabelBinarizer()
    if type(movies_final[column][0]) == list:
        top10 = pd.DataFrame(mlb.fit_transform(movies_final[movies_final[column].str.len() > 0][column]),columns=mlb.classes_).sum().nlargest(n=10)
    else:
        top10 = movies_final[(movies_final[column].str.len() > 0) & (movies_final[column] != 'N/A')][column].value_counts().nlargest(10)
    ax = sns.barplot(top10.values, top10.index)
    ax.set_xlabel("Movie Count")
    plt.rcParams["axes.labelsize"] = 15
    ax.set_title("Top 10 {} by Movie Count".format(column.capitalize()))
    total = float(len(movies_final))
    for p in ax.patches:
            percentage = '{:.1f}%'.format(100 * p.get_width()/total)
            x = p.get_x() + p.get_width() + 0.02
            y = p.get_y() + p.get_height()/1.5
            ax.annotate(percentage, (x, y))
    if plot:
        return plt.show()
    plt.close()
    return top10

# %% [markdown]
# ### Top 10 Popular Movies

# %%
movies_final.sort_values(by=['popularity'],ascending=False).head(10).loc[:,['budget','title','popularity',
                                                                     'revenue','number_of_years','runtime',
                                                                      'vote_average','vote_count' ]]
# Out:
#             budget                           title  popularity       revenue  \
# 30677   74000000.0                         Minions  547.488298  1.156731e+09
# 33333  149000000.0                    Wonder Woman  294.337037  8.205804e+08
# 42192  160000000.0            Beauty and the Beast  287.253654  1.262886e+09
# 43614   34000000.0                     Baby Driver  228.032744  2.245113e+08
# 24438  165000000.0                      Big Hero 6  213.849907  6.521054e+08
# 26546   58000000.0                        Deadpool  187.860492  7.831130e+08
# 26548  200000000.0  Guardians of the Galaxy Vol. 2  185.330992  8.634161e+08
# 14546  237000000.0                          Avatar  185.070892  2.787965e+09
# 24334   20000000.0                       John Wick  183.870374  8.876166e+07
# 23658   61000000.0                       Gone Girl  154.801009  3.693304e+08
#
#        number_of_years  runtime  vote_average  vote_count
# 30677              5.2     91.0           6.4      4729.0
# 33333              3.2    141.0           7.2      5025.0
# 42192              3.4    129.0           6.8      5530.0
# 43614              3.1    113.0           7.2      2083.0
# 24438              5.8    102.0           7.8      6289.0
# 26546              4.5    108.0           7.4     11444.0
# 26548              3.3    137.0           7.6      4858.0
# 14546             10.7    162.0           7.2     12114.0
# 24334              5.8    101.0           7.0      5499.0
# 23658              5.9    145.0           7.9      6023.0

# %% [markdown]
# ### Top 10 High Budget Movies

# %%
movies_final.sort_values(by=['budget'],ascending=False).head(10).loc[:,['budget','title','popularity',
                                                                     'revenue','number_of_years','runtime',
                                                                      'vote_average','vote_count' ]]
# Out:
#             budget                                        title  popularity  \
# 17116  380000000.0  Pirates of the Caribbean: On Stranger Tides   27.887720
# 11824  300000000.0     Pirates of the Caribbean: At World's End   31.363664
# 26540  280000000.0                      Avengers: Age of Ultron   37.379420
# 11064  270000000.0                             Superman Returns   13.284712
# 16123  260000000.0                                      Tangled   14.684761
# 18677  260000000.0                                  John Carter   14.670353
# 44810  260000000.0                Transformers: The Last Knight   39.186819
# 11777  258000000.0                                 Spider-Man 3   27.614265
# 21162  255000000.0                              The Lone Ranger   12.729104
# 31049  250000000.0           Batman v Superman: Dawn of Justice   31.435879
#
#             revenue  number_of_years  runtime  vote_average  vote_count
# 17116  1.045714e+09              9.2    136.0           6.4      5068.0
# 11824  9.610000e+08             13.2    169.0           6.9      4627.0
# 26540  1.405404e+09              5.3    141.0           7.3      6908.0
# 11064  3.910812e+08             14.1    154.0           5.4      1429.0
# 16123  5.917949e+08              9.7    100.0           7.4      3419.0
# 18677  2.841391e+08              8.4    132.0           6.1      2170.0
# 44810  6.049421e+08              3.1    149.0           6.2      1440.0
# 11777  8.908716e+08             13.3    139.0           5.9      3687.0
# 21162  8.928991e+07              7.1    149.0           5.9      2361.0
# 31049  8.732602e+08              4.4    151.0           5.7      7189.0

# %% [markdown]
# ### Top 10 actors

# %%
sns.set_style('dark')
get_top10_list('actors')

# %% [markdown]
# ### Top 10 Genres

# %%
get_top10_list('genres')

# %% [markdown]
# ### Top 10 Directors

# %%
get_top10_list('directors')

# %% [markdown]
# ### Top 10 Producers

# %%
get_top10_list('producers')

# %% [markdown]
# ### Top 10 Collections

# %%
get_top10_list('belongs_to_collection')

# %% [markdown]
# ### Top 10 Original languages

# %%
get_top10_list('original_language')

# %% [markdown]
# ### Top 10 Spoken Languages

# %%
print('Top 10 Spoken Languages by Movie Count')
pd.DataFrame(get_top10_list('spoken_languages', plot=False), columns=['Movie Count'])
# Out:
# Top 10 Spoken Languages by Movie Count
#            Movie Count
# English          28717
# Français          4173
# Deutsch           2590
# Español           2393
# Italiano          2338
# 日本語               1756
# Pусский           1554
# 普通话                790
# हिन्दी             706
# Português          586

# %% [markdown]
# ### Top 10 Movies by vote_count

# %%
movies[movies['vote_count'] > 999].nlargest(10, 'vote_average')[['title','vote_average','vote_count']]
# Out:
#                                  title  vote_average  vote_count
# 314           The Shawshank Redemption           8.5      8358.0
# 834                      The Godfather           8.5      6024.0
# 40222                       Your Name.           8.5      1030.0
# 292                       Pulp Fiction           8.3      8670.0
# 522                   Schindler's List           8.3      4436.0
# 1152   One Flew Over the Cuckoo's Nest           8.3      3001.0
# 1176                            Psycho           8.3      2405.0
# 1178            The Godfather: Part II           8.3      3418.0
# 1184       Once Upon a Time in America           8.3      1104.0
# 2210                 Life Is Beautiful           8.3      3643.0

# %% [markdown]
# # Modeling and Evaluation 1 - Model Training and Hypertuning

# %% [markdown]
# ## Set GPU for Recommendation System
# Turicreate supports only one GPU. So we will set just 1 GPU.

# %%
tc.config.set_num_gpus(1)

# %% [markdown]
# ## Train Test Split

# %% [markdown]
# <i>The Turi Create recommender toolkit provides several ways of working with rating data while ensuring good precision-recall. To accurately evaluate the precision-recall of a model trained on explicit rating data, it's important to only include highly rated items in your test set as these are the items a user would likely choose. Creating such a test set can be done with a handful of SFrame operations and tc.recommender.random_split_by_user:</i> <br><br>- Apple Turi Documentation

# %%
# %%time
data = tc.SFrame(data=ratings)

high_rated_data = data[data["rating"] >= 4]
low_rated_data = data[data["rating"] < 4]
train_data_1, test_data = tc.recommender.util.random_split_by_user(
                                    high_rated_data, user_id='userId', item_id='movieId')
train_data = train_data_1.append(low_rated_data)
print('Training Set Size ',train_data.shape)
print('Test Set Size ',test_data.shape)
# Out:
# Training Set Size  (26014582, 4)
# Test Set Size  (9707, 4)
# CPU times: user 25.9 s, sys: 1.38 s, total: 27.3 s
# Wall time: 6.57 s

# %% [markdown]
# ## Supporting functions

# %% [markdown]
# To help sort out our performance between precision and recall, we've added an F1 score indicator defined above.  We're using Turi's evaluate function that we pass to a get_metrics helper function, which aggregates the average precision and recall, then calculates F1 score using these two metrics and concatenates the top 5 scores for each model, which we will incorporate into tables and our plots to compare models.

# %%
def get_metrics(model_eval, model_name):
    agg_list = [
        tc.aggregate.AVG('precision'),
        tc.aggregate.STD('precision'),
        tc.aggregate.AVG('recall'),
        tc.aggregate.STD('recall')
    ]
    base_metrics = pd.DataFrame(model_eval['precision_recall_by_user'].groupby('cutoff',agg_list))
    rmse = model_eval['rmse_overall']
    #F1 calculation from: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
    p = base_metrics['Avg of precision']
    r = base_metrics['Avg of recall']
    base_metrics['F1'] = 2*(p*r)/(p+r)
    base_metrics['Model'] = model_name
    base_metrics['RMSE'] = model_eval['rmse_overall']
    return base_metrics.sort_values('F1', ascending=False).nlargest(5,'F1')

# %% [markdown]
# <b>Collaborative filtering</b> is a technique that can filter out items that a user might like on the basis of reactions by similar users. It works by searching a large group of people and finding a smaller set of users with tastes similar to a particular user.It looks at the items they like and combines them to create a ranked list of suggestions. There are many ways to decide which users are similar and combine their choices to create a list of recommendations.
# There are two types of collaborative filters <br>
# 1. User Based collaborative filtering <br>
# 2. Item based collaborative filtering <br>

# %% [markdown]
# ## Item-Item collaborative model
#
# Item-Item collaborative method is type of recommendation method which looks for similar items based on items users have already liked or consumed.Item-based collaborative filtering is a model-based algorithm for making recommendations. In the algorithm, the similarities between different items in the dataset are calculated by using one of a number of similarity measures, and then these similarity values are used to predict ratings for user-item pairs not present in the dataset.

# %%
# %%time
#
# Select side item data 
# keywords,directors,producers,actors,tagline,budget,number_of_years
#

movies_test = movies_final.copy()
movies_test = movies_test.rename(columns={"id": "movieId"})

movies_side_data = tc.SFrame(data=movies_test.loc[:,['movieId','genres','belongs_to_collection',
                                                     'keywords','tagline','producers','directors','budget',
                                                     'number_of_years']])
#
# Create item similarity model
#

#
# Load the saved model if it exists, otherwise create it:
#

try: 
    item_item_m = tc.load_model('./models/item_item_m')
except:
    item_item_m  = tc.item_similarity_recommender.create(train_data,
                               user_id='userId',target="rating",only_top_k=5,
                               item_id='movieId',item_data=movies_side_data,similarity_type="cosine")

    item_item_m.save("./models/item_item_m")

print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 1.01 s, sys: 41.7 ms, total: 1.05 s
# Wall time: 627 ms

# %% [markdown]
# ### Item-Item Model Summary

# %%
item_item_m
# Out:
# Class                            : ItemSimilarityRecommender
#
# Schema
# ------
# User ID                          : userId
# Item ID                          : movieId
# Target                           : rating
# Additional observation features  : 0
# User side features               : []
# Item side features               : ['movieId', 'genres', 'belongs_to_collection', 'keywords', 'tagline', 'producers', 'directors', 'budget', 'number_of_years']
#
# Statistics
# ----------
# Number of observations           : 26014582
# Number of users                  : 270890
# Number of items                  : 82742
#
# Training summary
# ----------------
# Training time                    : 35.5135
#
# Model Parameters
# ----------------
# Model class                      : ItemSimilarityRecommender
# threshold                        : 0.001
# similarity_type                  : cosine
# training_method                  : auto
#
# Other Settings
# --------------
# degree_approximation_threshold   : 4096
# max_data_passes                  : 4096
# max_item_neighborhood_size       : 5
# nearest_neighbors_interaction_proportion_threshold : 0.05
# seed_item_set_size               : 50
# sparse_density_estimation_sample_size : 4096
# target_memory_usage              : 8589934592

# %% [markdown]
# ### Recommendations from Item-Item Model

# %%
item_item_rec = item_item_m.recommend()
item_item_rec
# Out:
# recommendations finished on 1000/270890 queries. users per second: 4445.35
# recommendations finished on 2000/270890 queries. users per second: 4319.24
# recommendations finished on 3000/270890 queries. users per second: 4190.33
# recommendations finished on 4000/270890 queries. users per second: 4191.61
# recommendations finished on 5000/270890 queries. users per second: 4236.33
# recommendations finished on 6000/270890 queries. users per second: 4295.12
# recommendations finished on 7000/270890 queries. users per second: 4315.43
# recommendations finished on 8000/270890 queries. users per second: 4341.34
# recommendations finished on 9000/270890 queries. users per second: 4328.78
# recommendations finished on 10000/270890 queries. users per second: 4333.83
# recommendations finished on 11000/270890 queries. users per second: 4348.97
# recommendations finished on 12000/270890 queries. users per second: 4343.72
# recommendations finished on 13000/270890 queries. users per second: 4308.94
# recommendations finished on 14000/270890 queries. users per second: 4311.2
# recommendations finished on 15000/270890 queries. users per second: 4311.2
# recommendations finished on 16000/270890 queries. users per second: 4292.46
# recommendations finished on 17000/270890 queries. users per second: 4300.29
# recommendations finished on 18000/270890 queries. users per second: 4302.6
# recommendations finished on 19000/270890 queries. users per second: 4289.2
# recommendations finished on 20000/270890 queries. users per second: 4297.7
# recommendations finished on 21000/270890 queries. users per second: 4302.92
# recommendations finished on 22000/270890 queries. users per second: 4289.03
# recommendations finished on 23000/270890 queries. users per second: 4292.25
# recommendations finished on 24000/270890 queries. users per second: 4301.76
# recommendations finished on 25000/270890 queries. users per second: 4300.08
# recommendations finished on 26000/270890 queries. users per second: 4309.99
# recommendations finished on 27000/270890 queries. users per second: 4324.6
# recommendations finished on 28000/270890 queries. users per second: 4326.43
# recommendations finished on 29000/270890 queries. users per second: 4331.1
# recommendations finished on 30000/270890 queries. users per second: 4337.15
# recommendations finished on 31000/270890 queries. users per second: 4339.33
# recommendations finished on 32000/270890 queries. users per second: 4332.6
# recommendations finished on 33000/270890 queries. users per second: 4332.79
# recommendations finished on 34000/270890 queries. users per second: 4334.51
# recommendations finished on 35000/270890 queries. users per second: 4325.58
# recommendations finished on 36000/270890 queries. users per second: 4333.99
# recommendations finished on 37000/270890 queries. users per second: 4337.54
# recommendations finished on 38000/270890 queries. users per second: 4334.3
# recommendations finished on 39000/270890 queries. users per second: 4337.25
# recommendations finished on 40000/270890 queries. users per second: 4334.61
# recommendations finished on 41000/270890 queries. users per second: 4328.65
# recommendations finished on 42000/270890 queries. users per second: 4336.42
# recommendations finished on 43000/270890 queries. users per second: 4336.6
# recommendations finished on 44000/270890 queries. users per second: 4332.46
# recommendations finished on 45000/270890 queries. users per second: 4332.94
# recommendations finished on 46000/270890 queries. users per second: 4335.08
# recommendations finished on 47000/270890 queries. users per second: 4340.28
# recommendations finished on 48000/270890 queries. users per second: 4339.95
# recommendations finished on 49000/270890 queries. users per second: 4341.85
# recommendations finished on 50000/270890 queries. users per second: 4343.53
# recommendations finished on 51000/270890 queries. users per second: 4340.96
# recommendations finished on 52000/270890 queries. users per second: 4336.68
# recommendations finished on 53000/270890 queries. users per second: 4336.42
# recommendations finished on 54000/270890 queries. users per second: 4341.98
# recommendations finished on 55000/270890 queries. users per second: 4337.68
# recommendations finished on 56000/270890 queries. users per second: 4341.05
# recommendations finished on 57000/270890 queries. users per second: 4349.07
# recommendations finished on 58000/270890 queries. users per second: 4351.24
# recommendations finished on 59000/270890 queries. users per second: 4352.57
# recommendations finished on 60000/270890 queries. users per second: 4355.73
# recommendations finished on 61000/270890 queries. users per second: 4355.32
# recommendations finished on 62000/270890 queries. users per second: 4347.83
# recommendations finished on 63000/270890 queries. users per second: 4346.3
# recommendations finished on 64000/270890 queries. users per second: 4346
# recommendations finished on 65000/270890 queries. users per second: 4342.04
# recommendations finished on 66000/270890 queries. users per second: 4337.74
# recommendations finished on 67000/270890 queries. users per second: 4337.64
# recommendations finished on 68000/270890 queries. users per second: 4339.17
# recommendations finished on 69000/270890 queries. users per second: 4335.27
# recommendations finished on 70000/270890 queries. users per second: 4335.05
# recommendations finished on 71000/270890 queries. users per second: 4336.72
# recommendations finished on 72000/270890 queries. users per second: 4333.02
# recommendations finished on 73000/270890 queries. users per second: 4330.57
# recommendations finished on 74000/270890 queries. users per second: 4329.23
# recommendations finished on 75000/270890 queries. users per second: 4331.99
# recommendations finished on 76000/270890 queries. users per second: 4330.12
# recommendations finished on 77000/270890 queries. users per second: 4332.42
# recommendations finished on 78000/270890 queries. users per second: 4335.45
# recommendations finished on 79000/270890 queries. users per second: 4335.4
# recommendations finished on 80000/270890 queries. users per second: 4332.8
# recommendations finished on 81000/270890 queries. users per second: 4335.89
# recommendations finished on 82000/270890 queries. users per second: 4342.61
# recommendations finished on 83000/270890 queries. users per second: 4343.17
# recommendations finished on 84000/270890 queries. users per second: 4345.53
# recommendations finished on 85000/270890 queries. users per second: 4348.52
# recommendations finished on 86000/270890 queries. users per second: 4349.19
# recommendations finished on 87000/270890 queries. users per second: 4343.91
# recommendations finished on 88000/270890 queries. users per second: 4345.59
# recommendations finished on 89000/270890 queries. users per second: 4347.94
# recommendations finished on 90000/270890 queries. users per second: 4345.5
# recommendations finished on 91000/270890 queries. users per second: 4345.68
# recommendations finished on 92000/270890 queries. users per second: 4348.36
# recommendations finished on 93000/270890 queries. users per second: 4351.99
# recommendations finished on 94000/270890 queries. users per second: 4348.99
# recommendations finished on 95000/270890 queries. users per second: 4351.74
# recommendations finished on 96000/270890 queries. users per second: 4351.73
# recommendations finished on 97000/270890 queries. users per second: 4349.59
# recommendations finished on 98000/270890 queries. users per second: 4349.24
# recommendations finished on 99000/270890 queries. users per second: 4350.33
# recommendations finished on 100000/270890 queries. users per second: 4349.32
# recommendations finished on 101000/270890 queries. users per second: 4353.36
# recommendations finished on 102000/270890 queries. users per second: 4356.11
# recommendations finished on 103000/270890 queries. users per second: 4355.7
# recommendations finished on 104000/270890 queries. users per second: 4361.26
# recommendations finished on 105000/270890 queries. users per second: 4362.85
# recommendations finished on 106000/270890 queries. users per second: 4358.95
# recommendations finished on 107000/270890 queries. users per second: 4360.7
# recommendations finished on 108000/270890 queries. users per second: 4358.99
# recommendations finished on 109000/270890 queries. users per second: 4357.92
# recommendations finished on 110000/270890 queries. users per second: 4359.78
# recommendations finished on 111000/270890 queries. users per second: 4359.87
# recommendations finished on 112000/270890 queries. users per second: 4360.35
# recommendations finished on 113000/270890 queries. users per second: 4361.63
# recommendations finished on 114000/270890 queries. users per second: 4361.39
# recommendations finished on 115000/270890 queries. users per second: 4361.19
# recommendations finished on 116000/270890 queries. users per second: 4358.71
# recommendations finished on 117000/270890 queries. users per second: 4359.88
# recommendations finished on 118000/270890 queries. users per second: 4359.74
# recommendations finished on 119000/270890 queries. users per second: 4359.24
# recommendations finished on 120000/270890 queries. users per second: 4361.36
# recommendations finished on 121000/270890 queries. users per second: 4360.88
# recommendations finished on 122000/270890 queries. users per second: 4359.38
# recommendations finished on 123000/270890 queries. users per second: 4360.59
# recommendations finished on 124000/270890 queries. users per second: 4361.64
# recommendations finished on 125000/270890 queries. users per second: 4359.08
# recommendations finished on 126000/270890 queries. users per second: 4360.15
# recommendations finished on 127000/270890 queries. users per second: 4360.49
# recommendations finished on 128000/270890 queries. users per second: 4356.66
# recommendations finished on 129000/270890 queries. users per second: 4356.7
# recommendations finished on 130000/270890 queries. users per second: 4358.3
# recommendations finished on 131000/270890 queries. users per second: 4358.28
# recommendations finished on 132000/270890 queries. users per second: 4355.2
# recommendations finished on 133000/270890 queries. users per second: 4354.9
# recommendations finished on 134000/270890 queries. users per second: 4357.63
# recommendations finished on 135000/270890 queries. users per second: 4358.99
# recommendations finished on 136000/270890 queries. users per second: 4359.62
# recommendations finished on 137000/270890 queries. users per second: 4358.71
# recommendations finished on 138000/270890 queries. users per second: 4357.24
# recommendations finished on 139000/270890 queries. users per second: 4359.79
# recommendations finished on 140000/270890 queries. users per second: 4360.52
# recommendations finished on 141000/270890 queries. users per second: 4361.06
# recommendations finished on 142000/270890 queries. users per second: 4361.34
# recommendations finished on 143000/270890 queries. users per second: 4360.45
# recommendations finished on 144000/270890 queries. users per second: 4359.34
# recommendations finished on 145000/270890 queries. users per second: 4362.97
# recommendations finished on 146000/270890 queries. users per second: 4365.79
# recommendations finished on 147000/270890 queries. users per second: 4365.93
# recommendations finished on 148000/270890 queries. users per second: 4363.85
# recommendations finished on 149000/270890 queries. users per second: 4364.86
# recommendations finished on 150000/270890 queries. users per second: 4365.3
# recommendations finished on 151000/270890 queries. users per second: 4366.62
# recommendations finished on 152000/270890 queries. users per second: 4368.64
# recommendations finished on 153000/270890 queries. users per second: 4368.25
# recommendations finished on 154000/270890 queries. users per second: 4368.35
# recommendations finished on 155000/270890 queries. users per second: 4368.71
# recommendations finished on 156000/270890 queries. users per second: 4368.62
# recommendations finished on 157000/270890 queries. users per second: 4369.46
# recommendations finished on 158000/270890 queries. users per second: 4371.71
# recommendations finished on 159000/270890 queries. users per second: 4372.18
# recommendations finished on 160000/270890 queries. users per second: 4370.66
# recommendations finished on 161000/270890 queries. users per second: 4371.87
# recommendations finished on 162000/270890 queries. users per second: 4372.09
# recommendations finished on 163000/270890 queries. users per second: 4370.13
# recommendations finished on 164000/270890 queries. users per second: 4369.75
# recommendations finished on 165000/270890 queries. users per second: 4370.76
# recommendations finished on 166000/270890 queries. users per second: 4368.38
# recommendations finished on 167000/270890 queries. users per second: 4366.36
# recommendations finished on 168000/270890 queries. users per second: 4364.86
# recommendations finished on 169000/270890 queries. users per second: 4364.65
# recommendations finished on 170000/270890 queries. users per second: 4365.51
# recommendations finished on 171000/270890 queries. users per second: 4364.98
# recommendations finished on 172000/270890 queries. users per second: 4363.96
# recommendations finished on 173000/270890 queries. users per second: 4363.26
# recommendations finished on 174000/270890 queries. users per second: 4364.87
# recommendations finished on 175000/270890 queries. users per second: 4366.35
# recommendations finished on 176000/270890 queries. users per second: 4364.21
# recommendations finished on 177000/270890 queries. users per second: 4364.48
# recommendations finished on 178000/270890 queries. users per second: 4364.25
# recommendations finished on 179000/270890 queries. users per second: 4363.42
# recommendations finished on 180000/270890 queries. users per second: 4364.39
# recommendations finished on 181000/270890 queries. users per second: 4364
# recommendations finished on 182000/270890 queries. users per second: 4363.89
# recommendations finished on 183000/270890 queries. users per second: 4365.33
# recommendations finished on 184000/270890 queries. users per second: 4365.29
# recommendations finished on 185000/270890 queries. users per second: 4364.4
# recommendations finished on 186000/270890 queries. users per second: 4365.69
# recommendations finished on 187000/270890 queries. users per second: 4364.89
# recommendations finished on 188000/270890 queries. users per second: 4363.72
# recommendations finished on 189000/270890 queries. users per second: 4364.61
# recommendations finished on 190000/270890 queries. users per second: 4365.54
# recommendations finished on 191000/270890 queries. users per second: 4365.34
# recommendations finished on 192000/270890 queries. users per second: 4366.27
# recommendations finished on 193000/270890 queries. users per second: 4367.02
# recommendations finished on 194000/270890 queries. users per second: 4364.96
# recommendations finished on 195000/270890 queries. users per second: 4364.37
# recommendations finished on 196000/270890 queries. users per second: 4363.56
# recommendations finished on 197000/270890 queries. users per second: 4361.97
# recommendations finished on 198000/270890 queries. users per second: 4361.86
# recommendations finished on 199000/270890 queries. users per second: 4362.92
# recommendations finished on 200000/270890 queries. users per second: 4364.96
# recommendations finished on 201000/270890 queries. users per second: 4365.77
# recommendations finished on 202000/270890 queries. users per second: 4366.5
# recommendations finished on 203000/270890 queries. users per second: 4365.32
# recommendations finished on 204000/270890 queries. users per second: 4367.58
# recommendations finished on 205000/270890 queries. users per second: 4368.2
# recommendations finished on 206000/270890 queries. users per second: 4366.89
# recommendations finished on 207000/270890 queries. users per second: 4367.1
# recommendations finished on 208000/270890 queries. users per second: 4367.56
# recommendations finished on 209000/270890 queries. users per second: 4366.73
# recommendations finished on 210000/270890 queries. users per second: 4364.77
# recommendations finished on 211000/270890 queries. users per second: 4366.75
# recommendations finished on 212000/270890 queries. users per second: 4367.19
# recommendations finished on 213000/270890 queries. users per second: 4367.7
# recommendations finished on 214000/270890 queries. users per second: 4369.36
# recommendations finished on 215000/270890 queries. users per second: 4369.47
# recommendations finished on 216000/270890 queries. users per second: 4368.49
# recommendations finished on 217000/270890 queries. users per second: 4368.52
# recommendations finished on 218000/270890 queries. users per second: 4368.83
# recommendations finished on 219000/270890 queries. users per second: 4367.41
# recommendations finished on 220000/270890 queries. users per second: 4367.58
# recommendations finished on 221000/270890 queries. users per second: 4369.02
# recommendations finished on 222000/270890 queries. users per second: 4368.75
# recommendations finished on 223000/270890 queries. users per second: 4370.18
# recommendations finished on 224000/270890 queries. users per second: 4370.67
# recommendations finished on 225000/270890 queries. users per second: 4369.32
# recommendations finished on 226000/270890 queries. users per second: 4370.17
# recommendations finished on 227000/270890 queries. users per second: 4371.14
# recommendations finished on 228000/270890 queries. users per second: 4369.8
# recommendations finished on 229000/270890 queries. users per second: 4370.57
# recommendations finished on 230000/270890 queries. users per second: 4371.63
# recommendations finished on 231000/270890 queries. users per second: 4370.86
# recommendations finished on 232000/270890 queries. users per second: 4371.26
# recommendations finished on 233000/270890 queries. users per second: 4371.07
# recommendations finished on 234000/270890 queries. users per second: 4371.46
# recommendations finished on 235000/270890 queries. users per second: 4372.65
# recommendations finished on 236000/270890 queries. users per second: 4373.18
# recommendations finished on 237000/270890 queries. users per second: 4373.48
# recommendations finished on 238000/270890 queries. users per second: 4372.36
# recommendations finished on 239000/270890 queries. users per second: 4372.73
# recommendations finished on 240000/270890 queries. users per second: 4373.51
# recommendations finished on 241000/270890 queries. users per second: 4372.57
# recommendations finished on 242000/270890 queries. users per second: 4373.36
# recommendations finished on 243000/270890 queries. users per second: 4374.95
# recommendations finished on 244000/270890 queries. users per second: 4374.05
# recommendations finished on 245000/270890 queries. users per second: 4372.95
# recommendations finished on 246000/270890 queries. users per second: 4372.83
# recommendations finished on 247000/270890 queries. users per second: 4374.17
# recommendations finished on 248000/270890 queries. users per second: 4373.31
# recommendations finished on 249000/270890 queries. users per second: 4373.47
# recommendations finished on 250000/270890 queries. users per second: 4374.24
# recommendations finished on 251000/270890 queries. users per second: 4374.17
# recommendations finished on 252000/270890 queries. users per second: 4374.24
# recommendations finished on 253000/270890 queries. users per second: 4375.36
# recommendations finished on 254000/270890 queries. users per second: 4375.37
# recommendations finished on 255000/270890 queries. users per second: 4374.33
# recommendations finished on 256000/270890 queries. users per second: 4375.68
# recommendations finished on 257000/270890 queries. users per second: 4377.31
# recommendations finished on 258000/270890 queries. users per second: 4377.47
# recommendations finished on 259000/270890 queries. users per second: 4377.46
# recommendations finished on 260000/270890 queries. users per second: 4378.35
# recommendations finished on 261000/270890 queries. users per second: 4380.52
# recommendations finished on 262000/270890 queries. users per second: 4381.99
# recommendations finished on 263000/270890 queries. users per second: 4390.06
# recommendations finished on 264000/270890 queries. users per second: 4397.58
# recommendations finished on 265000/270890 queries. users per second: 4403.39
# recommendations finished on 266000/270890 queries. users per second: 4410.15
# recommendations finished on 267000/270890 queries. users per second: 4417.42
# recommendations finished on 268000/270890 queries. users per second: 4425.21
# recommendations finished on 269000/270890 queries. users per second: 4433.42
# recommendations finished on 270000/270890 queries. users per second: 4437.12
# Columns:
# 	userId	int
# 	movieId	int
# 	score	float
# 	rank	int
#
# Rows: 2708900
#
# Data:
# +--------+---------+---------------------+------+
# | userId | movieId |        score        | rank |
# +--------+---------+---------------------+------+
# |   1    |  89745  | 0.34124616340354635 |  1   |
# |   1    |  88125  | 0.31810148777785124 |  2   |
# |   1    |  77561  |  0.2874858953334667 |  3   |
# |   1    |   2571  | 0.27601119765528925 |  4   |
# |   1    |   2858  | 0.26622436885480527 |  5   |
# |   1    |  54001  |  0.2431843567777563 |  6   |
# |   1    |  40815  |  0.2249425760021916 |  7   |
# |   1    |   1213  | 0.21145953072441948 |  8   |
# |   1    |   8368  | 0.21033542023764717 |  9   |
# |   1    |   7361  | 0.18893836162708424 |  10  |
# +--------+---------+---------------------+------+
# [2708900 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ## Collaborative Filtering Model (user-item)

# %% [markdown]
# ### base_model: Explicit (user-item) model
# This is the very basic 5 liner from TuriCreate (GraphLab) that uses users, movies, and ratings to make recommendations.  We'll convert our pandas dataframes to SFrames in order to build the recommender, and let Turi Create choose a model for us.  The **ranking_factorization_recommender** (user-item) was selected, so let's see how it performs. We added a couple of paramters here **none** for userId will make predictions for all users, automatically excluding movies they've rated, and **k=5** limits the recommendations to the top 5 recommended movies per user.
#
# Additional info from Apple's documentation: https://apple.github.io/turicreate/docs/userguide/recommender/choosing-a-model.html
#
# *The RankingFactorizationRecommender tries to recommend items that are both similar to the items in a user's dataset and, if rating information is provided, those that would be rated highly by the user. It tends to predict ratings with less accuracy than the non-ranking factorization_recommender, but it tends to do much better at choosing items that a user would rate highly. This is because it also penalizes the predicted rating of items that are significantly different from the items a user has interacted with. In other words, it only predicts a high rating for user-item pairs in which it predicts a high rating and is confident in that prediction.*

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    base_model = tc.load_model('./models/base_model')
except:
    base_model = tc.recommender.create(train_data, user_id="userId", item_id="movieId", target="rating")
    base_model.save("./models/base_model")

#base_model_recs = base_model.recommend(users=None, k=5)
print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 706 ms, sys: 28 ms, total: 734 ms
# Wall time: 128 ms

# %%
#base_model_recs

# %% [markdown]
# ## Hypertuning the Explicit Model (user-item)

# %% [markdown]
# Below is a helper function that uses the links dataset to go from our MovieLens user ratings to the TMDB movie metadata.  The min size only adds genre and collection, while the large size adds directors, producers, actors, age of the movie (number of years), spoken and original languages.  With this much metadata, it will likely slow down our modeling significantly, but we think it may improve recommendation performance.

# %%
def get_side_features(size='min'):
    df = links
    df = df.merge(movies, how='left', left_on='tmdbId', right_on='id')
    df = df.fillna('')
    if size=='min':
        # Limit dataset to ratings, genre and collection
        df = df[['movieId','genre_dict','belongs_to_collection']]

    if size=='large':
        df = df[['movieId',
                 'genre_dict',
                 'belongs_to_collection',
                 'directors',
                 'producers',
                 'actors',
                 'number_of_years',
                 'spoken_languages',
                 'original_language']]
        df = df[~df['genre_dict'].isnull()]
        df = df[~df['directors'].isnull()]        
        df = df[~df['producers'].isnull()]        
        df = df[~df['actors'].isnull()]        
        df = df[~df['belongs_to_collection'].isnull()]     
        df = df[~df['number_of_years'].isnull()]     
        df = df[~df['spoken_languages'].isnull()]     
        df = df[~df['original_language'].isnull()]     
    return tc.SFrame(df)

# %% [markdown]
# ### user_prefs_min: Adding a minimal amount of movie features to our model
#
# In this step we add Genre and Collection data elements to our model to see if we get any performance improvement.

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    user_prefs_min = tc.load_model('./models/user_prefs_min')
except:
    user_prefs_min = tc.recommender.ranking_factorization_recommender.create(
        train_data, 
        user_id="userId", 
        item_id="movieId", 
        target="rating", 
        item_data=get_side_features('min'))
    user_prefs_min.save("./models/user_prefs_min")

#user_prefs_min_recs = user_prefs_min.recommend(users=None, k=5)

print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 546 ms, sys: 23.3 ms, total: 570 ms
# Wall time: 182 ms

# %% [markdown]
# ### user_prefs_large: Adding a lot of movie features to our model
#
# In this model we add genre, collection, directors, producers, actors, age of the movie (number of years), spoken and original languages.

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    user_prefs_large = tc.load_model('./models/user_prefs_large')
except:
    user_prefs_large = tc.recommender.ranking_factorization_recommender.create(
        train_data, 
        user_id="userId", 
        item_id="movieId", 
        target="rating", 
        item_data=get_side_features('large'))
    user_prefs_large.save("./models/user_prefs_large")

#user_prefs_large_recs = user_prefs_large.recommend(users=None, k=5)

print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 2.65 s, sys: 134 ms, total: 2.78 s
# Wall time: 456 ms

# %% [markdown]
# ### base_model_rr1: Base + Ranking Regularization = 1

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    base_model_rr1 = tc.load_model('./models/base_model_rr1')
except:
    base_model_rr1 = tc.recommender.ranking_factorization_recommender.create(train_data, 
                                       user_id="userId", 
                                       item_id="movieId", 
                                       target="rating",
                                       ranking_regularization=1
                                    )
    base_model_rr1.save("./models/base_model_rr1")

#base_model_recs = base_model.recommend(users=None, k=5)
print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 1.33 s, sys: 23.3 ms, total: 1.35 s
# Wall time: 198 ms

# %% [markdown]
# ### base_model_rr0: Base + Ranking Regularization = 0

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    base_model_rr0 = tc.load_model('./models/base_model_rr0')
except:
    base_model_rr0 = tc.recommender.ranking_factorization_recommender.create(train_data, 
                                       user_id="userId", 
                                       item_id="movieId", 
                                       target="rating",
                                       ranking_regularization=0
                                    )
    base_model_rr0.save("./models/base_model_rr0")

#base_model_recs = base_model.recommend(users=None, k=5)
print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 731 ms, sys: 16.5 ms, total: 748 ms
# Wall time: 131 ms

# %% [markdown]
# ### base_model_rr01: Base + Ranking Regularization = 0.1

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    base_model_rr01 = tc.load_model('./models/base_model_rr01')
except:
    base_model_rr01 = tc.recommender.ranking_factorization_recommender.create(train_data, 
                                       user_id="userId", 
                                       item_id="movieId", 
                                       target="rating",
                                       ranking_regularization=0.1
                                    )
    base_model_rr01.save("./models/base_model_rr01")

#base_model_recs = base_model.recommend(users=None, k=5)
print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 644 ms, sys: 10.1 ms, total: 654 ms
# Wall time: 125 ms

# %% [markdown]
# ### base_model_rr05: Base + Ranking Regularization = 0.5

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    base_model_rr05 = tc.load_model('./models/base_model_rr05')
except:
    base_model_rr05 = tc.recommender.ranking_factorization_recommender.create(train_data, 
                                       user_id="userId", 
                                       item_id="movieId", 
                                       target="rating",
                                       ranking_regularization=0.5
                                    )
    base_model_rr05.save("./models/base_model_rr05")

#base_model_recs = base_model.recommend(users=None, k=5)
print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 512 ms, sys: 23.1 ms, total: 535 ms
# Wall time: 113 ms

# %% [markdown]
# ### base_model_rr05_nsne8: Base + Ranking Regularization = 0.5 + num_sampled_negative_examples = 8

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    base_model_rr05_nsne8 = tc.load_model('./models/base_model_rr05_nsne8')
except:
    base_model_rr05_nsne8 = tc.recommender.ranking_factorization_recommender.create(train_data, 
                                       user_id="userId", 
                                       item_id="movieId", 
                                       target="rating",
                                       ranking_regularization=0.5,
                                       num_sampled_negative_examples = 8                                       
                                    )
    base_model_rr05_nsne8.save("./models/base_model_rr05_nsne8")

#base_model_recs = base_model.recommend(users=None, k=5)
print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 516 ms, sys: 20 ms, total: 536 ms
# Wall time: 114 ms

# %% [markdown]
# ### base_model_rr0_nsne8: Base + Ranking Regularization = 0 + num_sampled_negative_examples = 8

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    base_model_rr0_nsne8 = tc.load_model('./models/base_model_rr0_nsne8')
except:
    base_model_rr0_nsne8 = tc.recommender.ranking_factorization_recommender.create(train_data, 
                                       user_id="userId", 
                                       item_id="movieId", 
                                       target="rating",
                                       ranking_regularization=0.5,
                                       num_sampled_negative_examples = 8                                       
                                    )
    base_model_rr0_nsne8.save("./models/base_model_rr0_nsne8")

#base_model_recs = base_model.recommend(users=None, k=5)
print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 1.11 s, sys: 20 ms, total: 1.13 s
# Wall time: 164 ms

# %% [markdown]
# ### base_model_rr05_nsne16: Base + Ranking Regularization = 0.5 + num_sampled_negative_examples = 16

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    base_model_rr05_nsne16 = tc.load_model('./models/base_model_rr05_nsne16')
except:
    base_model_rr05_nsne16 = tc.recommender.ranking_factorization_recommender.create(train_data, 
                                       user_id="userId", 
                                       item_id="movieId", 
                                       target="rating",
                                       ranking_regularization=0.5,
                                       num_sampled_negative_examples = 8                                       
                                    )
    base_model_rr05_nsne16.save("./models/base_model_rr05_nsne16")

#base_model_recs = base_model.recommend(users=None, k=5)
print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 748 ms, sys: 16.5 ms, total: 765 ms
# Wall time: 155 ms

# %% [markdown]
# ### user_prefs_min_plus: user_prefs_min + Ranking Regularization = 0.5 + num_sampled_negative_examples = 8

# %%
# %%time

# Load the saved model if it exists, otherwise create it:
try: 
    user_prefs_min_plus = tc.load_model('./models/user_prefs_min_plus')
except:
    user_prefs_min_plus = tc.recommender.ranking_factorization_recommender.create(
        train_data, 
        user_id="userId", 
        item_id="movieId", 
        target="rating", 
        ranking_regularization=0.5,
        num_sampled_negative_examples = 8,
        item_data=get_side_features('min'))
    user_prefs_min.save("./models/user_prefs_min_plus")

#user_prefs_min_recs = user_prefs_min.recommend(users=None, k=5)

print(timebreak)
# Out:
# ----------------------------------------------------
# Cell Processing Time
# CPU times: user 769 ms, sys: 23.1 ms, total: 792 ms
# Wall time: 147 ms

# %% [markdown]
# ## Exploring Movie Recommendations:

# %% [markdown]
# ### Item-Item Movie Recommendation Example:

# %% [markdown]
# Below are the 8 movies rated by user 10930, we can see a common theme for preferences for action, drama, and thriller movies (rated at 5 stars, vs 4).

# %%
user_ratings = ratings[ratings['userId'] == 10930].merge(movies, left_on='movieId', right_on='id')
user_ratings[['userId','title','rating','genres']].sort_values('userId')
# Out:
#    userId                     title  rating  \
# 0   10930                   48 Hrs.     5.0
# 1   10930  The Million Dollar Hotel     4.0
# 2   10930           Monsoon Wedding     4.0
# 3   10930     The Prisoner of Zenda     4.5
# 4   10930             Reign Over Me     5.0
# 5   10930      The Bourne Supremacy     5.0
# 6   10930            License to Wed     4.0
# 7   10930                 Longitude     5.0
#
#                                      genres
# 0  [Thriller, Action, Comedy, Crime, Drama]
# 1                         [Drama, Thriller]
# 2                  [Comedy, Drama, Romance]
# 3               [Action, Adventure, Comedy]
# 4                                   [Drama]
# 5                 [Action, Drama, Thriller]
# 6                                  [Comedy]
# 7                [TV Movie, Drama, History]

# %% [markdown]
# The following are 5 ranked recommendations from the item-item model.  We can see that the model has selected primarily action and drama films, with a western film thrown in as the sole outlier.

# %%
item_recs = item_item_m.recommend(users=[10930], k=5)
item_recs = tc.SFrame.to_dataframe(item_recs)
item_recs = item_recs.merge(movies, left_on='movieId', right_on='id')
item_recs[['userId','score','rank','title','genres']].sort_values('userId')
# Out:
#    userId     score  rank                               title  \
# 0   10930  0.466233     1  Terminator 3: Rise of the Machines
# 1   10930  0.463973     2                     Monsoon Wedding
# 2   10930  0.462327     3                             Solaris
# 3   10930  0.420931     4                       The Searchers
# 4   10930  0.411269     5                         5 Card Stud
#
#                                          genres
# 0           [Action, Thriller, Science Fiction]
# 1                      [Comedy, Drama, Romance]
# 2  [Drama, Science Fiction, Adventure, Mystery]
# 3                                     [Western]
# 4                   [Action, Western, Thriller]

# %% [markdown]
# ### User-Item Movie Recommendation Example:

# %% [markdown]
# Using the same 8 movies ranked by user 10930, the best performing user-item model (based on F-1) recommended four action/drama movies and a horror/mystery movie.  **Note: we had to increase k to 7 before the model selected 5 movies for this particular user.**

# %%
user_recs = base_model_rr05_nsne8.recommend(users=[10930], k=7)
user_recs = tc.SFrame.to_dataframe(user_recs)
user_recs = user_recs.merge(movies, left_on='movieId', right_on='id')
user_recs[['userId','score','rank','title','genres']].sort_values('userId')
# Out:
#    userId     score  rank               title                       genres
# 0   10930  5.799431     1  Once Were Warriors                      [Drama]
# 1   10930  5.565250     2      Batman Returns            [Action, Fantasy]
# 2   10930  5.555592     3        The 39 Steps  [Action, Thriller, Mystery]
# 3   10930  5.466134     6         Silent Hill            [Horror, Mystery]
# 4   10930  5.462774     7   Three Colors: Red    [Drama, Mystery, Romance]

# %% [markdown]
# Using the same 8 movies ranked by user 10930, the best performing user-item model containing movie metadata recommended three action/drama movies and two outliers of horror/mystery and western movies.

# %%
user_recs = user_prefs_min_plus.recommend(users=[10930], k=5)
user_recs = tc.SFrame.to_dataframe(user_recs)
user_recs = user_recs.merge(movies, left_on='movieId', right_on='id')
user_recs[['userId','score','rank','title','genres']].sort_values('userId')
# Out:
#    userId     score  rank                     title  \
# 0   10930  5.935018     1               Silent Hill
# 1   10930  5.865106     2            Batman Returns
# 2   10930  5.786521     3             The Searchers
# 3   10930  5.633877     4                 The Beach
# 4   10930  5.612761     5  And Then There Were None
#
#                                   genres
# 0                      [Horror, Mystery]
# 1                      [Action, Fantasy]
# 2                              [Western]
# 3  [Drama, Adventure, Romance, Thriller]
# 4                [Crime, Drama, Mystery]

# %% [markdown]
# # Modeling and Evaluation 2 - Model Evaluations and Comparison

# %% [markdown]
# Our primary evaluation metrics are going to consist of RMSE, Precision, and Recall, with F-1 scores to help us choose the best balance between precision and recall.  We have borrowed from definitions given by Dr. Eric Larson @ SMU, which we think clearly articulate the usage and explanation of RMSE, Precision and Recall metrics below.
#
# * Root Mean Squared Error, or **RMSE**, measures the difference between the predicted rating and the actual rating for a given movie/user pair.  Our usage of RMSE will be at an aggregate level (i.e. the average of all RMSE calculations of every user/item prediction in the full ratings dataset).  RMSE is calculated using the following equation:
#
# $$RMSE = \sqrt{\frac{1}{n} \sum_{i=1}^{n}(\hat{y}_{i}-y_{i})^2}$$
#
#     * Additional calculations are available in the Turi evaluation functions, such as: RMSE for each user, U, in our data:
#
# $$\underbrace{RMSE(U)}_{\text{user=U}}=\sqrt{\frac{1}{|U|}\sum_{u\in U} (\hat{y}_u-y_u)^2}$$
#
#     * Or the RMSE for each item, J, in our data:
#
# $$\underbrace{RMSE(J)}_{\text{item=J}}=\sqrt{\frac{1}{|J|}\sum_{j\in J} (\hat{y}_j-y_j)^2}$$
#
#
# * **Precision** attempts to measure the number of positively rated movies by the user which were found by the recommender.  Precision is calculated per user, for k-items is given by the following:
#
# $$P(k)=\frac{|a \cap p_k|}{k} $$
#
#     * "Of the k items found by your recommender, how many were rated positively by the user?"
#
# * **Recall** attempts to measure the number of movies recommended by our algorithm that the user rated positively.  Recall is calculated per user, for k-items is given by the following:
#
# $$R(k)=\frac{|a \cap p_k|}{|a|} $$
#
#      * "Of all the items rated positively by the user, how many did your recommender find?"
#
#
# * The **F-1 Score** may be interpretted as the weighted average of precision and recall, with best performance at 1 (perfect precision and recall) and worst at 0.  Because Precision and Recall are oftentimes inversely related, it can be difficult to quickly ascerctain the best performing model.  F1 attempts to solve this problem by capturing the best possible combination of precision and recall scores.  F1 is calculated using the following equation:
#
# $$ F1 = 2 \Bigl(\frac{precision * recall}{precision + recall}\Bigl) $$
#
#     * Note our calculation of F1 uses the overall aggregate average precision and recall for each model.

# %% [markdown]
# ## Item-Item Model Evaluation

# %%
item_item_eval = item_item_m.evaluate(test_data)
# Out:
# Precision and recall summary statistics by cutoff
# +--------+---------------------+---------------------+
# | cutoff |    mean_precision   |     mean_recall     |
# +--------+---------------------+---------------------+
# |   1    |  0.287686996547756  | 0.04107702557647952 |
# |   2    | 0.24741081703107015 | 0.07132029158110317 |
# |   3    | 0.23245109321058693 | 0.09715344479818364 |
# |   4    | 0.22410817031070196 | 0.12205400340464242 |
# |   5    | 0.21242807825086302 |  0.1404456149313188 |
# |   6    |  0.2021480629075565 | 0.15682953799404897 |
# |   7    | 0.19201052112444522 | 0.17081312329002796 |
# |   8    | 0.18570195627157648 | 0.18796472866609854 |
# |   9    |  0.1778544943101903 |   0.19780198094752  |
# |   10   | 0.17169159953970087 | 0.20962438627635016 |
# +--------+---------------------+---------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 4.366865729219608
#
# Per User RMSE (best)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 119775 | 1.069653868675232 |   1   |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+------+-------+
# | userId | rmse | count |
# +--------+------+-------+
# | 223632 | 5.0  |   1   |
# +--------+------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |   153   | 3.569809974362425 |   4   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+------+-------+
# | movieId | rmse | count |
# +---------+------+-------+
# |   496   | 5.0  |   1   |
# +---------+------+-------+
# [1 rows x 3 columns]

# %% [markdown]
# ## Item-Item Model Evaluation Result

# %%
item_item_results = pd.concat([
    get_metrics(item_item_eval,'base')]
).sort_values('F1', ascending=False)

item_item_results
# Out:
#     cutoff  Avg of precision  Stdv of precision  Avg of recall  \
# 4       10          0.171692           0.201843       0.209624
# 5       11          0.164557           0.193663       0.219280
# 7        9          0.177854           0.208992       0.197802
# 11       8          0.185702           0.219151       0.187965
# 16      16          0.140967           0.169206       0.260462
#
#     Stdv of recall        F1 Model      RMSE
# 4         0.268282  0.188771  base  4.366866
# 5         0.272619  0.188017  base  4.366866
# 7         0.261897  0.187299  base  4.366866
# 11        0.258270  0.186826  base  4.366866
# 16        0.291217  0.182929  base  4.366866

# %% [markdown]
# ## User-Item Model Evaluation

# %%
base_eval = base_model.evaluate(test_data)
# Out:
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    |  0.1783659378596088 | 0.02129900288286234  |
# |   2    | 0.15420023014959724 | 0.03294107407869168  |
# |   3    | 0.14039125431530491 | 0.04430642800633718  |
# |   4    | 0.12859608745684697 | 0.05152296177439346  |
# |   5    | 0.12359033371691597 | 0.061717283985293823 |
# |   6    | 0.11718450326045265 | 0.07267770943140485  |
# |   7    |  0.1098142363965149 | 0.08002299819316683  |
# |   8    |  0.1060126582278481 |  0.0869402782379292  |
# |   9    | 0.10190512722158296 | 0.09430505964967266  |
# |   10   | 0.09792865362485619 | 0.10129369424658236  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.9018030943844395
#
# Per User RMSE (best)
# +--------+-----------------------+-------+
# | userId |          rmse         | count |
# +--------+-----------------------+-------+
# | 177672 | 0.0047587396835266915 |   1   |
# +--------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 259299 | 3.0955887540357865 |   2   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+----------------------+-------+
# | movieId |         rmse         | count |
# +---------+----------------------+-------+
# |   490   | 0.005149416831693898 |   1   |
# +---------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+------------------+-------+
# | movieId |       rmse       | count |
# +---------+------------------+-------+
# |  97785  | 4.66802381826798 |   1   |
# +---------+------------------+-------+
# [1 rows x 3 columns]

# %%
#Hypertuning evals:
user_min_eval = user_prefs_min.evaluate(test_data)
user_large_eval = user_prefs_large.evaluate(test_data)
base_model_rr05_eval = base_model_rr05.evaluate(test_data)
base_model_rr1_eval = base_model_rr1.evaluate(test_data)
base_model_rr0_eval = base_model_rr0.evaluate(test_data)
base_model_rr01_eval = base_model_rr01.evaluate(test_data)
base_model_rr05_nsne8_eval = base_model_rr05_nsne8.evaluate(test_data)
base_model_rr05_nsne16_eval = base_model_rr05_nsne16.evaluate(test_data)
user_prefs_min_plus_eval = user_prefs_min_plus.evaluate(test_data)
base_model_rr0_nsne8_eval = base_model_rr0_nsne8.evaluate(test_data)
# Out:
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.11737629459148452 | 0.012371871420150095 |
# |   2    | 0.11047180667433831 | 0.024275858332987746 |
# |   3    | 0.10164940544687374 | 0.03557530081138968  |
# |   4    | 0.10011507479861914 | 0.04660082072601716  |
# |   5    |  0.0959723820483314 | 0.05290340410570078  |
# |   6    | 0.09205983889528195 | 0.05940077893862578  |
# |   7    | 0.08729245438106199 | 0.06466827748316877  |
# |   8    |  0.0857307249712313 | 0.07517604555055407  |
# |   9    | 0.08477176831607214 | 0.08429604720459818  |
# |   10   |  0.0823935558112773 | 0.09074564357179693  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.9012848958267099
#
# Per User RMSE (best)
# +--------+----------------------+-------+
# | userId |         rmse         | count |
# +--------+----------------------+-------+
# | 178108 | 0.017715243776069478 |   1   |
# +--------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 259299 | 3.8751298969686716 |   2   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |   933   | 0.0012155620852256632 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+--------------------+-------+
# | movieId |        rmse        | count |
# +---------+--------------------+-------+
# |   3217  | 5.0538608443451025 |   1   |
# +---------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    |  0.1622554660529344 | 0.022387088545571872 |
# |   2    |  0.1403912543153049 | 0.03432191434308189  |
# |   3    |   0.12734944380514  | 0.04191128176810893  |
# |   4    | 0.11421173762945915 | 0.04677149261780495  |
# |   5    | 0.10563866513233608 | 0.053363604088495296 |
# |   6    | 0.10452627541235143 | 0.06482817773862135  |
# |   7    | 0.10044385993753073 | 0.07243999245157441  |
# |   8    | 0.09579976985040276 | 0.07686915519268737  |
# |   9    | 0.09410561309295487 | 0.08412165235246523  |
# |   10   | 0.09136939010356734 | 0.08944192134964303  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.8862797344248274
#
# Per User RMSE (best)
# +--------+---------------------+-------+
# | userId |         rmse        | count |
# +--------+---------------------+-------+
# | 101821 | 0.04033422064183512 |   1   |
# +--------+---------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+------------------+-------+
# | userId |       rmse       | count |
# +--------+------------------+-------+
# | 259299 | 2.94531120982403 |   2   |
# +--------+------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+----------------------+-------+
# | movieId |         rmse         | count |
# +---------+----------------------+-------+
# |  73290  | 0.000815125068385214 |   1   |
# +---------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+--------------------+-------+
# | movieId |        rmse        | count |
# +---------+--------------------+-------+
# |  25989  | 4.0622035479347005 |   1   |
# +---------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.17606444188722664 | 0.02320342350118394  |
# |   2    |  0.1524741081703107 | 0.03568395178444518  |
# |   3    |  0.1380897583429229 | 0.045976613279351715 |
# |   4    |  0.1277330264672036 | 0.05636944782194924  |
# |   5    | 0.12082853855005754 | 0.06734023464877714  |
# |   6    |  0.1135404679708477 |  0.0749536811165152  |
# |   7    | 0.10833470327141209 | 0.08372234031175423  |
# |   8    | 0.10428653624856156 | 0.09080674631537648  |
# |   9    | 0.10062651834803732 | 0.09622661829803132  |
# |   10   | 0.09689298043728423 | 0.10239702244860786  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.0138447114693658
#
# Per User RMSE (best)
# +--------+---------------------+-------+
# | userId |         rmse        | count |
# +--------+---------------------+-------+
# | 96473  | 0.03835078772616907 |   1   |
# +--------+---------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 119785 | 3.166136959646657 |   4   |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |   866   | 0.0064498674980217885 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.243249233801597 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+---------------------+
# | cutoff |    mean_precision   |     mean_recall     |
# +--------+---------------------+---------------------+
# |   1    | 0.19447640966628316 | 0.02309874284962948 |
# |   2    | 0.17031070195627157 |  0.0368039012990997 |
# |   3    | 0.15304948216340608 | 0.05059885453763637 |
# |   4    |  0.1432681242807826 | 0.06189967892307539 |
# |   5    |  0.1357882623705409 | 0.07105457350342485 |
# |   6    | 0.13233601841196768 | 0.08275900791574128 |
# |   7    | 0.12691106361992438 | 0.09285251577935792 |
# |   8    | 0.12111622554660528 |  0.0995418802625826 |
# |   9    |  0.1172484337041299 | 0.10881715991051606 |
# |   10   | 0.11254315304948215 | 0.11449636884892023 |
# +--------+---------------------+---------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.082633108073516
#
# Per User RMSE (best)
# +--------+---------------------+-------+
# | userId |         rmse        | count |
# +--------+---------------------+-------+
# | 254956 | 0.01823179399314334 |   1   |
# +--------+---------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 223632 | 3.336664711643069 |   1   |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |  110102 | 0.0009486067902084727 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+--------------------+-------+
# | movieId |        rmse        | count |
# +---------+--------------------+-------+
# |  97785  | 3.9321551804207253 |   1   |
# +---------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Precision and recall summary statistics by cutoff
# +--------+----------------------+----------------------+
# | cutoff |    mean_precision    |     mean_recall      |
# +--------+----------------------+----------------------+
# |   1    | 0.08285385500575378  | 0.010459457775555481 |
# |   2    | 0.07594936708860758  | 0.017859093620777228 |
# |   3    | 0.07057920981971617  | 0.02282953939401663  |
# |   4    | 0.06674338319907941  | 0.026358683025750593 |
# |   5    | 0.06283084004602991  | 0.02905749544148364  |
# |   6    | 0.05887993862677408  | 0.03318184004085629  |
# |   7    | 0.05622225875390435  | 0.036201650048525456 |
# |   8    | 0.055092059838895285 |  0.0396790336526923  |
# |   9    | 0.05280654647743254  | 0.04392517668743152  |
# |   10   | 0.05120828538550056  | 0.04593466829194137  |
# +--------+----------------------+----------------------+
# [10 rows x 3 columns]
# Overall RMSE: 0.7840351187047724
#
# Per User RMSE (best)
# +--------+----------------------+-------+
# | userId |         rmse         | count |
# +--------+----------------------+-------+
# | 209704 | 0.001076550023680234 |   1   |
# +--------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 119785 | 3.137919678216125 |   4   |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+----------------------+-------+
# | movieId |         rmse         | count |
# +---------+----------------------+-------+
# |   907   | 0.000348560922502017 |   1   |
# +---------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.193457463996056 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.18181818181818182 | 0.023155631596097008 |
# |   2    |  0.1513233601841196 | 0.034701840414057675 |
# |   3    |  0.1319524357499042 | 0.042172583174736274 |
# |   4    | 0.12197928653624857 | 0.05050517131945727  |
# |   5    | 0.11323360184119677 | 0.057412071491095916 |
# |   6    | 0.10759493670886076 | 0.06521514927985564  |
# |   7    | 0.10307414104882465 | 0.07161183503494946  |
# |   8    | 0.09781357882623708 | 0.07569285101581107  |
# |   9    | 0.09359416954353666 |  0.0840621791044804  |
# |   10   | 0.09136939010356734 | 0.09052399137591098  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.8341533150194543
#
# Per User RMSE (best)
# +--------+-----------------------+-------+
# | userId |          rmse         | count |
# +--------+-----------------------+-------+
# | 140988 | 0.0060176667452926935 |   1   |
# +--------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 12140  | 3.250517159105315 |   3   |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |   5339  | 0.0010780645169585767 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.588243057014447 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    |  0.2105868814729574 | 0.026565851905043156 |
# |   2    | 0.18239355581127734 | 0.04260841430884851  |
# |   3    | 0.16148830072880707 | 0.05446683773273367  |
# |   4    | 0.14700805523590327 | 0.06583626132397052  |
# |   5    |  0.1429228998849252 | 0.07577899930087938  |
# |   6    |  0.1344457230533179 | 0.08312343425469902  |
# |   7    | 0.13052770014795342 | 0.09561472720175691  |
# |   8    | 0.12356156501726127 | 0.10177561498717279  |
# |   9    | 0.11852704257767543 | 0.10704272387679149  |
# |   10   | 0.11495972382048338 | 0.11608408325988892  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.039848736972919
#
# Per User RMSE (best)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 254956 | 0.0171835709554351 |   1   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 112518 | 3.0924545267193286 |   1   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |  98243  | 0.0028367083316189756 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 3.924129944534921 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.17491369390103567 | 0.021966928161557094 |
# |   2    |  0.1565017261219793 | 0.03680330568859882  |
# |   3    | 0.14461066359800528 | 0.04676784314116213  |
# |   4    | 0.13665132336018407 | 0.059662394731982656 |
# |   5    | 0.12888377445339466 | 0.06971412201448575  |
# |   6    | 0.12255466052934409 |  0.0800262966793477  |
# |   7    | 0.11688311688311687 |  0.0885117778394214  |
# |   8    | 0.11104718066743383 | 0.09533159482086949  |
# |   9    | 0.10676384094105613 | 0.10105328065110367  |
# |   10   | 0.10218642117376296 | 0.10555219941035969  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.0935056720378475
#
# Per User RMSE (best)
# +--------+----------------------+-------+
# | userId |         rmse         | count |
# +--------+----------------------+-------+
# | 200662 | 0.016345196027573117 |   1   |
# +--------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 119785 | 3.3414196118665207 |   4   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |  60766  | 0.0020941721425256077 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.313906330548276 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.11737629459148444 | 0.012371871420150093 |
# |   2    | 0.11047180667433831 | 0.024275858332987753 |
# |   3    |  0.1016494054468738 | 0.03557530081138968  |
# |   4    | 0.10011507479861909 | 0.04660082072601717  |
# |   5    | 0.09597238204833144 | 0.05290340410570076  |
# |   6    | 0.09205983889528196 | 0.05940077893862573  |
# |   7    |  0.087292454381062  |  0.0646682774831688  |
# |   8    | 0.08573072497123131 | 0.07517604555055403  |
# |   9    | 0.08477176831607215 | 0.08429604720459813  |
# |   10   |  0.0823935558112774 | 0.09074564357179694  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.9012848958267099
#
# Per User RMSE (best)
# +--------+----------------------+-------+
# | userId |         rmse         | count |
# +--------+----------------------+-------+
# | 178108 | 0.017715243776069478 |   1   |
# +--------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 259299 | 3.8751298969686716 |   2   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |   933   | 0.0012155620852256632 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+--------------------+-------+
# | movieId |        rmse        | count |
# +---------+--------------------+-------+
# |   3217  | 5.0538608443451025 |   1   |
# +---------+--------------------+-------+
# [1 rows x 3 columns]
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.13693901035673198 | 0.019544646458641506 |
# |   2    | 0.12715765247410826 | 0.028071811973351832 |
# |   3    | 0.11891062523973914 | 0.036708592057094425 |
# |   4    |  0.1119102416570771 | 0.04602102623584426  |
# |   5    | 0.10794016110471803 | 0.05567887197732502  |
# |   6    | 0.10490985807441501 | 0.06491541993854055  |
# |   7    | 0.10126582278481015 | 0.07553386823888378  |
# |   8    | 0.09853279631760645 | 0.08486002759316164  |
# |   9    | 0.09640710906533694 | 0.09213838751553514  |
# |   10   | 0.09286536248561562 | 0.09620131763041521  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.1924186935565633
#
# Per User RMSE (best)
# +--------+---------------------+-------+
# | userId |         rmse        | count |
# +--------+---------------------+-------+
# | 45888  | 0.00889312365044681 |   1   |
# +--------+---------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 215196 | 3.110037473527586 |   14  |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |  106072 | 0.0022071665539380447 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.448472053660375 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]

# %% [markdown]
# ### Comparing Model Evaluation Statistics
#
# Turi Create offers a convenient **compare_models** function which quite literally compares model evaluation.  The resulting output is a concatenation of evaluation metrics, and saves us having to call them for each model.  These statistics describe RMSE overall, RMSE per item, RMSE per user, as well as best and worst scores.  It also includes overall average precision and recall statistics for each cutoff (number of movies selected).

# %%
compare = tc.recommender.util.compare_models
compare(test_data, [base_model, 
                    user_prefs_min, 
                    user_prefs_large,
                    base_model_rr05,
                    base_model_rr01,
                    base_model_rr0,
                    base_model_rr1,
                    base_model_rr05_nsne8,
                    base_model_rr05_nsne16,
                    user_prefs_min_plus,
                    base_model_rr0_nsne8
                   ], 
        model_names=['Base',
                     'Min Features',
                     'Large Features',
                     'Base with rr05',
                     'base with rr01',
                     'base with rr0',
                     'base with rr1',
                     'base with rr05 and nsne8',
                     'base with rr05 and nsne16',
                     'Min Features with rr05 and nsne8',
                     'Base with rr0 and nsne8'
                    ])
# Out:
# PROGRESS: Evaluate model Base
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.17836593785960875 | 0.021299002882862336 |
# |   2    | 0.15420023014959716 | 0.03294107407869172  |
# |   3    |  0.1403912543153048 | 0.044306428006337176 |
# |   4    |  0.128596087456847  | 0.05152296177439345  |
# |   5    | 0.12359033371691598 | 0.06171728398529387  |
# |   6    | 0.11718450326045265 |  0.0726777094314049  |
# |   7    |  0.1098142363965149 | 0.08002299819316679  |
# |   8    |  0.1060126582278481 | 0.08694027823792916  |
# |   9    | 0.10190512722158292 | 0.09430505964967262  |
# |   10   | 0.09792865362485614 | 0.10129369424658238  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.9018030943844395
#
# Per User RMSE (best)
# +--------+-----------------------+-------+
# | userId |          rmse         | count |
# +--------+-----------------------+-------+
# | 177672 | 0.0047587396835266915 |   1   |
# +--------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 259299 | 3.0955887540357865 |   2   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+----------------------+-------+
# | movieId |         rmse         | count |
# +---------+----------------------+-------+
# |   490   | 0.005149416831693898 |   1   |
# +---------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+------------------+-------+
# | movieId |       rmse       | count |
# +---------+------------------+-------+
# |  97785  | 4.66802381826798 |   1   |
# +---------+------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model Min Features
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.11737629459148445 | 0.012371871420150083 |
# |   2    | 0.11047180667433831 | 0.02427585833298774  |
# |   3    | 0.10164940544687383 | 0.035575300811389696 |
# |   4    |  0.1001150747986191 | 0.046600820726017164 |
# |   5    | 0.09597238204833149 | 0.052903404105700796 |
# |   6    |  0.0920598388952819 | 0.059400778938625734 |
# |   7    | 0.08729245438106198 | 0.06466827748316885  |
# |   8    | 0.08573072497123128 | 0.07517604555055406  |
# |   9    | 0.08477176831607221 | 0.08429604720459824  |
# |   10   | 0.08239355581127727 |  0.090745643571797   |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.9012848958267099
#
# Per User RMSE (best)
# +--------+----------------------+-------+
# | userId |         rmse         | count |
# +--------+----------------------+-------+
# | 178108 | 0.017715243776069478 |   1   |
# +--------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 259299 | 3.8751298969686716 |   2   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |   933   | 0.0012155620852256632 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+--------------------+-------+
# | movieId |        rmse        | count |
# +---------+--------------------+-------+
# |   3217  | 5.0538608443451025 |   1   |
# +---------+--------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model Large Features
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+---------------------+
# | cutoff |    mean_precision   |     mean_recall     |
# +--------+---------------------+---------------------+
# |   1    | 0.16225546605293448 | 0.02238708854557186 |
# |   2    | 0.14039125431530503 | 0.03432191434308191 |
# |   3    | 0.12734944380513996 | 0.04191128176810893 |
# |   4    | 0.11421173762945913 | 0.04677149261780494 |
# |   5    | 0.10563866513233604 | 0.05336360408849529 |
# |   6    | 0.10452627541235134 | 0.06482817773862137 |
# |   7    | 0.10044385993753084 | 0.07243999245157452 |
# |   8    | 0.09579976985040278 | 0.07686915519268737 |
# |   9    | 0.09410561309295486 |  0.0841216523524652 |
# |   10   | 0.09136939010356734 | 0.08944192134964303 |
# +--------+---------------------+---------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.8862797344248274
#
# Per User RMSE (best)
# +--------+---------------------+-------+
# | userId |         rmse        | count |
# +--------+---------------------+-------+
# | 101821 | 0.04033422064183512 |   1   |
# +--------+---------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+------------------+-------+
# | userId |       rmse       | count |
# +--------+------------------+-------+
# | 259299 | 2.94531120982403 |   2   |
# +--------+------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+----------------------+-------+
# | movieId |         rmse         | count |
# +---------+----------------------+-------+
# |  73290  | 0.000815125068385214 |   1   |
# +---------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+--------------------+-------+
# | movieId |        rmse        | count |
# +---------+--------------------+-------+
# |  25989  | 4.0622035479347005 |   1   |
# +---------+--------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model Base with rr05
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.17606444188722675 | 0.023203423501183946 |
# |   2    |  0.1524741081703107 | 0.03568395178444523  |
# |   3    | 0.13808975834292284 | 0.04597661327935171  |
# |   4    |  0.1277330264672037 | 0.056369447821949206 |
# |   5    | 0.12082853855005757 | 0.06734023464877721  |
# |   6    | 0.11354046797084776 | 0.07495368111651515  |
# |   7    | 0.10833470327141217 | 0.08372234031175418  |
# |   8    | 0.10428653624856159 | 0.09080674631537645  |
# |   9    |  0.1006265183480373 | 0.09622661829803136  |
# |   10   | 0.09689298043728423 | 0.10239702244860784  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.0138447114693658
#
# Per User RMSE (best)
# +--------+---------------------+-------+
# | userId |         rmse        | count |
# +--------+---------------------+-------+
# | 96473  | 0.03835078772616907 |   1   |
# +--------+---------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 119785 | 3.166136959646657 |   4   |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |   866   | 0.0064498674980217885 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.243249233801597 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model base with rr01
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    |  0.1818181818181818 |  0.023155631596097   |
# |   2    | 0.15132336018411965 | 0.034701840414057654 |
# |   3    |  0.1319524357499041 | 0.04217258317473627  |
# |   4    | 0.12197928653624861 | 0.050505171319457295 |
# |   5    | 0.11323360184119677 | 0.05741207149109595  |
# |   6    | 0.10759493670886072 |  0.0652151492798556  |
# |   7    |  0.1030741410488246 | 0.07161183503494944  |
# |   8    | 0.09781357882623702 | 0.07569285101581112  |
# |   9    | 0.09359416954353664 | 0.08406217910448041  |
# |   10   | 0.09136939010356727 |  0.090523991375911   |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
# Overall RMSE: 0.8341533150194543
#
# Per User RMSE (best)
# +--------+-----------------------+-------+
# | userId |          rmse         | count |
# +--------+-----------------------+-------+
# | 140988 | 0.0060176667452926935 |   1   |
# +--------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 12140  | 3.250517159105315 |   3   |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |   5339  | 0.0010780645169585767 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.588243057014447 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model base with rr0
#
# Precision and recall summary statistics by cutoff
# +--------+----------------------+----------------------+
# | cutoff |    mean_precision    |     mean_recall      |
# +--------+----------------------+----------------------+
# |   1    | 0.08285385500575378  | 0.010459457775555469 |
# |   2    |  0.0759493670886076  | 0.017859093620777217 |
# |   3    | 0.07057920981971615  | 0.022829539394016603 |
# |   4    | 0.06674338319907937  | 0.026358683025750586 |
# |   5    | 0.06283084004602993  | 0.02905749544148363  |
# |   6    | 0.058879938626774084 | 0.03318184004085634  |
# |   7    | 0.056222258753904304 | 0.03620165004852549  |
# |   8    | 0.05509205983889527  | 0.03967903365269228  |
# |   9    | 0.052806546477432555 | 0.04392517668743154  |
# |   10   | 0.05120828538550056  | 0.04593466829194138  |
# +--------+----------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.7840351187047724
#
# Per User RMSE (best)
# +--------+----------------------+-------+
# | userId |         rmse         | count |
# +--------+----------------------+-------+
# | 209704 | 0.001076550023680234 |   1   |
# +--------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 119785 | 3.137919678216125 |   4   |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+----------------------+-------+
# | movieId |         rmse         | count |
# +---------+----------------------+-------+
# |   907   | 0.000348560922502017 |   1   |
# +---------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.193457463996056 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model base with rr1
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.19447640966628307 | 0.023098742849629483 |
# |   2    | 0.17031070195627165 | 0.036803901299099724 |
# |   3    | 0.15304948216340614 | 0.05059885453763637  |
# |   4    | 0.14326812428078242 | 0.06189967892307535  |
# |   5    | 0.13578826237054092 |  0.0710545735034248  |
# |   6    |  0.1323360184119677 | 0.08275900791574135  |
# |   7    |  0.1269110636199245 | 0.09285251577935796  |
# |   8    |  0.1211162255466053 | 0.09954188026258257  |
# |   9    | 0.11724843370412992 | 0.10881715991051605  |
# |   10   | 0.11254315304948213 | 0.11449636884892021  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.082633108073516
#
# Per User RMSE (best)
# +--------+---------------------+-------+
# | userId |         rmse        | count |
# +--------+---------------------+-------+
# | 254956 | 0.01823179399314334 |   1   |
# +--------+---------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 223632 | 3.336664711643069 |   1   |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |  110102 | 0.0009486067902084727 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+--------------------+-------+
# | movieId |        rmse        | count |
# +---------+--------------------+-------+
# |  97785  | 3.9321551804207253 |   1   |
# +---------+--------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model base with rr05 and nsne8
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+---------------------+
# | cutoff |    mean_precision   |     mean_recall     |
# +--------+---------------------+---------------------+
# |   1    | 0.21058688147295743 | 0.02656585190504315 |
# |   2    |  0.1823935558112774 | 0.04260841430884852 |
# |   3    | 0.16148830072880702 | 0.05446683773273367 |
# |   4    | 0.14700805523590335 | 0.06583626132397051 |
# |   5    | 0.14292289988492518 | 0.07577899930087942 |
# |   6    | 0.13444572305331792 |  0.083123434254699  |
# |   7    | 0.13052770014795326 | 0.09561472720175689 |
# |   8    |  0.1235615650172612 | 0.10177561498717283 |
# |   9    | 0.11852704257767549 | 0.10704272387679152 |
# |   10   |  0.1149597238204833 | 0.11608408325988887 |
# +--------+---------------------+---------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.039848736972919
#
# Per User RMSE (best)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 254956 | 0.0171835709554351 |   1   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 112518 | 3.0924545267193286 |   1   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |  98243  | 0.0028367083316189756 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 3.924129944534921 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model base with rr05 and nsne16
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.17491369390103567 | 0.021966928161557094 |
# |   2    |  0.1565017261219792 | 0.03680330568859882  |
# |   3    | 0.14461066359800537 | 0.04676784314116211  |
# |   4    | 0.13665132336018418 | 0.05966239473198264  |
# |   5    |  0.1288837744533946 | 0.06971412201448579  |
# |   6    | 0.12255466052934413 |  0.0800262966793477  |
# |   7    |  0.1168831168831169 | 0.08851177783942148  |
# |   8    | 0.11104718066743383 |  0.0953315948208695  |
# |   9    |  0.1067638409410561 | 0.10105328065110364  |
# |   10   | 0.10218642117376299 |  0.1055521994103597  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.0935056720378475
#
# Per User RMSE (best)
# +--------+----------------------+-------+
# | userId |         rmse         | count |
# +--------+----------------------+-------+
# | 200662 | 0.016345196027573117 |   1   |
# +--------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 119785 | 3.3414196118665207 |   4   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |  60766  | 0.0020941721425256077 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.313906330548276 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model Min Features with rr05 and nsne8
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.11737629459148446 | 0.012371871420150098 |
# |   2    | 0.11047180667433831 | 0.024275858332987753 |
# |   3    | 0.10164940544687374 | 0.03557530081138968  |
# |   4    |  0.1001150747986191 | 0.046600820726017164 |
# |   5    | 0.09597238204833139 | 0.052903404105700755 |
# |   6    |  0.0920598388952819 | 0.05940077893862571  |
# |   7    | 0.08729245438106194 |  0.0646682774831688  |
# |   8    | 0.08573072497123131 |  0.0751760455505541  |
# |   9    | 0.08477176831607214 | 0.08429604720459818  |
# |   10   | 0.08239355581127727 |  0.090745643571797   |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 0.9012848958267099
#
# Per User RMSE (best)
# +--------+----------------------+-------+
# | userId |         rmse         | count |
# +--------+----------------------+-------+
# | 178108 | 0.017715243776069478 |   1   |
# +--------+----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+--------------------+-------+
# | userId |        rmse        | count |
# +--------+--------------------+-------+
# | 259299 | 3.8751298969686716 |   2   |
# +--------+--------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |   933   | 0.0012155620852256632 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+--------------------+-------+
# | movieId |        rmse        | count |
# +---------+--------------------+-------+
# |   3217  | 5.0538608443451025 |   1   |
# +---------+--------------------+-------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model Base with rr0 and nsne8
#
# Precision and recall summary statistics by cutoff
# +--------+---------------------+----------------------+
# | cutoff |    mean_precision   |     mean_recall      |
# +--------+---------------------+----------------------+
# |   1    | 0.13693901035673187 | 0.01954464645864152  |
# |   2    | 0.12715765247410818 | 0.02807181197335184  |
# |   3    | 0.11891062523973918 | 0.03670859205709438  |
# |   4    |  0.1119102416570771 | 0.04602102623584428  |
# |   5    |  0.1079401611047181 | 0.055678871977325024 |
# |   6    | 0.10490985807441505 | 0.06491541993854061  |
# |   7    | 0.10126582278481013 | 0.07553386823888382  |
# |   8    | 0.09853279631760645 |  0.0848600275931616  |
# |   9    | 0.09640710906533691 | 0.09213838751553523  |
# |   10   | 0.09286536248561562 | 0.09620131763041517  |
# +--------+---------------------+----------------------+
# [10 rows x 3 columns]
#
#
# Overall RMSE: 1.1924186935565633
#
# Per User RMSE (best)
# +--------+---------------------+-------+
# | userId |         rmse        | count |
# +--------+---------------------+-------+
# | 45888  | 0.00889312365044681 |   1   |
# +--------+---------------------+-------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------------------+-------+
# | userId |        rmse       | count |
# +--------+-------------------+-------+
# | 215196 | 3.110037473527586 |   14  |
# +--------+-------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-----------------------+-------+
# | movieId |          rmse         | count |
# +---------+-----------------------+-------+
# |  106072 | 0.0022071665539380447 |   1   |
# +---------+-----------------------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------------------+-------+
# | movieId |        rmse       | count |
# +---------+-------------------+-------+
# |  97785  | 4.448472053660375 |   1   |
# +---------+-------------------+-------+
# [1 rows x 3 columns]
# [{'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+-----------+--------+-------+
#   | userId | cutoff | precision | recall | count |
#   +--------+--------+-----------+--------+-------+
#   | 237350 |   1    |    0.0    |  0.0   |   8   |
#   | 237350 |   2    |    0.0    |  0.0   |   8   |
#   | 237350 |   3    |    0.0    |  0.0   |   8   |
#   | 237350 |   4    |    0.0    |  0.0   |   8   |
#   | 237350 |   5    |    0.0    |  0.0   |   8   |
#   | 237350 |   6    |    0.0    |  0.0   |   8   |
#   | 237350 |   7    |    0.0    |  0.0   |   8   |
#   | 237350 |   8    |    0.0    |  0.0   |   8   |
#   | 237350 |   9    |    0.0    |  0.0   |   8   |
#   | 237350 |   10   |    0.1    | 0.125  |   8   |
#   +--------+--------+-----------+--------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+----------------------+
#   | cutoff |      precision      |        recall        |
#   +--------+---------------------+----------------------+
#   |   1    | 0.17836593785960875 | 0.02129900288286233  |
#   |   2    | 0.15420023014959722 | 0.032941074078691686 |
#   |   3    | 0.14039125431530486 | 0.04430642800633718  |
#   |   4    | 0.12859608745684695 | 0.05152296177439346  |
#   |   5    | 0.12359033371691595 | 0.061717283985293886 |
#   |   6    | 0.11718450326045265 | 0.07267770943140492  |
#   |   7    |  0.1098142363965149 | 0.08002299819316684  |
#   |   8    |  0.1060126582278481 | 0.08694027823792917  |
#   |   9    |  0.1019051272215829 | 0.09430505964967258  |
#   |   10   | 0.09792865362485613 | 0.10129369424658238  |
#   +--------+---------------------+----------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+---------------------+-------+
#   | userId |         rmse        | count |
#   +--------+---------------------+-------+
#   | 58235  |  0.7822577521881758 |   15  |
#   | 113382 |  1.3178937526133492 |   2   |
#   | 87933  | 0.29091060958341686 |   1   |
#   | 171399 |  0.9776389350217709 |   2   |
#   | 160368 |  1.2647924288718124 |   13  |
#   | 23235  |  0.7476005165755829 |   95  |
#   | 24765  |  1.5067618141065942 |   12  |
#   | 10445  |  0.8175992973152472 |   5   |
#   | 239457 |  0.8458723735236513 |   2   |
#   | 176300 |  0.9300598986526136 |   3   |
#   +--------+---------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  0.7296070399366384 |   3   |
#   |    60   |  0.5719716319863357 |   1   |
#   |  54272  |  0.5820981941854194 |   3   |
#   |   2010  |  0.620287659431611  |   3   |
#   |   5013  |  0.6578657225860257 |   4   |
#   |  114935 |  0.5291137615571535 |   2   |
#   |   1672  | 0.46492773322938685 |   1   |
#   |  30825  |  0.1006720659039324 |   1   |
#   |   926   | 0.22994849802755846 |   3   |
#   |  105468 |  0.965739598944368  |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 0.9018030943844395},
#  {'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+---------------------+---------------------+-------+
#   | userId | cutoff |      precision      |        recall       | count |
#   +--------+--------+---------------------+---------------------+-------+
#   |  641   |   1    |         1.0         | 0.07692307692307693 |   13  |
#   |  641   |   2    |         0.5         | 0.07692307692307693 |   13  |
#   |  641   |   3    |  0.3333333333333333 | 0.07692307692307693 |   13  |
#   |  641   |   4    |         0.25        | 0.07692307692307693 |   13  |
#   |  641   |   5    |         0.2         | 0.07692307692307693 |   13  |
#   |  641   |   6    | 0.16666666666666666 | 0.07692307692307693 |   13  |
#   |  641   |   7    | 0.14285714285714285 | 0.07692307692307693 |   13  |
#   |  641   |   8    |        0.125        | 0.07692307692307693 |   13  |
#   |  641   |   9    |  0.1111111111111111 | 0.07692307692307693 |   13  |
#   |  641   |   10   |         0.1         | 0.07692307692307693 |   13  |
#   +--------+--------+---------------------+---------------------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+----------------------+
#   | cutoff |      precision      |        recall        |
#   +--------+---------------------+----------------------+
#   |   1    | 0.11737629459148446 | 0.012371871420150088 |
#   |   2    | 0.11047180667433831 | 0.024275858332987753 |
#   |   3    | 0.10164940544687383 | 0.035575300811389654 |
#   |   4    |  0.1001150747986191 | 0.046600820726017164 |
#   |   5    | 0.09597238204833146 | 0.052903404105700755 |
#   |   6    | 0.09205983889528194 | 0.05940077893862575  |
#   |   7    |  0.087292454381062  | 0.06466827748316877  |
#   |   8    | 0.08573072497123134 | 0.07517604555055404  |
#   |   9    | 0.08477176831607217 | 0.08429604720459824  |
#   |   10   | 0.08239355581127736 | 0.09074564357179686  |
#   +--------+---------------------+----------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+--------------------+-------+
#   | userId |        rmse        | count |
#   +--------+--------------------+-------+
#   | 58235  | 0.7510061615427329 |   15  |
#   | 113382 | 0.9106351815869632 |   2   |
#   | 87933  | 0.3476107150210632 |   1   |
#   | 171399 | 1.387615189890029  |   2   |
#   | 160368 | 1.2697236283476931 |   13  |
#   | 23235  | 0.7712206763016184 |   95  |
#   | 24765  | 1.5284566523934144 |   12  |
#   | 10445  | 0.6867076398666897 |   5   |
#   | 239457 | 1.432063599116111  |   2   |
#   | 176300 | 0.7351241054227353 |   3   |
#   +--------+--------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  0.9845359690114656 |   3   |
#   |    60   |  0.8300819557247907 |   1   |
#   |  54272  |  0.6199882757099784 |   3   |
#   |   2010  |  0.6826418620213167 |   3   |
#   |   5013  |  0.8384833750668395 |   4   |
#   |  114935 |  0.8857178799368334 |   2   |
#   |   1672  |  0.2107244164494091 |   1   |
#   |  30825  |  0.2664121081829207 |   1   |
#   |   926   | 0.31276313389925764 |   3   |
#   |  105468 |  1.3830844744707744 |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 0.9012848958267099},
#  {'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+---------------------+---------------------+-------+
#   | userId | cutoff |      precision      |        recall       | count |
#   +--------+--------+---------------------+---------------------+-------+
#   |  641   |   1    |         1.0         | 0.07692307692307693 |   13  |
#   |  641   |   2    |         0.5         | 0.07692307692307693 |   13  |
#   |  641   |   3    |  0.3333333333333333 | 0.07692307692307693 |   13  |
#   |  641   |   4    |         0.25        | 0.07692307692307693 |   13  |
#   |  641   |   5    |         0.2         | 0.07692307692307693 |   13  |
#   |  641   |   6    | 0.16666666666666666 | 0.07692307692307693 |   13  |
#   |  641   |   7    | 0.14285714285714285 | 0.07692307692307693 |   13  |
#   |  641   |   8    |        0.125        | 0.07692307692307693 |   13  |
#   |  641   |   9    |  0.1111111111111111 | 0.07692307692307693 |   13  |
#   |  641   |   10   |         0.1         | 0.07692307692307693 |   13  |
#   +--------+--------+---------------------+---------------------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+----------------------+
#   | cutoff |      precision      |        recall        |
#   +--------+---------------------+----------------------+
#   |   1    |  0.1622554660529344 | 0.02238708854557186  |
#   |   2    |  0.1403912543153049 |  0.0343219143430819  |
#   |   3    |   0.12734944380514  |  0.0419112817681089  |
#   |   4    | 0.11421173762945916 | 0.046771492617804944 |
#   |   5    | 0.10563866513233604 | 0.05336360408849531  |
#   |   6    | 0.10452627541235139 | 0.06482817773862139  |
#   |   7    | 0.10044385993753083 | 0.07243999245157444  |
#   |   8    | 0.09579976985040278 | 0.07686915519268726  |
#   |   9    | 0.09410561309295487 | 0.08412165235246523  |
#   |   10   | 0.09136939010356729 |  0.0894419213496431  |
#   +--------+---------------------+----------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+---------------------+-------+
#   | userId |         rmse        | count |
#   +--------+---------------------+-------+
#   | 58235  |  0.6759141750977637 |   15  |
#   | 113382 |  1.1049169606819826 |   2   |
#   | 87933  | 0.13749198699324516 |   1   |
#   | 171399 |  1.011198320662287  |   2   |
#   | 160368 |  1.3856178535108947 |   13  |
#   | 23235  |  0.756275349994983  |   95  |
#   | 24765  |  1.397928462815849  |   12  |
#   | 10445  |  0.6835098240874381 |   5   |
#   | 239457 |  0.8737856182407995 |   2   |
#   | 176300 |  1.3478765729482063 |   3   |
#   +--------+---------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  0.8554757159373342 |   3   |
#   |    60   |  0.610896632789105  |   1   |
#   |  54272  | 0.40213966460869355 |   3   |
#   |   2010  |  0.8318184728906186 |   3   |
#   |   5013  |  0.5746705197981772 |   4   |
#   |  114935 |  0.8223939487130054 |   2   |
#   |   1672  | 0.05292719454598949 |   1   |
#   |  30825  |  0.2452262568084298 |   1   |
#   |   926   | 0.34875541670059046 |   3   |
#   |  105468 |  1.1638726447062324 |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 0.8862797344248274},
#  {'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+---------------------+---------------------+-------+
#   | userId | cutoff |      precision      |        recall       | count |
#   +--------+--------+---------------------+---------------------+-------+
#   |  641   |   1    |         1.0         | 0.07692307692307693 |   13  |
#   |  641   |   2    |         0.5         | 0.07692307692307693 |   13  |
#   |  641   |   3    |  0.3333333333333333 | 0.07692307692307693 |   13  |
#   |  641   |   4    |         0.25        | 0.07692307692307693 |   13  |
#   |  641   |   5    |         0.2         | 0.07692307692307693 |   13  |
#   |  641   |   6    | 0.16666666666666666 | 0.07692307692307693 |   13  |
#   |  641   |   7    | 0.14285714285714285 | 0.07692307692307693 |   13  |
#   |  641   |   8    |        0.125        | 0.07692307692307693 |   13  |
#   |  641   |   9    |  0.1111111111111111 | 0.07692307692307693 |   13  |
#   |  641   |   10   |         0.1         | 0.07692307692307693 |   13  |
#   +--------+--------+---------------------+---------------------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+---------------------+
#   | cutoff |      precision      |        recall       |
#   +--------+---------------------+---------------------+
#   |   1    |  0.1760644418872267 | 0.02320342350118395 |
#   |   2    |  0.1524741081703107 | 0.03568395178444519 |
#   |   3    |  0.1380897583429228 | 0.04597661327935172 |
#   |   4    | 0.12773302646720378 | 0.05636944782194922 |
#   |   5    | 0.12082853855005755 | 0.06734023464877718 |
#   |   6    | 0.11354046797084776 | 0.07495368111651513 |
#   |   7    |  0.1083347032714121 | 0.08372234031175424 |
#   |   8    | 0.10428653624856156 | 0.09080674631537655 |
#   |   9    | 0.10062651834803732 | 0.09622661829803132 |
#   |   10   | 0.09689298043728428 | 0.10239702244860786 |
#   +--------+---------------------+---------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+---------------------+-------+
#   | userId |         rmse        | count |
#   +--------+---------------------+-------+
#   | 58235  |  0.6188309895263163 |   15  |
#   | 113382 |  1.1761185607285505 |   2   |
#   | 87933  | 0.10336965757932148 |   1   |
#   | 171399 |  0.8915339936225705 |   2   |
#   | 160368 |  1.4316654172860965 |   13  |
#   | 23235  |  0.8545585529888227 |   95  |
#   | 24765  |  1.380389351417648  |   12  |
#   | 10445  |  0.8420446614248643 |   5   |
#   | 239457 |  0.8853372131370894 |   2   |
#   | 176300 |  1.1090205188129714 |   3   |
#   +--------+---------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  0.713160245636105  |   3   |
#   |    60   |  0.8826835599491241 |   1   |
#   |  54272  |  0.7143525894675975 |   3   |
#   |   2010  |  0.6935433344534676 |   3   |
#   |   5013  |  0.8665274707840097 |   4   |
#   |  114935 |  0.7450432877872838 |   2   |
#   |   1672  |  0.7333240633698677 |   1   |
#   |  30825  | 0.13915637832022165 |   1   |
#   |   926   | 0.27428554041480446 |   3   |
#   |  105468 |  1.5185347228896515 |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 1.0138447114693658},
#  {'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+---------------------+---------------------+-------+
#   | userId | cutoff |      precision      |        recall       | count |
#   +--------+--------+---------------------+---------------------+-------+
#   |  641   |   1    |         1.0         | 0.07692307692307693 |   13  |
#   |  641   |   2    |         0.5         | 0.07692307692307693 |   13  |
#   |  641   |   3    |  0.3333333333333333 | 0.07692307692307693 |   13  |
#   |  641   |   4    |         0.25        | 0.07692307692307693 |   13  |
#   |  641   |   5    |         0.2         | 0.07692307692307693 |   13  |
#   |  641   |   6    | 0.16666666666666666 | 0.07692307692307693 |   13  |
#   |  641   |   7    | 0.14285714285714285 | 0.07692307692307693 |   13  |
#   |  641   |   8    |        0.125        | 0.07692307692307693 |   13  |
#   |  641   |   9    |  0.1111111111111111 | 0.07692307692307693 |   13  |
#   |  641   |   10   |         0.1         | 0.07692307692307693 |   13  |
#   +--------+--------+---------------------+---------------------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+----------------------+
#   | cutoff |      precision      |        recall        |
#   +--------+---------------------+----------------------+
#   |   1    | 0.18181818181818185 | 0.023155631596097008 |
#   |   2    |  0.1513233601841196 | 0.03470184041405764  |
#   |   3    | 0.13195243574990415 | 0.042172583174736274 |
#   |   4    | 0.12197928653624848 | 0.05050517131945731  |
#   |   5    |  0.1132336018411968 | 0.05741207149109594  |
#   |   6    | 0.10759493670886076 | 0.06521514927985568  |
#   |   7    |  0.1030741410488246 |  0.0716118350349495  |
#   |   8    | 0.09781357882623705 | 0.07569285101581115  |
#   |   9    | 0.09359416954353664 | 0.08406217910448034  |
#   |   10   | 0.09136939010356733 | 0.09052399137591097  |
#   +--------+---------------------+----------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+---------------------+-------+
#   | userId |         rmse        | count |
#   +--------+---------------------+-------+
#   | 58235  |  0.8698165954642829 |   15  |
#   | 113382 |  1.3647192645139528 |   2   |
#   | 87933  | 0.35585658110103946 |   1   |
#   | 171399 |  1.0649771063151041 |   2   |
#   | 160368 |  1.2932695028179781 |   13  |
#   | 23235  |  0.6461629307003678 |   95  |
#   | 24765  |  0.9037619054000743 |   12  |
#   | 10445  |  0.6930999296018971 |   5   |
#   | 239457 | 0.37018593261094346 |   2   |
#   | 176300 |  1.0764575789978517 |   3   |
#   +--------+---------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  0.6311361166404542 |   3   |
#   |    60   |  0.6282426780639474 |   1   |
#   |  54272  |  0.4087552134774138 |   3   |
#   |   2010  |  0.6410989241411057 |   3   |
#   |   5013  |  0.598181552053959  |   4   |
#   |  114935 |  0.4431515046027069 |   2   |
#   |   1672  |  0.4721043743974054 |   1   |
#   |  30825  | 0.08716097030967163 |   1   |
#   |   926   |  0.4098475823606921 |   3   |
#   |  105468 |   1.24229071740606  |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 0.8341533150194543},
#  {'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+---------------------+---------------------+-------+
#   | userId | cutoff |      precision      |        recall       | count |
#   +--------+--------+---------------------+---------------------+-------+
#   |  641   |   1    |         0.0         |         0.0         |   13  |
#   |  641   |   2    |         0.0         |         0.0         |   13  |
#   |  641   |   3    |  0.3333333333333333 | 0.07692307692307693 |   13  |
#   |  641   |   4    |         0.25        | 0.07692307692307693 |   13  |
#   |  641   |   5    |         0.2         | 0.07692307692307693 |   13  |
#   |  641   |   6    | 0.16666666666666666 | 0.07692307692307693 |   13  |
#   |  641   |   7    | 0.14285714285714285 | 0.07692307692307693 |   13  |
#   |  641   |   8    |        0.125        | 0.07692307692307693 |   13  |
#   |  641   |   9    |  0.1111111111111111 | 0.07692307692307693 |   13  |
#   |  641   |   10   |         0.1         | 0.07692307692307693 |   13  |
#   +--------+--------+---------------------+---------------------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+----------------------+----------------------+
#   | cutoff |      precision       |        recall        |
#   +--------+----------------------+----------------------+
#   |   1    | 0.08285385500575372  | 0.010459457775555478 |
#   |   2    |  0.0759493670886076  | 0.017859093620777238 |
#   |   3    |  0.0705792098197161  | 0.02282953939401662  |
#   |   4    | 0.06674338319907942  | 0.026358683025750593 |
#   |   5    | 0.06283084004602993  | 0.02905749544148363  |
#   |   6    | 0.058879938626774056 | 0.03318184004085632  |
#   |   7    | 0.056222258753904325 | 0.03620165004852546  |
#   |   8    | 0.055092059838895285 | 0.03967903365269228  |
#   |   9    | 0.052806546477432575 | 0.04392517668743154  |
#   |   10   | 0.05120828538550058  | 0.04593466829194138  |
#   +--------+----------------------+----------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+--------------------+-------+
#   | userId |        rmse        | count |
#   +--------+--------------------+-------+
#   | 58235  | 0.782587105759246  |   15  |
#   | 113382 | 0.8102802662967358 |   2   |
#   | 87933  | 0.0643234928154639 |   1   |
#   | 171399 | 0.8203104851057409 |   2   |
#   | 160368 | 1.058922351723617  |   13  |
#   | 23235  | 0.5660119440479862 |   95  |
#   | 24765  | 1.6199239760314512 |   12  |
#   | 10445  | 0.5607260850196215 |   5   |
#   | 239457 | 0.6729485364612148 |   2   |
#   | 176300 | 0.9655351544332494 |   3   |
#   +--------+--------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  0.5068755870504359 |   3   |
#   |    60   |  0.7860258584631801 |   1   |
#   |  54272  |  0.605879118725022  |   3   |
#   |   2010  |  0.5573946158935732 |   3   |
#   |   5013  |  0.5960207139940351 |   4   |
#   |  114935 |  0.6196910456796059 |   2   |
#   |   1672  |  0.703715120942344  |   1   |
#   |  30825  | 0.08786808249514699 |   1   |
#   |   926   |  0.3942134299808449 |   3   |
#   |  105468 |  0.9133565503194725 |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 0.7840351187047724},
#  {'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+-----------+--------+-------+
#   | userId | cutoff | precision | recall | count |
#   +--------+--------+-----------+--------+-------+
#   | 34527  |   1    |    0.0    |  0.0   |   1   |
#   | 34527  |   2    |    0.0    |  0.0   |   1   |
#   | 34527  |   3    |    0.0    |  0.0   |   1   |
#   | 34527  |   4    |    0.0    |  0.0   |   1   |
#   | 34527  |   5    |    0.0    |  0.0   |   1   |
#   | 34527  |   6    |    0.0    |  0.0   |   1   |
#   | 34527  |   7    |    0.0    |  0.0   |   1   |
#   | 34527  |   8    |    0.0    |  0.0   |   1   |
#   | 34527  |   9    |    0.0    |  0.0   |   1   |
#   | 34527  |   10   |    0.0    |  0.0   |   1   |
#   +--------+--------+-----------+--------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+----------------------+
#   | cutoff |      precision      |        recall        |
#   +--------+---------------------+----------------------+
#   |   1    | 0.19447640966628307 | 0.023098742849629483 |
#   |   2    |  0.1703107019562716 | 0.03680390129909975  |
#   |   3    |  0.1530494821634061 | 0.050598854537636365 |
#   |   4    | 0.14326812428078242 | 0.06189967892307537  |
#   |   5    | 0.13578826237054106 | 0.07105457350342488  |
#   |   6    | 0.13233601841196785 | 0.08275900791574135  |
#   |   7    | 0.12691106361992438 | 0.09285251577935796  |
#   |   8    | 0.12111622554660532 | 0.09954188026258252  |
#   |   9    | 0.11724843370412993 | 0.10881715991051603  |
#   |   10   | 0.11254315304948219 | 0.11449636884892019  |
# ...
#   | 236625 |   3    |  0.3333333333333333 | 0.038461538461538464 |   26  |
#   | 236625 |   4    |         0.25        | 0.038461538461538464 |   26  |
#   | 236625 |   5    |         0.2         | 0.038461538461538464 |   26  |
#   | 236625 |   6    | 0.16666666666666666 | 0.038461538461538464 |   26  |
#   | 236625 |   7    | 0.14285714285714285 | 0.038461538461538464 |   26  |
#   | 236625 |   8    |        0.125        | 0.038461538461538464 |   26  |
#   | 236625 |   9    |  0.1111111111111111 | 0.038461538461538464 |   26  |
#   | 236625 |   10   |         0.1         | 0.038461538461538464 |   26  |
#   +--------+--------+---------------------+----------------------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+---------------------+
#   | cutoff |      precision      |        recall       |
#   +--------+---------------------+---------------------+
#   |   1    | 0.21058688147295743 | 0.02656585190504315 |
#   |   2    | 0.18239355581127734 | 0.04260841430884852 |
#   |   3    | 0.16148830072880715 | 0.05446683773273367 |
#   |   4    | 0.14700805523590338 | 0.06583626132397045 |
#   |   5    | 0.14292289988492526 | 0.07577899930087939 |
#   |   6    |  0.1344457230533179 | 0.08312343425469902 |
#   |   7    | 0.13052770014795329 |  0.0956147272017569 |
#   |   8    | 0.12356156501726129 |  0.1017756149871728 |
#   |   9    | 0.11852704257767543 | 0.10704272387679147 |
#   |   10   |  0.1149597238204833 | 0.11608408325988889 |
#   +--------+---------------------+---------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+----------------------+-------+
#   | userId |         rmse         | count |
#   +--------+----------------------+-------+
#   | 58235  |   0.68420689192243   |   15  |
#   | 113382 |  1.2510775125912545  |   2   |
#   | 87933  | 0.040055314696678224 |   1   |
#   | 171399 |  1.0212712479307229  |   2   |
#   | 160368 |  1.637772925545992   |   13  |
#   | 23235  |  0.9087154997993083  |   95  |
#   | 24765  |  1.3346534758349116  |   12  |
#   | 10445  |  0.8579246783305525  |   5   |
#   | 239457 |  1.3927235799609627  |   2   |
#   | 176300 |  1.0947973250390355  |   3   |
#   +--------+----------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  1.2072110972908296 |   3   |
#   |    60   |  0.8667052896769376 |   1   |
#   |  54272  | 0.48478408884848356 |   3   |
#   |   2010  |  1.0028641543076153 |   3   |
#   |   5013  |  0.7157570801001137 |   4   |
#   |  114935 |  0.8717673712982908 |   2   |
#   |   1672  |  0.5475074070647636 |   1   |
#   |  30825  | 0.28061052073641335 |   1   |
#   |   926   |  0.3333677831164237 |   3   |
#   |  105468 |  1.1563009396149826 |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 1.039848736972919},
#  {'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+---------------------+----------------------+-------+
#   | userId | cutoff |      precision      |        recall        | count |
#   +--------+--------+---------------------+----------------------+-------+
#   | 236625 |   1    |         1.0         | 0.038461538461538464 |   26  |
#   | 236625 |   2    |         0.5         | 0.038461538461538464 |   26  |
#   | 236625 |   3    |  0.3333333333333333 | 0.038461538461538464 |   26  |
#   | 236625 |   4    |         0.25        | 0.038461538461538464 |   26  |
#   | 236625 |   5    |         0.2         | 0.038461538461538464 |   26  |
#   | 236625 |   6    | 0.16666666666666666 | 0.038461538461538464 |   26  |
#   | 236625 |   7    | 0.14285714285714285 | 0.038461538461538464 |   26  |
#   | 236625 |   8    |        0.125        | 0.038461538461538464 |   26  |
#   | 236625 |   9    |  0.1111111111111111 | 0.038461538461538464 |   26  |
#   | 236625 |   10   |         0.1         | 0.038461538461538464 |   26  |
#   +--------+--------+---------------------+----------------------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+----------------------+
#   | cutoff |      precision      |        recall        |
#   +--------+---------------------+----------------------+
#   |   1    |  0.1749136939010357 | 0.021966928161557108 |
#   |   2    | 0.15650172612197927 | 0.036803305688598825 |
#   |   3    |  0.1446106635980054 | 0.04676784314116212  |
#   |   4    | 0.13665132336018412 | 0.05966239473198264  |
#   |   5    | 0.12888377445339474 | 0.06971412201448574  |
#   |   6    | 0.12255466052934405 | 0.08002629667934769  |
#   |   7    | 0.11688311688311695 | 0.08851177783942146  |
#   |   8    | 0.11104718066743383 | 0.09533159482086948  |
#   |   9    |  0.1067638409410561 |  0.1010532806511036  |
#   |   10   | 0.10218642117376298 | 0.10555219941035969  |
#   +--------+---------------------+----------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+---------------------+-------+
#   | userId |         rmse        | count |
#   +--------+---------------------+-------+
#   | 58235  |  0.6031676837258625 |   15  |
#   | 113382 |  0.9071486084122289 |   2   |
#   | 87933  | 0.22835477318092634 |   1   |
#   | 171399 |  0.910710357232479  |   2   |
#   | 160368 |  1.4845103656297987 |   13  |
#   | 23235  |  0.9277622517616063 |   95  |
#   | 24765  |  1.1838711163455051 |   12  |
#   | 10445  |  0.6856866852178165 |   5   |
#   | 239457 |  0.7689967606753203 |   2   |
#   | 176300 |  0.9052297542645157 |   3   |
#   +--------+---------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  1.080435459971094  |   3   |
#   |    60   |  0.9979502271184137 |   1   |
#   |  54272  |  0.9117900653225545 |   3   |
#   |   2010  |  0.9220528436265791 |   3   |
#   |   5013  |  0.8029992326997986 |   4   |
#   |  114935 |  0.8616998887628975 |   2   |
#   |   1672  |  0.8436519449489177 |   1   |
#   |  30825  | 0.09491690474804404 |   1   |
#   |   926   |  0.740159935712348  |   3   |
#   |  105468 |  1.4768602809991753 |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 1.0935056720378475},
#  {'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+---------------------+---------------------+-------+
#   | userId | cutoff |      precision      |        recall       | count |
#   +--------+--------+---------------------+---------------------+-------+
#   |  641   |   1    |         1.0         | 0.07692307692307693 |   13  |
#   |  641   |   2    |         0.5         | 0.07692307692307693 |   13  |
#   |  641   |   3    |  0.3333333333333333 | 0.07692307692307693 |   13  |
#   |  641   |   4    |         0.25        | 0.07692307692307693 |   13  |
#   |  641   |   5    |         0.2         | 0.07692307692307693 |   13  |
#   |  641   |   6    | 0.16666666666666666 | 0.07692307692307693 |   13  |
#   |  641   |   7    | 0.14285714285714285 | 0.07692307692307693 |   13  |
#   |  641   |   8    |        0.125        | 0.07692307692307693 |   13  |
#   |  641   |   9    |  0.1111111111111111 | 0.07692307692307693 |   13  |
#   |  641   |   10   |         0.1         | 0.07692307692307693 |   13  |
#   +--------+--------+---------------------+---------------------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+----------------------+
#   | cutoff |      precision      |        recall        |
#   +--------+---------------------+----------------------+
#   |   1    | 0.11737629459148446 | 0.012371871420150093 |
#   |   2    | 0.11047180667433831 | 0.024275858332987735 |
#   |   3    | 0.10164940544687383 | 0.03557530081138967  |
#   |   4    |  0.1001150747986191 | 0.046600820726017164 |
#   |   5    |  0.0959723820483314 | 0.052903404105700796 |
#   |   6    | 0.09205983889528194 | 0.05940077893862578  |
#   |   7    | 0.08729245438106198 | 0.06466827748316875  |
#   |   8    | 0.08573072497123128 | 0.07517604555055406  |
#   |   9    | 0.08477176831607212 | 0.08429604720459825  |
#   |   10   | 0.08239355581127734 | 0.09074564357179693  |
#   +--------+---------------------+----------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+--------------------+-------+
#   | userId |        rmse        | count |
#   +--------+--------------------+-------+
#   | 58235  | 0.7510061615427329 |   15  |
#   | 113382 | 0.9106351815869632 |   2   |
#   | 87933  | 0.3476107150210632 |   1   |
#   | 171399 | 1.387615189890029  |   2   |
#   | 160368 | 1.2697236283476931 |   13  |
#   | 23235  | 0.7712206763016184 |   95  |
#   | 24765  | 1.5284566523934144 |   12  |
#   | 10445  | 0.6867076398666897 |   5   |
#   | 239457 | 1.432063599116111  |   2   |
#   | 176300 | 0.7351241054227353 |   3   |
#   +--------+--------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  0.9845359690114656 |   3   |
#   |    60   |  0.8300819557247907 |   1   |
#   |  54272  |  0.6199882757099784 |   3   |
#   |   2010  |  0.6826418620213167 |   3   |
#   |   5013  |  0.8384833750668395 |   4   |
#   |  114935 |  0.8857178799368334 |   2   |
#   |   1672  |  0.2107244164494091 |   1   |
#   |  30825  |  0.2664121081829207 |   1   |
#   |   926   | 0.31276313389925764 |   3   |
#   |  105468 |  1.3830844744707744 |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 0.9012848958267099},
#  {'precision_recall_by_user': Columns:
#   	userId	int
#   	cutoff	int
#   	precision	float
#   	recall	float
#   	count	int
#
#   Rows: 15642
#
#   Data:
#   +--------+--------+-----------+--------+-------+
#   | userId | cutoff | precision | recall | count |
#   +--------+--------+-----------+--------+-------+
#   | 237350 |   1    |    0.0    |  0.0   |   8   |
#   | 237350 |   2    |    0.0    |  0.0   |   8   |
#   | 237350 |   3    |    0.0    |  0.0   |   8   |
#   | 237350 |   4    |    0.0    |  0.0   |   8   |
#   | 237350 |   5    |    0.0    |  0.0   |   8   |
#   | 237350 |   6    |    0.0    |  0.0   |   8   |
#   | 237350 |   7    |    0.0    |  0.0   |   8   |
#   | 237350 |   8    |    0.0    |  0.0   |   8   |
#   | 237350 |   9    |    0.0    |  0.0   |   8   |
#   | 237350 |   10   |    0.0    |  0.0   |   8   |
#   +--------+--------+-----------+--------+-------+
#   [15642 rows x 5 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'precision_recall_overall': Columns:
#   	cutoff	int
#   	precision	float
#   	recall	float
#
#   Rows: 18
#
#   Data:
#   +--------+---------------------+----------------------+
#   | cutoff |      precision      |        recall        |
#   +--------+---------------------+----------------------+
#   |   1    | 0.13693901035673198 | 0.019544646458641506 |
#   |   2    | 0.12715765247410812 | 0.02807181197335183  |
#   |   3    | 0.11891062523973914 | 0.03670859205709441  |
#   |   4    |  0.1119102416570771 | 0.04602102623584431  |
#   |   5    | 0.10794016110471807 | 0.055678871977325003 |
#   |   6    |  0.104909858074415  | 0.06491541993854065  |
#   |   7    | 0.10126582278481018 | 0.07553386823888378  |
#   |   8    | 0.09853279631760645 | 0.08486002759316164  |
#   |   9    | 0.09640710906533699 | 0.09213838751553513  |
#   |   10   | 0.09286536248561562 | 0.09620131763041513  |
#   +--------+---------------------+----------------------+
#   [18 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_user': Columns:
#   	userId	int
#   	rmse	float
#   	count	int
#
#   Rows: 869
#
#   Data:
#   +--------+----------------------+-------+
#   | userId |         rmse         | count |
#   +--------+----------------------+-------+
#   | 58235  |  0.6636011324393557  |   15  |
#   | 113382 |  1.303659771777302   |   2   |
#   | 87933  | 0.025856941442409465 |   1   |
#   | 171399 |  0.9134020794948031  |   2   |
#   | 160368 |  1.4781310572945614  |   13  |
#   | 23235  |  1.0051986926180931  |   95  |
#   | 24765  |  1.8879313812689476  |   12  |
#   | 10445  |  0.8333027501203264  |   5   |
#   | 239457 |  1.3177314611056492  |   2   |
#   | 176300 |  0.5891293745277761  |   3   |
#   +--------+----------------------+-------+
#   [869 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_by_item': Columns:
#   	movieId	int
#   	rmse	float
#   	count	int
#
#   Rows: 2974
#
#   Data:
#   +---------+---------------------+-------+
#   | movieId |         rmse        | count |
#   +---------+---------------------+-------+
#   |   1343  |  1.0595347947200455 |   3   |
#   |    60   |  1.0777188808618816 |   1   |
#   |  54272  | 0.49729120054768566 |   3   |
#   |   2010  |  0.9308271111937259 |   3   |
#   |   5013  |  1.143825252822015  |   4   |
#   |  114935 |  1.1797856695860724 |   2   |
#   |   1672  |  1.190204482466017  |   1   |
#   |  30825  |  0.5538900072543993 |   1   |
#   |   926   |  1.265575462666627  |   3   |
#   |  105468 |  1.603839275555028  |   1   |
#   +---------+---------------------+-------+
#   [2974 rows x 3 columns]
#   Note: Only the head of the SFrame is printed.
#   You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
#   'rmse_overall': 1.1924186935565633}]

# %% [markdown]
# The following table is a combination of all models tested, which we have passed through our get_metrics function.  The results are concatenated into a pandas dataframe called **final_results**, and sorted by F1 score descending to show the best performing models by way of balanced precision and recall.  It shows the calculations for each cutoff (the number of movies recommended by our algorithms).

# %%
final_results = pd.concat([
    get_metrics(base_eval,'base'),
    get_metrics(user_min_eval,'user_min'),
    get_metrics(user_large_eval,'user_large'),
    get_metrics(base_model_rr01_eval,'base_model_rr01'),
    get_metrics(base_model_rr05_eval,'base_model_rr05'),
    get_metrics(base_model_rr0_eval,'base_model_rr0'),
    get_metrics(base_model_rr1_eval,'base_model_rr1'),
    get_metrics(item_item_eval,'item_item_eval'),
    get_metrics(base_model_rr05_nsne16_eval,'base_model_rr05_nsne16'),
    get_metrics(base_model_rr05_nsne8_eval,'base_model_rr05_nsne8'),
    get_metrics(base_model_rr0_nsne8_eval,'base_model_rr0_nsne8'),
    get_metrics(user_prefs_min_plus_eval,'user_prefs_min_plus')]

).sort_values('F1', ascending=False)

final_results.head(15)
# Out:
#     cutoff  Avg of precision  Stdv of precision  Avg of recall  \
# 4       10          0.171692           0.201843       0.209624
# 5       11          0.164557           0.193663       0.219280
# 7        9          0.177854           0.208992       0.197802
# 11       8          0.185702           0.219151       0.187965
# 16      16          0.140967           0.169206       0.260462
# 16      16          0.097022           0.139495       0.157020
# 17      21          0.088060           0.125055       0.184096
# 5       11          0.110367           0.160189       0.122835
# 4       10          0.114960           0.167516       0.116084
# 5       11          0.109007           0.157687       0.122191
# 1       26          0.080552           0.115158       0.201889
# 16      16          0.093570           0.134647       0.149181
# 4       10          0.112543           0.164633       0.114496
# 7        9          0.117248           0.171874       0.108817
# 17      21          0.083950           0.121756       0.170703
#
#     Stdv of recall        F1                  Model      RMSE
# 4         0.268282  0.188771         item_item_eval  4.366866
# 5         0.272619  0.188017         item_item_eval  4.366866
# 7         0.261897  0.187299         item_item_eval  4.366866
# 11        0.258270  0.186826         item_item_eval  4.366866
# 16        0.291217  0.182929         item_item_eval  4.366866
# 16        0.225471  0.119936  base_model_rr05_nsne8  1.039849
# 17        0.240307  0.119133  base_model_rr05_nsne8  1.039849
# 5         0.198246  0.116268  base_model_rr05_nsne8  1.039849
# 4         0.193643  0.115519  base_model_rr05_nsne8  1.039849
# 5         0.197233  0.115223         base_model_rr1  1.082633
# 1         0.245926  0.115158  base_model_rr05_nsne8  1.039849
# 16        0.216075  0.115006         base_model_rr1  1.082633
# 4         0.191050  0.113511         base_model_rr1  1.082633
# 7         0.185781  0.112876         base_model_rr1  1.082633
# 17        0.229216  0.112549         base_model_rr1  1.082633

# %% [markdown]
# Sorting the final results by RMSE shows that base model with ranking_regularization = 0 yields the lowest RMSE score.

# %%
final_results.nsmallest(3, "RMSE")
# Out:
#     cutoff  Avg of precision  Stdv of precision  Avg of recall  \
# 16      16          0.044663           0.090926       0.066268
# 1       26          0.037886           0.073792       0.086723
# 13      31          0.035599           0.067462       0.099916
#
#     Stdv of recall        F1           Model      RMSE
# 16        0.150057  0.053362  base_model_rr0  0.784035
# 1         0.165749  0.052735  base_model_rr0  0.784035
# 13        0.181841  0.052495  base_model_rr0  0.784035

# %% [markdown]
# # Modeling and Evaluation 3 - Visualization of Evaluation Metrics

# %% [markdown]
# ## Precision vs Recall Curves (Comparison)
#
# This shows precision vs recall from our 12 models obtained from hyperparameter tunning.
# Ranking Regularization is the hyperparameter that is tuned with different values [1,0,0.1,0.5]. This hyperparameter was tuned to build different user-item based recommender and precision recall were plotted below.

# %%
plt.figure(figsize=(15, 9))
sns.set_context("talk")
sns.set_style("dark")
sns.lineplot(y="Avg of recall", x="Avg of precision",
             hue="Model", 
             data=final_results).set_title("Precision vs Recall by Model")
plt.show()

# %% [markdown]
# ### F1 Score Vs Cutoff by Model
#
# This plot shows performance of models using different metric F1 Score Vs CutOff. F1 score uses overall aggregate average precision and recall and
# cut off is maximum number of movies that were recommended by these different recommenders.

# %%
plt.figure(figsize=(20, 5))
sns.set_context("talk")
sns.set_style("dark")
sns.lineplot(x="cutoff", y="F1",
             hue="Model", 
             data=final_results).set_title("F1 Score vs Cutoff by Model")

plt.show()

# %% [markdown]
# ### Recall Vs Cut off by Model
#
# This plot shows performance of models using different metric Recall Vs CutOff. Recall attempts to measure the number of movies recommended by our algorithm that the user rated positively.
# and cut off is maximum number of movies that were recommended by these different recommenders.

# %%
plt.figure(figsize=(20,7))
sns.set_context("talk")
sns.set_style("dark")
sns.lineplot(x="cutoff", y="Avg of recall",
             hue="Model", 
             data=final_results).set_title("Recall vs Cutoff by Model")
plt.show()

# %% [markdown]
# ### Precision vs Cutoff by Model
#
# This plot shows performance of models using different metric Precision Vs CutOff. Precision attempts to measure the number of positively rated movies by the user which were found by the recommender.
# and cut off is maximum number of movies that were recommended by these different recommenders.

# %%
plt.figure(figsize=(18, 7))
sns.set_context("talk")
sns.set_style("dark")
sns.lineplot(x="cutoff", y="Avg of precision",
             hue="Model", 
             data=final_results).set_title("Precision vs Cutoff by Model")

plt.show()

# %% [markdown]
# ## Overall RMSE by Model

# %% [markdown]
# This plot is quite interesting, the RMSE for the class leading item-item model (by F-1 score) is *abysmal* by comparison in RMSE.  The base_model with ranking-regularization parameter setting of 0 actually has the best performance for predicting user ratings.

# %%
plt.figure(figsize=(15, 7))
sns.set_context("talk")
sns.set_style("dark")
ax = sns.barplot(y="Model", x="RMSE",
             data=final_results.sort_values('RMSE'))
for p in ax.patches:
    _x = p.get_x() + p.get_width() + .01
    _y = p.get_y() + p.get_height() -.2
    value = '{:4.3f}'.format(p.get_width())
    ax.text(_x, _y, value, ha="left")
ax.set_title("Overall RMSE by Model")

plt.show()

# %% [markdown]
# ### User RMSE by model
# Below are three plots for the base user-item model, the item-item model, and the lowest RMSE model found in hypertuning.
#
# In the plots below, the x-axis shows the user RMSE score, and the y-axis is the frequency by which it occurs.  These plots display a measure of RMSE for each user and for each binned RMSE value, how many users had movie predictions errors (RMSE) by the displayed amount on average for all rated movies.
#
# The base model performs admirably with no additional tuning, it sits approximately in the middle, performance-wise in RMSE between the best and worst performing models which came out of parameter tuning.

# %% [markdown]
# ### Item-Item model

# %%
# %matplotlib inline
plt.style.use('ggplot')

rmsevals = item_item_eval['rmse_by_user']['rmse']

plt.hist(rmsevals,bins=20)
plt.title('RMSE by User (Item-Item Model)')
plt.show()

# %% [markdown]
# ### User-Item Base Model

# %%
# %matplotlib inline
plt.style.use('ggplot')

rmsevals = base_eval['rmse_by_user']['rmse']

plt.hist(rmsevals,bins=20)
plt.title('RMSE by User (Base Model)')
plt.show()

# %% [markdown]
# ### User-Item Model (Minimum RMSE)

# %%
# %matplotlib inline
plt.style.use('ggplot')

rmsevals = base_model_rr0_eval['rmse_by_user']['rmse']

plt.hist(rmsevals,bins=20)
plt.title('RMSE by User (Base Model rr0)')
plt.show()

# %% [markdown]
# # Modeling and Evaluation 4 - In Summary

# %% [markdown]
# We have collected a vast amount of movie and user rating data, cleaned it, transformed it, visualized key points and trends.  We compared 3 different recommender models, conducted hypertuning on the explicit user-item recommender model, and evaluated the performance of 12 various models.  Some key observations from analyzing our results are as follows:
#
# * Calculating Precision and Recall scores is not intuitive for this use case, we must think about these evaluation metrics differently than their use in classification algorithms.  In our movie recommendation scenario, each user will likely only rate a handful of movies, out of the possible population of 45,000+ movies in our database. Given larger cutoff values (i.e. number of recommended movies), we should expect precision and recall to improve as the pool of recommended movies increases relative to the static number of movies rated by the user.
#
#
# * RMSE and Precision/Recall/F1 metrics measure different use cases of the recommender:
#     * **RMSE** measures *how accurately can we predict user preferences for a given movie (i.e. what will this user rate this movie?)*
#     * **F1** measures *how often can we recommend movies the user will like? (i.e. unseen movies we think the user will rate highly)*
#
#
# * Incorporating item information can improve performance of our recommendations, but at the expense of run time.  Our base model runs in approximately 7-8 minutes using the full 45,000 movies and 26 million ratings.  Adding in just the movie collection and genre resulted in marginal improvements, with marginal increase in time (an additional 3-5 minutes, total).  Adding in actors, directors, producers, age of the movie, and language information resulted in another marginal improvment in performance, but resulted in a very large increase in training time requiring approximately 90 minutes (over 10 time as long as the base model.)
#
#
# * The item-item recommender performs significantly better than the user-item recommender in Precision/Recall scores, but suffers greatly in RMSE.  Conversely, the user-item recommender is MUCH better at accurately predicting user ratings for unseen movies (RMSE scores < 1, while item-item RMSE is consistently >3).

# %% [markdown]
# ### RMSE vs F-1 (precision and recall)
#
# We see somewhat of an inverse relationship between RMSE performance and Precision/Recall performance.  Our final_results dataframe shows us that the highest F-1 score (good) also has the highest RMSE (bad), and the model with the lowest RMSE (good) also has a poor F-1 score (bad).  This trade-off must be considered when implementing a model in a production environment.  **A low RMSE score can more accurately predict a user's sentiment on a movie, but may not be the best choice for recommending a movie that a user would like.**

# %% [markdown]
# ### Precision vs Recall
#
# First plot in Modeling and evaluation 3 section is plot for Precision Vs recall from 12 models obtained from hyperparameter tunning.
# Ranking Regularization is the hyperparameter that is tuned with different values [1,0,0.1,0.5]. This hyperparameter was tuned to build different user-item based recommender and precision recall was plotted and following are the observations
# 1. Item based recommender performs extremely well with precision of Avg 0.185702 and Avg recall of 0.187965 which is higher than any
#    other model and it is clearly visible on the extreme right of the plotted.
# 2. All base models i.e. user-item models with different raking parameters with and without any side data varies between 0.04 and 0.12.
#    which is lower than item-item models and indicates item-item performs much better.
# 3. user-item model with min or just one side data with ranking parameter 0 performs very poorly.
# 4. user-item model with multiple (large) side items performs with ranking parameter little better than base user-item model.
#
# **In summary, our Item-Item model performs quite well on precision and recall metric.**

# %% [markdown]
# ### F1 Score Vs Cutoff by Model
#
# This plot shows performance of models using different metric F1 Score Vs CutOff. F1 score uses overall aggregate average precision and recall and
# cut off is maximum number of movies that were recommended by these different recommenders.
# Following are observations from the plot
# 1. As hyperparameter value increases base model performs litter better on F1 score. It performs worst when this parameter is zero
#    performs same on all different cut offs set for models i.e. from 15 to 40
# 2. user-item model with min side data (just 1 side item information) performs poorly compared to user-item model with multiple side item data.
# 3. Here also item-item model seen to be performing exteremly well compared to user-item model.
#
# **In summary, Item-Item model performs quite well on F1 score vs cutoff as well for cut offs from 5 to 18**

# %% [markdown]
# ### Recall Vs Cut off by Model
#
# This plot shows performance of models using different metric Recall Vs CutOff. Recall attempts to measure the number of movies recommended by our algorithm that the user rated positively.
# and cut off is maximum number of movies that were recommended by these different recommenders.
# Following are observations from the plot
# 1. As hyperparameter value increases base model performs litter better on Recall score.
#    It performs worst when this parameter is zero with cutoff from from 15 to 40.
# 2. user-item model with min side data (just 1 side item information) performs poorly compared to user-item model with multiple side item data.
# 3. Here also item-item model seen to be performing extremely well compared to user-item model.
#
# **In summary again , Item-Item model performs quite well on Recall vs cutoff.**

# %% [markdown]
# ### Precision Vs Cut off by Model
#
# This plot shows performance of models using different metric Precision Vs CutOff. Precision attempts to measure the number of positively rated movies by the user which were found by the recommender.
# and cut off is maximum number of movies that were recommended by these different recommenders.
# Following are observations from the plot
# 1. As hyperparameter value increases base model performs litter better on Precision score.
#    It performs worst when this parameter is zero with cutoff from from 15 to 40.
# 2. user-item model with min side data (just 1 side item information) performs poorly compared to user-item model with multiple side item data.
# 3. Here also item-item model seen to be performing extremely well compared to user-item model.
#
# **In summary again , Item-Item model performs quite well on Precision vs cutoff.
# The key takeway from Precision Recall plots is that Item-Item peforms well on thes metric while User-Item performs poorly.**

# %% [markdown]
# ### Challenges of collaborative filters
# Some of the drawbacks of the collaborative filters are:
#
# ##### Sparsity
# As we saw in above section, The dataset we are using has long tail which indicates few movies are extremely
# popular. It means this data is hugely sparse and not many users rate movies or write feedback and it makes difficult to find neighbor.
#
# ##### Gray Sheep
# Users who don't have individual tastes resembling other users, sometimes gray sheep can be helped by abstracting the content into genres.
#
# ##### Number of ratings
# New items/Movies don't have ratings at the beginning and hence it becomes difficult to recommend such items to users.  This is sometimes described as the new user problem, and is frequently mitigated by collecting user preference during registration.
#
# ##### Similarity
# This is one of the problems with collaborative filters. The system looks for similar users based on their behavior or habit of watching particular types of movies or product.  This creates a type of popularity bias, and can develop a pattern of recommending the most popular items more often.

# %% [markdown]
# ### Which recommendation system is better?
# When choosing between the implementation of a user-based and an item-based neighborhood recommender system,
# following five criteria's are important: [7]
#
# ##### Accuracy
# In cases of user based methods, Accuracy depends on ratio of the number of users and numbers of items. User similarity is based on ratings made by users on the similar items. So when if number of users exceeds the number of items, its quite difficult to achieve highest accuracy as every user has different likes and dislikes. The matrix of user-user similarity becomes sparse and nearest neighbor algorithm performs poor.
#
# Item-item based models usually compute similarity by comparing ratings made by same user on the items. So if a user has watched/liked/rated comedy movie then it is highly likely that he will get another comedy movie in recommendations list.  The more dense the matrix, the more accurate nearest neighbor algorithm will work.
#
# *In the case of movie recommender system, item-item based recommenders looks more preferable.*
#
# ##### Efficiency
# Memory and computational efficiency of the recommender system also depends on ratio between number of users and number of items.  When number of users exceeds the number of items which is often the case, item based recommenders requires much less memory and time to compute similarity between items.
#
# *Again, In case of movie recommender system item-item based recommenders looks more preferable.*
#
# ##### Stability
# Stability of the model largely depends on how frequently user or item information gets updated in the system. In case of movie recommender, information about the movies is fairly static compared to user's information.
#
# *From a stability point of view Item-based recommnders looks more appropriate.*
#
# ##### Justifiability
# One of the big advantages of item-based recommenders is they can be easily used to justify recommendation. Items presented to user as recommendations can be changed by asking user to participate in the recommendation process. For example: by giving users the ability to change his or her preferences, thereby changing its nearest neighbors. This is highly unlikely with user-user recommender systems as two users do not typically have interaction (in the system) with each other.
#
# ##### Serendipity
# In item-based methods, the rating predicted for an item is based on the ratings given to similar items. Consequently, recommender systems using this approach will tend to recommend to a user items that are related to those usually appreciated by this user. For instance, in a movie recommendation application, movies having the same genre, actors or director as those highly rated by the user are likely to be recommended. While this may lead to safe recommendations, it does less to help the user discover different types of items that he might like as much.
#
# Because they work with user similarity, on the other hand, user-based approaches are more likely to make serendipitous recommendations. This is particularly true if the recommendation is made with a small number of nearest- neighbors. For example, a user A that has watched only comedies may be very similar to a user B only by the ratings made on such movies. However, if B is fond of a movie in a different genre, this movie may be recommended to A through his similarity with B.

# %% [markdown]
# # Deployment

# %% [markdown]
# ## Pre-Production Considerations
#
# ##### How accurate is our model?
#
# The RMSE is a measure of how concentrated the data is around the line of best fit for a model. In other words, the RMSE measures the distance between values predicted by a model and the values observed. A smaller RMSE represent a better a better fit.  RMSE is the most important criterium for our model because the model's main purpose is to predict user's movie preferences and it provides a true picture of the quality of the predictions. The accuracy of our model determines the effectiveness of the movie's recommender system.  Based on the evaluation the of the different models the base model with ranking_regularization = 0 yields the lowest RMSE score with an accuracy of approximately 78% (0.784035). This would be the best model for predicting movies the user is most likely to rate high.
#
# We are using F1 score for evaluating this multiclass classification model. The final score is obtained using macro-averaging (taking all classes as equally important), using the arithmetic mean of class-wise F-scores.
# Based on F1 score 0.188771, the Item-Item model is the best model to predict what a viewer will like. This makes the Item-Item model the most accurate in providing recommendations based on a viewer's preferences.
#
# ##### New user problem:
#
# One of the problems of this model is how to provide recommendations for a new user. Some of the proposed ideas include set the default initial recommendations based of a few criterium composed on:
#
# **Highest rated movies by density**
#
# The data suggest a viewer's bias towards more frequently rating movies with high score. In this data set movies with a rating of 4.0 received a rating from 26% of the viewers. This is important because getting users to rate movies or programs has proven to be an industry challenge. We can speculate about the reasons for users providing a rating for movies that have higher ratings. Some of our hypothesis include that the viewers may be more inclined to rate a movie when they feel it was good and hesitate to rate a movie when it is not so good. It is also possible that movies that receive a high rating by viewers are more though after, referred or spark the interest on potential viewers in watching it and subsequently rating it. This practice turns into a cycle or hype for a period. It is also noticeable that series tend to have higher rating. Series tend to inspire higher loyalty and therefore more ratings.
#
# **Highest rated movies this year**
#
# This value can be chosen based on multiple factors:
# * Actors with the most movies
# * Genres with the most movies
# * Directors with the most movies
# * Producers with the most movies
# * Collections with the most movies
# * Original Languages with the most movies
# * Spoken Languages with the most movies
# * Highest rated movies by TMDB user votes
#
# Drama has by far the highest rating, followed by comedy, thriller, romance, and action.
#
# ##### What additional info to collect?
#
# One additional parameter that could be collected or recorded in the database is whether the user finished watching a movie or not. This new information could assist in indirectly assessing if a user liked a movie enough to watch it until the end. This can complement the predictions based on user's ratings and contribute to enhance the model's accuracy. Additionally, it is important that the recommender system does not recommend movies that the user saw recently. For that purpose, the database must include information that identify the date when a rating occurred, or when a movie was last watched.
#
# What trailers user has watched. Given the short length of a trailer, information about whether the user finished watching a trailer may not directly contribute to improve the predictive power of a model. However, it may be a good complement when combined with genre. This would require feature engineering and testing.
#
# * User preferences should be recorded as an initial parameter when a new user creates a profile. However, the user can update parameter over time.
# * A user's device can have a significant impact on his viewing experience and rating. The user's device should be recorded and taken into consideration when creating the model.
# * User's profile could include some sensitive data like PII (name, age, location) for this application it is recommended to minimize the risk of exposure by collecting less precise information (i.e. firs name only, age group, region).
# * The time of day when the user watches movies can inform user habits and there may be a correlation between a user's watching patterns and his or her preferences.
#
# ##### How to deploy:
#
# The movies database and user preferences constitute a large database ~ 900 Megabytes and likely will continue to expand into the Gigabyte. To improve performance and enhance availability by region, it is best to deploy this database to a cloud provider like AWS or Google cloud.
#
# Creating the initial model is facilitated by having this large database deployed to the cloud. The trained models will be saved to the cloud provider, along with the database, in this case we used AWS S3.
#
# The database is frequently updated based on user's interactions. Therefore, a new model must be created and trained to provide accurate predictions. It is recommended that this new model be created, trained, and deployed at least every night.

# %% [markdown]
# ## Conclusion
#
# Online media companies are always looking to improve their products by making it personable to their users by having a robust recommendation system. As users use their product, the recommendation system becomes more and more effective in achieving this goal. When a new user is introduced into this system, there is a possibility for the recommendation system to recommend poorly because there are no historic or preference data for this new user. There could be some way for the recommendation system to make a useful recommendation by requesting a user to pick a preference when they sign up and then from there collect the necessary data for that user.  The recommendation system could just recommend highest rated movies by density for each category or highest rated movies at a certain period. The system could also have trailers available for new users and can recommend movies similar to the trailers successfully watched by the new user.
#
# There would always be limitations in a recommendation system because every user is unique and the system can’t always generate perfect results but can do a good job of pairing similar users based on their ratings and other features. In reality, recommendation systems do not set a threshold when looking for compatibility between people; they look for the best possible match. If we have a user, Dustin, who has a 95% compatibility with Ike, 80% with Edgar, and 30% with Sachin, the system will start by looking at Ike when deciding if Dustin will like a certain movie. The more users we have in the data set, the more likely it is that a person with a high compatibility will give a response that the system can leverage.
#
# For data collection, we would implement a system that would collect user preferences, trailers watched. User devices, user profiles, different times the users accounts are accessed etc. The interest in access times and users devices is to track the potential of having 2 users with one account and 2 devices or one device but access at a specific time of the day. Having one account and one device might be a bit complex to implement but we would test and see how the model performs with that.
#
# We have to come up with a way to measure the success of our model. We could implement 2 version of online application, one with the recommendation system and one without it. We make both applications available to 2 different set of users to see which one performs better in achieving the set goals. From there we could measure when to updated the model. This depends on how much useful data generated and how well the recommendation system performed.
#
# The fact that collaborative filtering is content-agnostic is a great plus. You don't have to spend any energy adding metadata to your content or collect knowledge about your users. You only need the ratings and the interactions between items.

# %% [markdown]
# # Exceptional Work
#
# * **Hypertuning**:
#     * While there is a built-in function in GraphLab for a gridsearch functionality, Apple chose not to port it over to Turi Create, so it is unavailable for Python 3.x.  We still wanted to conduct hypertuning, so we ended up doing our hypertuning by hand, selecting parameters to adjust that we thought could improve model performance, evaluating, and visualizing one at a time.  We were able to see a good bit of performance differences by adjusting **ranking_regularization, num_sampled_negative_examples, and feature selection.**  The create function automatically runs several small tests to determine the best **sgd_step_size**, so we did not have to tune this parameter individually.
#
#
# * **Cloud Integration**:
#     * We spent a good bit of time training and hypertuning models, and Turi Create offers the ability to export (save) models.  The models are too large to upload to github (all of them exceed github's recommended 50mb filesize limit), so we created an AWS S3 bucket to store the data, and the models for users who would like to run our notebook, to save a lot of training time and start using the model data right away.
#     * We also scripted all steps required to download, unzip, and load these files right into the notebook to make it easy on users.
#
#
#
# * **EDA & Visualization**:
#     * We chose to utilize a totally new dataset, and suite of tools in the Turi Create library, thus we feel like we did quite a bit more EDA than would have been necessary if we had continued to utilize our prior labs' dataset.  Several of these plots are interesting in their own right, and we thought readers might like to see some of the movie metrics.
#     * We also spent quite a bit of time figuring out how best to visualize the evaluation metrics, and were able to come up with some pretty telling plots that really helped build our analysis.

# %% [markdown]
# # References
#
# 1. Dataset obtained from kaggle : <a href="https://www.kaggle.com/rounakbanik/the-movies-dataset"> click here </a>
# 2. Apple (turicreate) <a href="https://apple.github.io/turicreate/docs/userguide/recommender/"> article </a> on Recommender.
# 3. Recommendor Systems instruction by Dr. Eric Larson: <a href="https://www.youtube.com/watch?v=I-xPNMCqW2o"> video </a>
# 4. Movie Recommendation System with Collaborative Filteringn by Code Heroku: <a href="https://www.youtube.com/watch?v=3ecNC-So0r4&t=903s"> video </a>
# 5. Practical Recommeder Systems by Kim Falk
# 6. Evaluation metric calculations from: https://github.com/jakemdrew/DataMiningNotebooks/blob/master/13.%20Recommendation%20Systems.ipynb
# 7. Recommender systems handook - Francesco Ricci,Lior Rokach,Bracha Sharipa, Paul Kantor The Springer
